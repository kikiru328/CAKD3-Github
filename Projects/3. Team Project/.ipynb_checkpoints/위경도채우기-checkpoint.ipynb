# %%
import pandas as pd

data = pd.read_excel('dataset/전국스마트가로등표준데이터-20210801.xls',index_col=0)
data.columns = data.iloc[0]
data = data[1:]
seoul_data = data.query('시도명=="서울특별시"')

seoul_data.drop(['소재지도로명주소','제공기관코드','제공기관명','관리기관전화번호','도로명','시도명','앱서비스명','앱서비스제공내용','관리기관명'],axis=1,inplace=True)
seoul_data.센싱정보서비스.fillna('없음',inplace=True)
seoul_data.기타서비스.fillna('없음',inplace=True)
seoul_data.index = seoul_data.스마트가로등형태
seoul_data.drop('스마트가로등형태',axis=1,inplace=True)
seoul_data
# Out:
# D:\Tools\envs\cakd3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# D:\Tools\envs\cakd3\lib\site-packages\pandas\core\series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
# 스마트가로등유형 시군구명               소재지지번주소         위도          경도 점등상태여부       센서종류  \
# 스마트가로등형태
# 01        강서구   서울특별시 강서구 공항동 2-104  37.562692         NaN      Y  속도센서+전류센서
# 01        강서구   서울특별시 강서구 공항동 2-104        NaN         NaN      Y       전류센서
# 01        강서구   서울특별시 강서구 공항동 2-104  37.562441  126.816405      Y  속도센서+전류센서
# 01        강서구   서울특별시 강서구 공항동 2-104  37.562468  126.816555      Y       전류센서
# 01        강서구   서울특별시 강서구 공항동 2-104  37.562164  126.816405      Y  속도센서+전류센서
# ...       ...                   ...        ...         ...    ...        ...
# 01        강서구  서울특별시 강서구 방화동 217-22  37.568234         NaN      Y       전류센서
# 01        강서구  서울특별시 강서구 방화동 217-22  37.568075         NaN      Y  속도센서+전류센서
# 01        강서구  서울특별시 강서구 방화동 217-22  37.568081         NaN      Y       전류센서
# 01        강서구  서울특별시 강서구 방화동 217-22  37.567777  126.816534      Y  속도센서+전류센서
# 01        강서구  서울특별시 강서구 방화동 217-22        NaN  126.816671      Y       전류센서
#
# 스마트가로등유형 센싱정보서비스 CCTV유무 WiFi유무 GPS수신기유무 비콘유무 조명제어여부 위급상황신고가능여부         기타서비스  \
# 스마트가로등형태
# 01          도로조명      N      N        N    N      Y          N  전력사용량정보+고장정보
# 01          도로조명      N      N        N    N      Y          N  전력사용량정보+고장정보
# 01          도로조명      N      N        N    N      Y          N  전력사용량정보+고장정보
# 01          도로조명      N      N        N    N      Y          N  전력사용량정보+고장정보
# 01          도로조명      N      N        N    N      Y          N  전력사용량정보+고장정보
# ...          ...    ...    ...      ...  ...    ...        ...           ...
# 01          도로조명      N      N        N    N      Y          N  전력사용량정보+고장정보
# 01          도로조명      N      N        N    N      Y          N  전력사용량정보+고장정보
# 01          도로조명      N      N        N    N      Y          N  전력사용량정보+고장정보
# 01          도로조명      N      N        N    N      Y          N  전력사용량정보+고장정보
# 01          도로조명      N      N        N    N      Y          N  전력사용량정보+고장정보
#
# 스마트가로등유형  설치연도     데이터기준일자
# 스마트가로등형태
# 01        2020  2021-03-19
# 01        2020  2021-03-19
# 01        2020  2021-03-19
# 01        2020  2021-03-19
# 01        2020  2021-03-19
# ...        ...         ...
# 01        2020  2021-03-19
# 01        2020  2021-03-19
# 01        2020  2021-03-19
# 01        2020  2021-03-19
# 01        2020  2021-03-19
#
# [247 rows x 16 columns]

# %%
LY_null = seoul_data[(seoul_data['위도'].isnull()==1) | (seoul_data['경도'].isnull()==1)]

# %%
LY_null['소재지지번주소'].unique()
# Out:
# array(['서울특별시 강서구 공항동 2-104', '서울특별시 강서구 방화동 217-123',
#        '서울특별시 강서구 방화동 271-4', '서울특별시 강서구 마곡동 2-17', '서울특별시 강서구 마곡동 407-6',
#        '서울특별시 강서구 공항동 1-1', '서울특별시 강서구 가양동 258-3', '서울특별시 강서구 방화동 252-4',
#        '서울특별시 강서구 방화동 240-5', '서울특별시 강서구 방화동 217-22'], dtype=object)

# %%
list_location = LY_null['소재지지번주소'].unique().tolist()

# %%
LY_null
# Out:
# 스마트가로등유형 시군구명                소재지지번주소          위도          경도 점등상태여부  \
# 스마트가로등형태
# 01        강서구    서울특별시 강서구 공항동 2-104   37.562692         NaN      Y
# 01        강서구    서울특별시 강서구 공항동 2-104         NaN         NaN      Y
# 01        강서구    서울특별시 강서구 공항동 2-104         NaN  126.816552      Y
# 01        강서구    서울특별시 강서구 공항동 2-104   37.561741         NaN      Y
# 01        강서구    서울특별시 강서구 공항동 2-104   37.561466         NaN      Y
# 01        강서구    서울특별시 강서구 공항동 2-104   37.561327         NaN      Y
# 99        강서구  서울특별시 강서구 방화동 217-123   37.563719         NaN      Y
# 01        강서구    서울특별시 강서구 방화동 271-4         NaN         NaN      Y
# 01        강서구    서울특별시 강서구 방화동 271-4         NaN         NaN      Y
# 01        강서구    서울특별시 강서구 방화동 271-4   37.572995         NaN      Y
# 01        강서구    서울특별시 강서구 방화동 271-4   37.572999         NaN      Y
# 01        강서구    서울특별시 강서구 방화동 271-4   37.572697         NaN      Y
# 01        강서구    서울특별시 강서구 방화동 271-4         NaN         NaN      Y
# 01        강서구    서울특별시 강서구 방화동 271-4         NaN  126.816637      Y
# 01        강서구    서울특별시 강서구 방화동 271-4         NaN  126.816775      Y
# 01        강서구    서울특별시 강서구 방화동 271-4   37.572285         NaN      Y
# 01        강서구    서울특별시 강서구 방화동 271-4         NaN  126.816754      Y
# 01        강서구    서울특별시 강서구 방화동 271-4   37.571982         NaN      Y
# 01        강서구    서울특별시 강서구 방화동 271-4   37.571597         NaN      Y
# 01        강서구    서울특별시 강서구 방화동 271-4         NaN  126.816745      Y
# 01        강서구    서울특별시 강서구 방화동 271-4   37.571454         NaN      Y
# 01        강서구    서울특별시 강서구 방화동 271-4   37.571426         NaN      Y
# 01        강서구     서울특별시 강서구 마곡동 2-17   37.576315         NaN      Y
# 01        강서구    서울특별시 강서구 마곡동 407-6         NaN  126.836922      Y
# 01        강서구    서울특별시 강서구 마곡동 407-6   37.573459         NaN      Y
# 01        강서구    서울특별시 강서구 마곡동 407-6         NaN  126.837119      Y
# 01        강서구  서울특별시 강서구 방화동 217-123         NaN  126.816488      Y
# 01        강서구  서울특별시 강서구 방화동 217-123         NaN  126.816475      Y
# 01        강서구      서울특별시 강서구 공항동 1-1   37.565025         NaN      Y
# 01        강서구      서울특별시 강서구 공항동 1-1   37.564791         NaN      Y
# 01        강서구      서울특별시 강서구 공항동 1-1         NaN         NaN      Y
# 01        강서구      서울특별시 강서구 공항동 1-1   37.564094         NaN      Y
# 01        강서구    서울특별시 강서구 공항동 2-104   37.563243         NaN      Y
# 01        강서구    서울특별시 강서구 공항동 2-104   37.562946         NaN      Y
# 01        강서구    서울특별시 강서구 공항동 2-104   37.562959         NaN      Y
# 01        강서구    서울특별시 강서구 마곡동 407-6         NaN  126.837201      Y
# 01        강서구    서울특별시 강서구 가양동 258-3         NaN  126.837783      Y
# 01        강서구    서울특별시 강서구 가양동 258-3   37.570884         NaN      Y
# 01        강서구    서울특별시 강서구 가양동 258-3   37.570535         NaN      Y
# 01        강서구    서울특별시 강서구 방화동 271-4   37.570936         NaN      Y
# 01        강서구    서울특별시 강서구 방화동 271-4         NaN         NaN      Y
# 01        강서구    서울특별시 강서구 방화동 271-4  37.5706735         NaN      Y
# 01        강서구    서울특별시 강서구 방화동 271-4   37.569933         NaN      Y
# 01        강서구    서울특별시 강서구 방화동 271-4   37.569914         NaN      Y
# 01        강서구    서울특별시 강서구 방화동 252-4   37.569649         NaN      Y
# 01        강서구    서울특별시 강서구 방화동 271-4   37.569383         NaN      Y
# 01        강서구    서울특별시 강서구 방화동 240-5         NaN  126.816685      Y
# 01        강서구   서울특별시 강서구 방화동 217-22   37.568395         NaN      Y
# 01        강서구   서울특별시 강서구 방화동 217-22   37.568416         NaN      Y
# 01        강서구   서울특별시 강서구 방화동 217-22   37.568231         NaN      Y
# 01        강서구   서울특별시 강서구 방화동 217-22   37.568234         NaN      Y
# 01        강서구   서울특별시 강서구 방화동 217-22   37.568075         NaN      Y
# 01        강서구   서울특별시 강서구 방화동 217-22   37.568081         NaN      Y
# 01        강서구   서울특별시 강서구 방화동 217-22         NaN  126.816671      Y
#
# 스마트가로등유형        센서종류 센싱정보서비스 CCTV유무 WiFi유무 GPS수신기유무 비콘유무 조명제어여부 위급상황신고가능여부  \
# 스마트가로등형태
# 01         속도센서+전류센서    도로조명      N      N        N    N      Y          N
# 01              전류센서    도로조명      N      N        N    N      Y          N
# 01              전류센서    도로조명      N      N        N    N      Y          N
# 01              전류센서    도로조명      N      N        N    N      Y          N
# 01              전류센서    도로조명      N      N        N    N      Y          N
# 01              전류센서    도로조명      N      N        N    N      Y          N
# 99        속도센서+카운팅센서      교통      N      N        N    N      N          N
# 01         속도센서+전류센서    도로조명      N      N        N    N      Y          N
# 01              전류센서    도로조명      N      N        N    N      Y          N
# 01         속도센서+전류센서    도로조명      N      N        N    N      Y          N
# 01              전류센서    도로조명      N      N        N    N      Y          N
# 01         속도센서+전류센서    도로조명      N      N        N    N      Y          N
# 01              전류센서    도로조명      N      N        N    N      Y          N
# 01         속도센서+전류센서    도로조명      N      N        N    N      Y          N
# 01              전류센서    도로조명      N      N        N    N      Y          N
# 01         속도센서+전류센서    도로조명      N      N        N    N      Y          N
# 01              전류센서    도로조명      N      N        N    N      Y          N
# 01              전류센서    도로조명      N      N        N    N      Y          N
# 01         속도센서+전류센서    도로조명      N      N        N    N      Y          N
# 01              전류센서    도로조명      N      N        N    N      Y          N
# 01         속도센서+전류센서    도로조명      N      N        N    N      Y          N
# 01              전류센서    도로조명      N      N        N    N      Y          N
# 01         속도센서+전류센서    도로조명      N      N        N    N      Y          N
# 01         속도센서+전류센서    도로조명      N      N        N    N      Y          N
# 01         속도센서+전류센서    도로조명      N      N        N    N      Y          N
# 01         속도센서+전류센서    도로조명      N      N        N    N      Y          N
# 01         속도센서+전류센서    도로조명      N      N        N    N      Y          N
# 01         속도센서+전류센서    도로조명      N      N        N    N      Y          N
# 01              전류센서    도로조명      N      N        N    N      Y          N
# 01         속도센서+전류센서    도로조명      N      N        N    N      Y          N
# 01              전류센서    도로조명      N      N        N    N      Y          N
# 01         속도센서+전류센서    도로조명      N      N        N    N      Y          N
# 01              전류센서    도로조명      N      N        N    N      Y          N
# 01         속도센서+전류센서    도로조명      N      N        N    N      Y          N
# 01              전류센서    도로조명      N      N        N    N      Y          N
# 01         속도센서+전류센서    도로조명      N      N        N    N      Y          N
# 01         속도센서+전류센서    도로조명      N      N        N    N      Y          N
# 01         속도센서+전류센서    도로조명      N      N        N    N      Y          N
# 01         속도센서+전류센서    도로조명      N      N        N    N      Y          N
# 01         속도센서+전류센서    도로조명      N      N        N    N      Y          N
# 01              전류센서    도로조명      N      N        N    N      Y          N
# 01              전류센서    도로조명      N      N        N    N      Y          N
# 01         속도센서+전류센서    도로조명      N      N        N    N      Y          N
# 01              전류센서    도로조명      N      N        N    N      Y          N
# 01         속도센서+전류센서    도로조명      N      N        N    N      Y          N
# 01              전류센서    도로조명      N      N        N    N      Y          N
# 01              전류센서    도로조명      N      N        N    N      Y          N
# 01         속도센서+전류센서    도로조명      N      N        N    N      Y          N
# 01              전류센서    도로조명      N      N        N    N      Y          N
# 01         속도센서+전류센서    도로조명      N      N        N    N      Y          N
# 01              전류센서    도로조명      N      N        N    N      Y          N
# 01         속도센서+전류센서    도로조명      N      N        N    N      Y          N
# 01              전류센서    도로조명      N      N        N    N      Y          N
# 01              전류센서    도로조명      N      N        N    N      Y          N
#
# 스마트가로등유형           기타서비스  설치연도     데이터기준일자
# 스마트가로등형태
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 99        교통량측정정보+평균속도정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19
# 01          전력사용량정보+고장정보  2020  2021-03-19

# %%
LY['소재지지번주소'].agg(get_lat_lng)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-46-7f4cbd5357f5> in <module>
# ----> 1 LY['소재지지번주소'].agg(get_lat_lng)
#
# D:\Tools\envs\cakd3\lib\site-packages\pandas\core\series.py in aggregate(self, func, axis, *args, **kwargs)
#    3989             # operation is actually defined on the Series, e.g. str
#    3990             try:
# -> 3991                 result = self.apply(func, *args, **kwargs)
#    3992             except (ValueError, AttributeError, TypeError):
#    3993                 result = func(self, *args, **kwargs)
#
# D:\Tools\envs\cakd3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-44-73370a258d64> in get_lat_lng(x)
#      10         # float(p_s_places[select_number]) ~
#      11
# ---> 12         p_s_Lat = float(p_s_places[0]['y'])
#      13         p_s_Lng = float(p_s_places[0]['x'])
#      14         p_s_LatLng=(p_s_Lat,p_s_Lng)
#
# IndexError: list index out of range
