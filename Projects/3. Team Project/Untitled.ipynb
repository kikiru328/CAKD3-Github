# %%
import pandas as pd
import numpy as np
import urllib.request as req
import requests
from bs4 import BeautifulSoup as bs

# %%
url = 'http://api.data.go.kr/openapi/tn_pubr_public_smart_streetlight_api?serviceKey=0nvWRjDWerwQGQ7dGwJhCm%2FxEkkbYBiWQXfnf%2BJkkO3dkoTpaGvyy44heAG1hY%2BjV7ZQxbK0LlDdoeer2yORHw%3D%3D&pageNo=0&numOfRows=100&type=json'
response = req.urlopen(url)

# %%
data = bs(response, 'html.parser')

# %%
data
# Out:
# {"response":{"header":{"resultCode":"00","resultMsg":"NORMAL_SERVICE","type":"json"},"body":{"items":[{"streetLampType":"1","ctprvnNm":"충청남도","signguNm":"홍성군","roadNm":"남장중로","rdnmadr":"","lnmadr":"충청남도 홍성군 홍성읍 남장리 626","latitude":"36.587412","longitude":"126.668446","streetLampStle":"01","lghtUsgsttYn":"Y","sensorKnd":"없음","sensingInfoSvc":"","cctvYn":"N","wifiYn":"N","gpsYn":"N","beaconYn":"N","lghtCtrlYn":"Y","emrgncSttemntPosblYn":"N","appSvcNm":"","appSvcCn":"","etcSvc":"","installationYear":"","institutionNm":"홍성군","phoneNumber":"041-630-1582","referenceDate":"2020-07-07","insttCode":"4600000"},{"streetLampType":"1","ctprvnNm":"충청남도","signguNm":"홍성군","roadNm":"남장중로","rdnmadr":"","lnmadr":"충청남도 홍성군 홍성읍 남장리 626","latitude":"36.587341","longitude":"126.667754","streetLampStle":"01","lghtUsgsttYn":"Y","sensorKnd":"없음","sensingInfoSvc":"","cctvYn":"N","wifiYn":"N","gpsYn":"N","beaconYn":"N","lghtCtrlYn":"Y","emrgncSttemntPosblYn":"N","appSvcNm":"","appSvcCn":"","etcSvc":"","installa
# ...
