# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
fdf = pd.read_csv('Dataset/서울화재빈도데이터.csv')
child = pd.read_csv('Dataset/어린이보호구역데이터.csv')

# %%
crime_small = pd.read_excel('Dataset/범죄발생장소.csv')
# Out:
# C:\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
crime1 = pd.read_excel('Dataset/범죄발생장소.csv')

# %%
crime1.head()
# crime1 = crime1.drop(1,axis=0)
# Out:
#    No   자료시점    분류      분류.1          계        계.1     계.2    계.3      계.4  \
# 0  No   자료시점    분류        분류          계  아파트,연립다세대    단독주택   고속도로       노상
# 1  No   자료시점    분류        분류        원자료        원자료     원자료    원자료      원자료
# 2   1  2019년    총계        총계  1,611,906     96,879  84,895  7,762  625,533
# 3   2  2019년  강력범죄  강력범죄(소계)     26,476      3,892   2,725     18    3,932
# 4   3  2019년  강력범죄        강간      5,310      1,432     999      0      158
#
#      계.5  ...   계.25   계.26    계.27   계.28  계.29 계.30    계.31   계.32   계.33  \
# 0    백화점  ...   종교기관     산야      해상     부대  구금장소   공지     주차장  공중화장실    피씨방
# 1    원자료  ...    원자료    원자료     원자료    원자료   원자료  원자료     원자료    원자료    원자료
# 2  4,155  ...  3,263  9,878  20,287  2,266   111  339  26,356  4,529  6,917
# 3     28  ...     87     93       7     14    12    7     225    168     73
# 4      1  ...     14      8       0      1     0    1      37     59      2
#
#       계.34
# 0       기타
# 1      원자료
# 2  297,411
# ...

# %%
crime1.head()
crime1['분류.1'].unique()
# Out:
# array(['분류', '총계', '강력범죄(소계)', '강간', '강간·강제추행', '강도', '강제추행',
#        '기타(강간·강제추행등)', '방화', '살인(기수)', '살인(미수등)', '유사강간', '절도범죄',
#        '폭력범죄(소계)', '공갈', '상해', '손괴', '약취·유인', '체포·감금', '폭력행위등', '폭행',
#        '협박', '지능범죄(소계)', '문서·인장', '배임', '사기', '유가증권인지', '증수뢰', '직권남용',
#        '직무유기', '통화', '횡령', '풍속범죄(소계)', '도박범죄', '성풍속범죄', '특별경제범죄', '마약범죄',
#        '보건범죄', '환경범죄', '교통범죄', '노동범죄', '안보범죄', '선거범죄', '병역범죄', '기타범죄'],
#       dtype=object)

# %%
crime2 = pd.read_csv('Dataset/범죄검거율.csv')

# %%
crime2.head(3)
# crime2 = crime2.drop(1,axis=0)
# Out:
#      기간  자치구       합계    합계.1   살인 살인.1   강도 강도.1 강간강제추행 강간강제추행.1      절도  \
# 0    기간  자치구       발생      검거   발생   검거   발생   검거     발생       검거      발생
# 1  2019   합계  103,668  74,805  136  128  136  133  6,469    6,007  42,204
# 2  2019  종로구    3,846   4,117    4    5    7    8    238    1,143   1,515
#
#      절도.1      폭력    폭력.1
# 0      검거      발생      검거
# 1  21,284  54,723  47,253
# 2   1,069   2,082   1,892

# %%
crime2.head()
# Out:
#      기간  자치구       합계    합계.1   살인 살인.1   강도 강도.1 강간강제추행 강간강제추행.1      절도  \
# 0    기간  자치구       발생      검거   발생   검거   발생   검거     발생       검거      발생
# 1  2019   합계  103,668  74,805  136  128  136  133  6,469    6,007  42,204
# 2  2019  종로구    3,846   4,117    4    5    7    8    238    1,143   1,515
# 3  2019   중구    4,327   2,804    2    1    6    5    195      115   2,202
# 4  2019  용산구    3,313   2,611    3    3    3    4    272      237     999
#
#      절도.1      폭력    폭력.1
# 0      검거      발생      검거
# 1  21,284  54,723  47,253
# 2   1,069   2,082   1,892
# 3   1,050   1,922   1,633
# 4     544   2,036   1,823

# %%
crime2 = crime2.drop(1)

# %%
crime2 = crime2.set_index('자치구')

# %%
crime2 = crime2[['합계']]

# %%
import re
def to_f(x):
    new=re.sub(',',"",x)
    new=float(new)
    return new

# %%
crime2['합계'] = crime2['합계'].apply(lambda x : to_f(x))
# Out:
# <ipython-input-41-6bab49f96378>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   crime2['합계'] = crime2['합계'].apply(lambda x : to_f(x))

# %%
crime2
# Out:
#           합계
# 자치구
# 종로구   3846.0
# 중구    4327.0
# 용산구   3313.0
# 성동구   2512.0
# 광진구   4011.0
# 동대문구  3692.0
# 중랑구   4268.0
# 성북구   2877.0
# 강북구   3838.0
# 도봉구   2110.0
# 노원구   4153.0
# 은평구   3880.0
# 서대문구  2943.0
# 마포구   4842.0
# 양천구   3214.0
# 강서구   4924.0
# 구로구   4707.0
# 금천구   3105.0
# 영등포구  5820.0
# 동작구   3400.0
# 관악구   5328.0
# 서초구   5542.0
# 강남구   7304.0
# 송파구   5698.0
# 강동구   4014.0
