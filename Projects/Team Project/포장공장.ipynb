# %%
import os
import pandas as pd
path = 'New1'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.csv')]
df = pd.DataFrame()
for i in file_list_py:
    data = pd.read_csv(path + '/'+ i,index_col=0)
    df = pd.concat([df,data])

# %%
dd = pd.read_csv('New1/강원도인구.csv',index_col=0,encoding='cp949')

# %%
dd =dd.reset_index(drop=False)

# %%
dd['읍면동별(1)']. unique()
# Out:
# array(['읍면동별(1)', '전체', '춘천시', '원주시', '강릉시', '동해시', '태백시', '속초시', '삼척시',
#        '홍천군', '횡성군', '영월군', '평창군', '정선군', '철원군', '화천군', '양구군', '인제군',
#        '고성군', '양양군'], dtype=object)

# %%
dd
# Out:
#      읍면동별(1)  읍면동별(2)      2018    2018.1    2018.2    2018.3   2018.4  \
# 0    읍면동별(1)  읍면동별(2)  세대수 (세대)  등록인구 (명)  등록인구 (명)  등록인구 (명)  한국인 (명)
# 1    읍면동별(1)  읍면동별(2)        소계        소계         남         여       소계
# 2         전체       소계    707245   1561313    786364    774949  1543052
# 3        춘천시       소계    120190    285002    140527    144475   280640
# 4        춘천시      신북읍      3472      8080      4059      4021     7949
# ..       ...      ...       ...       ...       ...       ...      ...
# 204      양양군       서면      1526      3017      1557      1460     3005
# 205      양양군      손양면      1240      2485      1273      1212     2426
# 206      양양군      현북면      1463      2648      1373      1275     2612
# 207      양양군      현남면      1704      3135      1604      1531     3081
# 208      양양군      강현면      2306      4423      2237      2186     4385
#
#       2018.5   2018.6   2018.7   2018.8   2018.9        2018.10
# ...

# %%
dd = dd[['읍면동별(1)','읍면동별(2)','2018.1']]

# %%
dd = dd.rename(columns={'읍면동별(1)':'시군구명','읍면동별(2)':'읍/면/동','2018.1':'등록인구수'})

# %%
읍면동 = [index for index, row in dd[dd['읍/면/동']=='소계'].iterrows()]
불필요시군구 = [index for index, row in dd[dd['읍/면/동']=='읍면동별(2)'].iterrows()]

# %%
dd = dd.drop(읍면동)
dd = dd.drop(불필요시군구)

# %%
dd['시도명'] = '강원도'

# %%
dd = dd[['시도명','시군구명','읍/면/동','등록인구수']]

# %%
dd
# Out:
#      시도명 시군구명 읍/면/동  등록인구수
# 4    강원도  춘천시   신북읍   8080
# 5    강원도  춘천시    동면  20120
# 6    강원도  춘천시   동산면   1560
# 7    강원도  춘천시   신동면   2594
# 8    강원도  춘천시    남면   1123
# ..   ...  ...   ...    ...
# 204  강원도  양양군    서면   3017
# 205  강원도  양양군   손양면   2485
# 206  강원도  양양군   현북면   2648
# 207  강원도  양양군   현남면   3135
# 208  강원도  양양군   강현면   4423
#
# [188 rows x 4 columns]

# %%
data

# %%
data = pd.read_csv('Dataset/total/화재통합.csv',index_col=0)

# %%
data1 = pd.read_csv('Dataset/total/인구_충청남도아산시_완.csv',index_col=0)

# %%
data1
# Out:
#      시도명 읍/면/동     인구
# 0   충청남도   염치읍   6980
# 1   충청남도   배방읍  74906
# 2   충청남도   송악면   4355
# 3   충청남도   탕정면  21879
# 4   충청남도   음봉면  20996
# 5   충청남도   둔포면  25135
# 6   충청남도   영인면   6397
# 7   충청남도   인주면   7478
# 8   충청남도   선장면   3664
# 9   충청남도   도고면   4630
# 10  충청남도   신창면  25247
# 11  충청남도  온양1동  10085
# 12  충청남도  온양2동   7869
# 13  충청남도  온양3동  37848
# 14  충청남도  온양4동  19078
# 15  충청남도  온양5동  26973
# 16  충청남도  온양6동  29554

# %%
data2 =data[data['시군구명']=='아산시']

# %%
data2[data2['어린이보호구역수'].isnull()==0]
# Out:
# Empty DataFrame
# Columns: [시도명, 시군구명, 읍/면/동, 설치유무, 화재발생횟수, 화재발생비율, 어린이보호구역수, 어린이보호구역비율]
# Index: []

# %%
data1 = data1.rename(columns = {'동/읍/면':'읍/면/동'})

# %%
data3 = pd.merge(data1,data2,on='읍/면/동',how='outer')

# %%
data[data['어린이보호구역비율'].isnull()==0]
# Out:
#       시도명 시군구명 읍/면/동  설치유무  화재발생횟수  화재발생비율  어린이보호구역수  어린이보호구역비율
# 751  충청북도  진천군   진천읍   1.0    31.0    0.25      12.0       0.33
# 752  충청북도  진천군   덕산읍   1.0     0.0    0.00       5.0       0.14
# 753  충청북도  진천군   초평면   1.0    17.0    0.13       4.0       0.11
# 754  충청북도  진천군   문백면   1.0    16.0    0.13       4.0       0.11
# 755  충청북도  진천군   백곡면   1.0     7.0    0.06       2.0       0.06
# 756  충청북도  진천군   이월면   0.0    19.0    0.15       6.0       0.17
# 757  충청북도  진천군  광혜원면   1.0    11.0    0.09       3.0       0.08
# 758  충청북도  진천군   덕산면   0.0    25.0    0.20       0.0       0.00

# %%
data3
# Out:
#    시도명_x 읍/면/동       인구 시도명_y 시군구명  설치유무  화재발생횟수    화재발생비율  어린이보호구역수  \
# 0   충청남도   염치읍   6980.0  충청남도  아산시   0.0    10.0  0.034602       NaN
# 1   충청남도   배방읍  74906.0  충청남도  아산시   0.0    35.0  0.121107       NaN
# 2   충청남도   송악면   4355.0  충청남도  아산시   1.0     9.0  0.031142       NaN
# 3   충청남도   탕정면  21879.0  충청남도  아산시   0.0    18.0  0.062284       NaN
# 4   충청남도   음봉면  20996.0  충청남도  아산시   1.0    35.0  0.121107       NaN
# 5   충청남도   둔포면  25135.0  충청남도  아산시   1.0    28.0  0.096886       NaN
# 6   충청남도   영인면   6397.0  충청남도  아산시   1.0    26.0  0.089965       NaN
# 7   충청남도   인주면   7478.0  충청남도  아산시   1.0    15.0  0.051903       NaN
# 8   충청남도   선장면   3664.0  충청남도  아산시   1.0     8.0  0.027682       NaN
# 9   충청남도   도고면   4630.0  충청남도  아산시   1.0    12.0  0.041522       NaN
# 10  충청남도   신창면  25247.0  충청남도  아산시   0.0    28.0  0.096886       NaN
# 11  충청남도  온양1동  10085.0   NaN  NaN   NaN     NaN       NaN       NaN
# 12  충청남도  온양2동   7869.0   NaN  NaN   NaN     NaN       NaN       NaN
# ...

# %%
data2
# Out:
#       시도명 시군구명 읍/면/동  설치유무  화재발생횟수    화재발생비율  어린이보호구역수  어린이보호구역비율
# 725  충청남도  아산시   염치읍   0.0    10.0  0.034602       NaN        NaN
# 726  충청남도  아산시   배방읍   0.0    35.0  0.121107       NaN        NaN
# 727  충청남도  아산시   송악면   1.0     9.0  0.031142       NaN        NaN
# 728  충청남도  아산시   탕정면   0.0    18.0  0.062284       NaN        NaN
# 729  충청남도  아산시   음봉면   1.0    35.0  0.121107       NaN        NaN
# 730  충청남도  아산시   둔포면   1.0    28.0  0.096886       NaN        NaN
# 731  충청남도  아산시   영인면   1.0    26.0  0.089965       NaN        NaN
# 732  충청남도  아산시   인주면   1.0    15.0  0.051903       NaN        NaN
# 733  충청남도  아산시   선장면   1.0     8.0  0.027682       NaN        NaN
# 734  충청남도  아산시   도고면   1.0    12.0  0.041522       NaN        NaN
# 735  충청남도  아산시   신창면   0.0    28.0  0.096886       NaN        NaN
# 736  충청남도  아산시   온양동   0.0     0.0  0.000000       NaN        NaN
# 737  충청남도  아산시   권곡동   0.0     9.0  0.031142       NaN        NaN
# ...

# %%
시도명 = (df['시도명'].unique()).tolist()
시군구명 = (df['시군구명'].unique()).tolist()

# %%
df[['시군구명','읍/면/동']]
ui = []
for i in range(len(시군구명)):
    for j in 시군구명:
        ui.append([j,df[(df['시군구명']==j)]['읍/면/동'].unique().tolist()])

# %%
ui
# Out:
# [['강릉시',
#   ['강동면',
#    '강동면정동',
#    '강문동',
#    '교동',
#    '구정면',
#    '내곡동',
#    '노암동',
#    '두산동',
#    '사천면',
#    '성산면',
#    '송정동',
#    '안현동',
#    '연곡면',
#    '옥계면',
#    '옥천동',
#    '왕산면',
#    '유천동',
#    '입암동',
#    '장현동',
#    '주문진읍',
#    '초당동',
#    '포남동',
#    '홍제동',
#    '회산동',
#    '중앙동',
#    '교1동',
#    '교2동',
#    '포남1동',
#    '포남2동',
#    '강남동',
#    '성덕동',
#    '경포동',
#    '견소동',
#    '금학동',
#    '난곡동',
#    '남문동',
#    '남항진동',
#    '담산동',
#    '대전동',
#    '박월동',
#    '병산동',
#    '성남동',
#    '신석동',
#    '용강동',
#    '운정동',
#    '유산동',
#    '임당동',
#    '저동',
#    '죽헌동',
#    '지변동',
#    '청량동',
#    '학동']],
#  ['인제군', ['기린면', '기린면방동', '기린면진동', '남면', '북면', '상남면', '서화면', '인제읍', '인제읍상동']],
#  ['춘천시',
#   ['교동',
#    '근화동',
#    '낙원동',
#    '남산면',
#    '동내면',
#    '동면',
#    '동산면',
#    '봉의동',
#    '북산면',
#    '사북면',
#    '서면',
#    '석사동',
#    '소양로1가',
#    '신동',
#    '신동면',
#    '신북읍',
#    '약사동',
#    '온의동',
#    '우두동',
#    '죽림동',
#    '중앙로3가',
#    '칠전동',
# ...
