# %%
import pandas as pd
pd.set_option('display.max_row', 500)
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# import re
# def dong(x):
#     import re

#     p = re.compile('[가-힣]\S*[읍면동가]')

#     r = p.findall(x)
    
#     return ''.join(r)

# 제공기관명 = '강원도 춘천시'
검색할시도명='강원도'
검색할시군구명='춘천시'
제공기관명 = f'{검색할시도명} {검색할시군구명}'

빼올ui = 검색할시도명
검색할구 = 검색할시군구명
PP = pd.read_csv(f'Dataset/human/{빼올ui}.csv')
um = PP[PP['시군구명']==검색할구]
u1 = um['읍/면/동'].tolist()
u1
len(u1)
# Out:
# 25

# %%
import re
def dong(x):
    import re

    p = re.compile('[가-힣]\S*[읍면동가]')

    r = p.findall(x)
    
    return ''.join(r)

import re
def dong1(x):
    import re

    p = re.compile('[가-힣]\S*[면동가]')

    r = p.findall(x)
    
    return ''.join(r)

# %%
data = pd.read_csv('Dataset/전국스마트가로등표준데이터.csv',encoding='cp949')

data.isnull().sum()

data.columns

data['시도명'].unique()

data['시도명'] = data['시도명'].replace('14','전라남도')

data[data['시도명']==검색할시도명]['시군구명'].unique()

data1 = data[data['시도명']==검색할시도명]
detail_1 = data1[data1['시군구명']==검색할시군구명]


detail_1['읍/면/동'] = detail_1['소재지지번주소'].apply(lambda x : dong(x))


detail_1['설치유무'] = 1

get_col = ['시도명','시군구명','소재지지번주소','읍/면/동','설치유무']
detail_1 = detail_1[get_col]


u2 = detail_1['읍/면/동'].unique().tolist()
us = pd.Series(u1)

detail = pd.DataFrame(us)
detail['설치유무'] = np.nan
detail['시도명'] = data[data['시도명']==검색할시도명]['시도명'].unique()[0]
detail['시군구명'] = data[data['시군구명']==검색할시군구명]['시군구명'].unique()[0]

def 설치유무(x):
    y = ''
    for i in u2 :
        if x == i :
            y = 1
    return y


detail['설치유무'].update(detail[0].apply(설치유무))
detail['설치유무'] = detail['설치유무'].replace("",0)
detail = detail.rename(columns={0:'읍/면/동'})

detail = detail[['시도명','시군구명','읍/면/동','설치유무']]

detail
# Out:
#     시도명 시군구명 읍/면/동  설치유무
# 0   강원도  춘천시   신북읍     1
# 1   강원도  춘천시    동면     1
# 2   강원도  춘천시   동산면     1
# 3   강원도  춘천시   신동면     1
# 4   강원도  춘천시    남면     0
# 5   강원도  춘천시    서면     1
# 6   강원도  춘천시   사북면     1
# 7   강원도  춘천시   북산면     0
# 8   강원도  춘천시   동내면     1
# 9   강원도  춘천시   남산면     0
# 10  강원도  춘천시    교동     1
# 11  강원도  춘천시   조운동     0
# 12  강원도  춘천시  약사명동     0
# 13  강원도  춘천시   근화동     1
# 14  강원도  춘천시   소양동     0
# 15  강원도  춘천시  후평1동     0
# 16  강원도  춘천시  후평2동     0
# 17  강원도  춘천시  후평3동     0
# 18  강원도  춘천시  효자1동     0
# 19  강원도  춘천시  효자2동     0
# 20  강원도  춘천시  효자3동     0
# 21  강원도  춘천시   석사동     1
# 22  강원도  춘천시   퇴계동     1
# 23  강원도  춘천시   강남동     0
# 24  강원도  춘천시  신사우동     0

# %%
df= pd.read_excel('dataset/전국어린이보호구역표준데이터-20210801.xls')

df = df.rename(columns=df.iloc[0])
df= df.drop(df.index[0])

df1 = df.loc[df.loc[:,'제공기관명'].str.contains(제공기관명,na=False)]

detail_1 = df1[df1['제공기관명']==제공기관명]


detail_1['읍/면/동'] = detail_1['소재지지번주소'].apply(lambda x : dong1(x))


a= 제공기관명.split(" ")[0]
b= 제공기관명.split(" ")[1]

detail_1['시도명']= a
detail_1['시군구명']= b

# %%
#여기 replace("" , '여기부분')
#여기에는 '소재지지번주소가 일정하면 안뺸거 넣으면 됨. ex) 강원도 춘천시 - 신북읍'

# %%
a = detail_1[detail_1['읍/면/동']=='']
display(a)
a['읍/면/동'] = a['읍/면/동'].replace("",'신북읍')
detail_1[detail_1['읍/면/동']==''] = a
child = detail_1[['시도명','시군구명','읍/면/동']]
child['어린이보호구역개수'] = 1
child[child['읍/면/동']=='']
# Out:
#        시설종류     대상시설명                         소재지도로명주소                소재지지번주소  \
# 14930  특수학교    춘천동원학교              강원도 춘천시 신북읍 상천1길 31   강원도 춘천시 신북읍 천전리 70-2
# 15758  초등학교    상천초등학교              강원도 춘천시 신북읍 상천2길 19    강원도 춘천시 신북읍 천전리 170
# 15769  초등학교    오동초등학교               강원도 춘천시 신북읍 장본길 74  강원도 춘천시 신북읍 발산리 473-2
# 15774  초등학교    천전초등학교            강원도 춘천시 신북읍 율문1길 16-9    강원도 춘천시 신북읍 율문리 295
# 15793   유치원  오동초병설유치원         강원도 춘천시 신북읍 장본길 74 (발산리)  강원도 춘천시 신북읍 발산리 473-2
# 15796   유치원  천전초병설유치원      강원도 춘천시 신북읍 율문1길 16-9 (율문리)    강원도 춘천시 신북읍 율문리 295
# 15824   유치원  상천초병설유치원        강원도 춘천시 신북읍 상천2길 19 (천전리)    강원도 춘천시 신북읍 천전리 170
# 15847  어린이집    진실어린이집               강원도 춘천시 신북읍 맥국길 74    강원도 춘천시 신북읍 천전리 993
# 15849  어린이집    한솔어린이집               강원도 춘천시 신북읍 신북로 99  강원도 춘천시 신북읍 율문리 813-1
# 15871  어린이집    다경어린이집  강원도 춘천시 신북읍 율문4길 20 (신북읍 304-1)  강원도 춘천시 신북읍 율문리 304-1
#
#                 위도           경도     관리기관명 관할경찰서명 CCTV설치여부 CCTV설치대수 보호구역도로폭  \
# 14930  37.93173701   127.789144  강원도 춘천시청  춘천경찰서        Y      NaN       8
# 15758  37.93360788  127.7858289  강원도 춘천시청  춘천경찰서        Y      NaN   15~20
# 15769  37.95184124  127.7580023  강원도 춘천시청  춘천경찰서        Y      NaN   20~25
# 15774  37.92746623  127.7461188  강원도 춘천시청  춘천경찰서        Y      NaN       8
# 15793  37.95184124  127.7580023  강원도 춘천시청  춘천경찰서        N      NaN   20~25
# 15796  37.92746623  127.7461188  강원도 춘천시청  춘천경찰서        N      NaN       8
# 15824  37.93360788  127.7858289  강원도 춘천시청  춘천경찰서        N      NaN   15~20
# 15847    37.936569  127.7757605  강원도 춘천시청  춘천경찰서        N      NaN       8
# 15849   37.9340319  127.7511589  강원도 춘천시청  춘천경찰서        Y      NaN   25~30
# 15871   37.9278113  127.7485311  강원도 춘천시청  춘천경찰서        Y      NaN       8
#
#           데이터기준일자   제공기관코드    제공기관명 읍/면/동  시도명 시군구명
# 14930  2020-07-13  4180000  강원도 춘천시        강원도  춘천시
# 15758  2020-07-13  4180000  강원도 춘천시        강원도  춘천시
# 15769  2020-07-13  4180000  강원도 춘천시        강원도  춘천시
# 15774  2020-07-13  4180000  강원도 춘천시        강원도  춘천시
# 15793  2020-07-13  4180000  강원도 춘천시        강원도  춘천시
# 15796  2020-07-13  4180000  강원도 춘천시        강원도  춘천시
# 15824  2020-07-13  4180000  강원도 춘천시        강원도  춘천시
# 15847  2020-07-13  4180000  강원도 춘천시        강원도  춘천시
# 15849  2020-07-13  4180000  강원도 춘천시        강원도  춘천시
# 15871  2020-07-13  4180000  강원도 춘천시        강원도  춘천시
# Empty DataFrame
# Columns: [시도명, 시군구명, 읍/면/동, 어린이보호구역개수]
# Index: []

# %%
group = child.groupby(['시도명','시군구명','읍/면/동'])
a = group.sum()
a = a.reset_index()
child = a

# %%
df = pd.merge(detail,child,on=['시도명','시군구명','읍/면/동'],how='left')
df['어린이보호구역개수'] = df['어린이보호구역개수'].fillna(0)
print(df.isnull().sum())
df
# Out:
# 시도명          0
# 시군구명         0
# 읍/면/동        0
# 설치유무         0
# 어린이보호구역개수    0
# dtype: int64
#     시도명 시군구명 읍/면/동  설치유무  어린이보호구역개수
# 0   강원도  춘천시   신북읍     1       10.0
# 1   강원도  춘천시    동면     1        8.0
# 2   강원도  춘천시   동산면     1        1.0
# 3   강원도  춘천시   신동면     1        3.0
# 4   강원도  춘천시    남면     0        0.0
# 5   강원도  춘천시    서면     1        6.0
# 6   강원도  춘천시   사북면     1        4.0
# 7   강원도  춘천시   북산면     0        2.0
# 8   강원도  춘천시   동내면     1        6.0
# 9   강원도  춘천시   남산면     0        6.0
# 10  강원도  춘천시    교동     1        2.0
# 11  강원도  춘천시   조운동     0        0.0
# 12  강원도  춘천시  약사명동     0        0.0
# 13  강원도  춘천시   근화동     1        1.0
# 14  강원도  춘천시   소양동     0        0.0
# 15  강원도  춘천시  후평1동     0        0.0
# 16  강원도  춘천시  후평2동     0        0.0
# 17  강원도  춘천시  후평3동     0        0.0
# 18  강원도  춘천시  효자1동     0        0.0
# 19  강원도  춘천시  효자2동     0        0.0
# 20  강원도  춘천시  효자3동     0        0.0
# 21  강원도  춘천시   석사동     1        6.0
# 22  강원도  춘천시   퇴계동     1        9.0
# 23  강원도  춘천시   강남동     0        0.0
# 24  강원도  춘천시  신사우동     0        0.0

# %%
df.to_csv(f'Dataset/child/{검색할시도명}{검색할시군구명}어린이보호구역.csv')
