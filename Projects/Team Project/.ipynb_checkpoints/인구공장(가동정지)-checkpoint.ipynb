# %% [raw]
# 광주광역시 : 남구
# 부산광역시 : 서구

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_row', 500)
import warnings
warnings.filterwarnings('ignore')

검색할시도명 = '광주광역시'
검색할시군구명 = '남구'


import re
def dong(x):
    import re

    p = re.compile('[가-힣]\S*[읍면동]')

    r = p.findall(x)
    
    return ''.join(r)

import re
def dong1(x):
    import re

    p = re.compile('[가-힣]\S*[면동가]')

    r = p.findall(x)
    
    return ''.join(r)






빼올ui = 검색할시도명
검색할구 = 검색할시군구명

PP = pd.read_csv(f'Dataset/인구밀도/{빼올ui}.csv')
um = PP[PP['시군구명']==검색할구]
u1 = um['읍/면/동'].tolist()
print(u1)
len(u1)
# Out:
# ['양림동', '방림1동', '방림2동', '봉선1동', '봉선2동', '사직동', '월산동', '월산4동', '월산5동', '백운1동', '백운2동', '주월1동', '주월2동', '효덕동', '송암동', '대촌동']
# 16

# %%
data[(data['시도명']==f'{검색할시도명}') & (data['시군구명']==f'{검색할시군구명}')]
# Out:
#      스마트가로등유형    시도명 시군구명         도로명  \
# 248         2  광주광역시   남구        대남대로
# 273         2  광주광역시   남구        대남대로
# 298         2  광주광역시   남구        대남대로
# 323         2  광주광역시   남구        대남대로
# 506         2  광주광역시   남구        대남대로
# 531         2  광주광역시   남구        대남대로
# 556         2  광주광역시   남구        대남대로
# 581         2  광주광역시   남구        대남대로
# 606         2  광주광역시   남구        대남대로
# 631         2  광주광역시   남구        대남대로
# 656         2  광주광역시   남구        대남대로
# 681         2  광주광역시   남구       난지실1길
# 706         2  광주광역시   남구         금당로
# 731         2  광주광역시   남구         군분로
# 761         2  광주광역시   남구    중앙로107번길
# 2028        2  광주광역시   남구        서문대로
# 2058        2  광주광역시   남구         용대로
# 2059        2  광주광역시   남구        서문대로
# 2060        2  광주광역시   남구        서문대로
# 2061        2  광주광역시   남구        서문대로
# 2062        2  광주광역시   남구        서문대로
# 2063        2  광주광역시   남구        서문대로
# 2064        2  광주광역시   남구        서문대로
# ...

# %%
data = pd.read_csv('Dataset/광주스마트가로등표준데이터.csv',encoding='cp949')
# data = pd.read_csv('Dataset/부산스마트가로등표준데이터.csv')
data.isnull().sum()

data.columns

data['시도명'].unique()

data['시도명'] = data['시도명'].replace('14','전라남도')

data[data['시도명']==검색할시도명]['시군구명'].unique()

data1 = data[data['시도명']==검색할시도명]
detail_1 = data1[data1['시군구명']==검색할시군구명]


detail_1['읍/면/동'] = detail_1['소재지지번주소'].apply(lambda x : dong(x))

detail_1['설치유무'] = 1

get_col = ['시도명','시군구명','소재지지번주소','읍/면/동','설치유무']
detail_1 = detail_1[get_col]


u2 = detail_1['읍/면/동'].unique().tolist()
us = pd.Series(u1)

detail = pd.DataFrame(us)
detail['설치유무'] = np.nan
detail['시도명'] = data[data['시도명']==검색할시도명]['시도명'].unique()[0]
detail['시군구명'] = data[data['시군구명']==검색할시군구명]['시군구명'].unique()[0]

def 설치유무(x):
    y = ''
    for i in u2 :
        if x == i :
            y = 1
    return y


detail['설치유무'].update(detail[0].apply(설치유무))
detail['설치유무'] = detail['설치유무'].replace("",0)
detail = detail.rename(columns={0:'읍/면/동'})

detail = detail[['시도명','시군구명','읍/면/동','설치유무']]
display(detail)
len(detail)
# Out:
#       시도명 시군구명 읍/면/동  설치유무
# 0   광주광역시   남구   양림동     0
# 1   광주광역시   남구  방림1동     0
# 2   광주광역시   남구  방림2동     0
# 3   광주광역시   남구  봉선1동     0
# 4   광주광역시   남구  봉선2동     0
# 5   광주광역시   남구   사직동     1
# 6   광주광역시   남구   월산동     0
# 7   광주광역시   남구  월산4동     0
# 8   광주광역시   남구  월산5동     0
# 9   광주광역시   남구  백운1동     0
# 10  광주광역시   남구  백운2동     0
# 11  광주광역시   남구  주월1동     0
# 12  광주광역시   남구  주월2동     0
# 13  광주광역시   남구   효덕동     1
# 14  광주광역시   남구   송암동     0
# 15  광주광역시   남구   대촌동     1
# 16

# %%
# real = detail_1[(detail_1['시도명']==f'{검색할시도명}') & (detail_1['시군구명']==f'{검색할시군구명}')][['읍/면/동']]

# %%
detail_1[(detail_1['시도명']==f'{검색할시도명}') & (detail_1['시군구명']==f'{검색할시군구명}')]['읍/면/동'].unique()
# Out:
# array(['사직동', '효덕동', '대촌동'], dtype=object)

# %%
print(np.array(u1))
# Out:
# ['양림동' '방림1동' '방림2동' '봉선1동' '봉선2동' '사직동' '월산동' '월산4동' '월산5동' '백운1동' '백운2동'
#  '주월1동' '주월2동' '효덕동' '송암동' '대촌동']

# %%
detail[(detail['시도명'] == '광주광역시')&(detail['시군구명']=='남구')]
# Out:
#       시도명 시군구명 읍/면/동  설치유무
# 0   광주광역시   남구   양림동     0
# 1   광주광역시   남구  방림1동     0
# 2   광주광역시   남구  방림2동     0
# 3   광주광역시   남구  봉선1동     0
# 4   광주광역시   남구  봉선2동     0
# 5   광주광역시   남구   사직동     1
# 6   광주광역시   남구   월산동     0
# 7   광주광역시   남구  월산4동     0
# 8   광주광역시   남구  월산5동     0
# 9   광주광역시   남구  백운1동     0
# 10  광주광역시   남구  백운2동     0
# 11  광주광역시   남구  주월1동     0
# 12  광주광역시   남구  주월2동     0
# 13  광주광역시   남구   효덕동     1
# 14  광주광역시   남구   송암동     0
# 15  광주광역시   남구   대촌동     1

# %%
human = pd.read_csv(f'Dataset/인구밀도/{검색할시도명}.csv')
human = human[human['시군구명']==f'{검색할시군구명}']

# %%
display(human)
len(human)
# Out:
#       시도명 시군구명 읍/면/동  등록인구수
# 31  광주광역시   남구   양림동   7592
# 32  광주광역시   남구  방림1동   7274
# 33  광주광역시   남구  방림2동   9421
# 34  광주광역시   남구  봉선1동  15122
# 35  광주광역시   남구  봉선2동  29602
# 36  광주광역시   남구   사직동   5669
# 37  광주광역시   남구   월산동   8005
# 38  광주광역시   남구  월산4동   9225
# 39  광주광역시   남구  월산5동   6830
# 40  광주광역시   남구  백운1동  13019
# 41  광주광역시   남구  백운2동   6311
# 42  광주광역시   남구  주월1동  20184
# 43  광주광역시   남구  주월2동   8698
# 44  광주광역시   남구   효덕동  47590
# 45  광주광역시   남구   송암동  19302
# 46  광주광역시   남구   대촌동   5769
# 16

# %%
df = pd.merge(detail,human,on=['시도명','시군구명','읍/면/동'],how='left')
display(df)
df.to_csv(f'Dataset/human/{검색할시도명}{검색할시군구명}인구총수.csv',index=0)
# Out:
#       시도명 시군구명 읍/면/동  설치유무  등록인구수
# 0   광주광역시   남구   양림동     0   7592
# 1   광주광역시   남구  방림1동     0   7274
# 2   광주광역시   남구  방림2동     0   9421
# 3   광주광역시   남구  봉선1동     0  15122
# 4   광주광역시   남구  봉선2동     0  29602
# 5   광주광역시   남구   사직동     1   5669
# 6   광주광역시   남구   월산동     0   8005
# 7   광주광역시   남구  월산4동     0   9225
# 8   광주광역시   남구  월산5동     0   6830
# 9   광주광역시   남구  백운1동     0  13019
# 10  광주광역시   남구  백운2동     0   6311
# 11  광주광역시   남구  주월1동     0  20184
# 12  광주광역시   남구  주월2동     0   8698
# 13  광주광역시   남구   효덕동     1  47590
# 14  광주광역시   남구   송암동     0  19302
# 15  광주광역시   남구   대촌동     1   5769

# %% [markdown]
# # 스마트 가로등이 없는 지역

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_row', 500)
import warnings
warnings.filterwarnings('ignore')

검색할시도명 = '강원도'
검색할시군구명 = '양양군'

빼올ui = 검색할시도명
검색할구 = 검색할시군구명
PP = pd.read_csv(f'Dataset/인구밀도/{빼올ui}.csv')
um = PP[PP['시군구명']==검색할구]
u1 = um['읍/면/동'].tolist()
u1
len(u1)
# Out:
# 6

# %%
human = pd.read_csv(f'Dataset/인구밀도/{검색할시도명}.csv')
human = human[human['시군구명']==f'{검색할시군구명}']
display(human)
len(human)
# Out:
#      시도명 시군구명 읍/면/동  등록인구수
# 182  강원도  양양군   양양읍  11944
# 183  강원도  양양군    서면   3017
# 184  강원도  양양군   손양면   2485
# 185  강원도  양양군   현북면   2648
# 186  강원도  양양군   현남면   3135
# 187  강원도  양양군   강현면   4423
# 6

# %%
df = human
df['설치유무'] = 0
df = df[['시도명','시군구명','읍/면/동','설치유무','등록인구수']]
len(df)
display(df)
df.to_csv(f'Dataset/human/{검색할시도명}{검색할시군구명}인구총수.csv',index=0)
# Out:
#      시도명 시군구명 읍/면/동  설치유무  등록인구수
# 182  강원도  양양군   양양읍     0  11944
# 183  강원도  양양군    서면     0   3017
# 184  강원도  양양군   손양면     0   2485
# 185  강원도  양양군   현북면     0   2648
# 186  강원도  양양군   현남면     0   3135
# 187  강원도  양양군   강현면     0   4423

# %% [markdown]
# ### 자동화

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_row', 500)
import warnings
warnings.filterwarnings('ignore')

검색할시도명 = '서울특별시'
검색할시군구명 = '가평군'

빼올ui = 검색할시도명
검색할구 = 검색할시군구명
PP = pd.read_csv(f'Dataset/인구밀도/{빼올ui}.csv')
자동화 = (PP['시군구명'].unique()).tolist()
자동화
# Out:
# ['종로구',
#  '중구',
#  '용산구',
#  '성동구',
#  '광진구',
#  '동대문구',
#  '중랑구',
#  '성북구',
#  '강북구',
#  '도봉구',
#  '노원구',
#  '은평구',
#  '서대문구',
#  '마포구',
#  '양천구',
#  '강서구',
#  '구로구',
#  '금천구',
#  '영등포구',
#  '동작구',
#  '관악구',
#  '서초구',
#  '강남구',
#  '송파구',
#  '강동구']

# %% [markdown]
# ### 스마트폴 있는 지역 꼭 제거!

# %% [raw]
# 강원도 : 춘천 인제 강릉
# 경기도 : 가평
# 광주광역시 : 남구 광산구
# 전라남도 : 신안
# 전라북도 : 고창 무주 정읍
# 충청남도 : 아산
# 충청북도 : 진천
# 부산광역시 : 서구
# 서울 : 강서구 광진구 서대문구

# %%
자동화 =['종로구',
 '중구',
 '용산구',
 '성동구',

 '동대문구',
 '중랑구',
 '성북구',
 '강북구',
 '도봉구',
 '노원구',
 '은평구',

 '마포구',
 '양천구',

 '구로구',
 '금천구',
 '영등포구',
 '동작구',
 '관악구',
 '서초구',
 '강남구',
 '송파구',
 '강동구']

# %%
while True:
    for i in 자동화:
        u1 = (PP[PP['시군구명']== i ]['읍/면/동'].unique()).tolist()
        human = pd.read_csv(f'Dataset/인구밀도/{검색할시도명}.csv')
        human = human[human['시군구명']== i ]
        df = human
        df['설치유무'] = 0
        df = df[['시도명','시군구명','읍/면/동','설치유무','등록인구수']]
        df.to_csv(f'Dataset/human/{검색할시도명}{i}인구총수.csv',index=0)
    
    break
    
result = pd.read_csv(f'Dataset/human/{검색할시도명}{i}인구총수.csv')
display(result)
# Out:
#      시도명 시군구명 읍/면/동  설치유무  등록인구수
# 0  서울특별시  강동구   강일동     0  35778
# 1  서울특별시  강동구   상일동     0  33345
# 2  서울특별시  강동구   명일동     0  43932
# 3  서울특별시  강동구   고덕동     0  48671
# 4  서울특별시  강동구   암사동     0  69655
# 5  서울특별시  강동구   성내동     0  68993
# 6  서울특별시  강동구   둔촌동     0  26675
# 7  서울특별시  강동구   천호동     0  90081
# 8  서울특별시  강동구    길동     0  46868
