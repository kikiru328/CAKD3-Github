# %%
A = pd.read_csv('Dataset/total/찐찐찐최종.csv')

# %%
A
# Out:
#       시도명 시군구명 읍/면/동  설치유무    등록인구수  어린이보호구역개수  화재발생횟수  관광지개수    예상범죄비율
# 0     강원도  강릉시  주문진읍   1.0  17085.0        8.0     0.0    1.0  0.000258
# 1     강원도  강릉시   성산면   0.0   3393.0        3.0     0.0    1.0  0.000051
# 2     강원도  강릉시   왕산면   0.0   1648.0        2.0     0.0    0.0  0.000025
# 3     강원도  강릉시   구정면   0.0   4096.0        5.0     0.0    0.0  0.000062
# 4     강원도  강릉시   강동면   1.0   4690.0        3.0     0.0    0.0  0.000071
# ..    ...  ...   ...   ...      ...        ...     ...    ...       ...
# 638  충청북도  진천군   초평면   1.0   3508.0        4.0     0.0    0.0  0.002933
# 639  충청북도  진천군   문백면   1.0   4147.0        4.0     0.0    0.0  0.003467
# 640  충청북도  진천군   백곡면   1.0   2167.0        2.0     0.0    0.0  0.001811
# 641  충청북도  진천군   이월면   0.0   8078.0        6.0     0.0    0.0  0.006753
# 642  충청북도  진천군  광혜원면   1.0  12009.0        3.0     0.0    0.0  0.010038
#
# [643 rows x 9 columns]

# %%
A = A.drop('읍/면/동',axis=1)

# %%
grouped = A.groupby('시군구명').sum()

# %%
def make_simple(x):
    result = ''
    if x > 0 : result = 1
    else: result = 0
    return result

# %%
grouped['설치유무'] = grouped['설치유무'].apply(lambda x : make_simple(x))

# %%
grouped.to_csv('Dataset/도시시각화자료.csv')

# %%
pd.read_csv('Dataset/도시시각화자료.csv')
# Out:
#     시군구명  설치유무     등록인구수  어린이보호구역개수  화재발생횟수  관광지개수    예상범죄비율
# 0    가평군     1   32493.0       20.0     0.0    2.0  0.113854
# 1    강남구     0  544055.0       94.0   495.0    0.0  0.026026
# 2    강동구     0  463998.0      180.0   269.0    0.0  0.012820
# 3    강릉시     1  215239.0       54.0     0.0    4.0  0.003250
# 4    강북구     0  311569.0       76.0   186.0    0.0  0.008222
# 5    강서구     1  585901.0       79.0   309.0    4.0  0.019498
# 6    고성군     0   29118.0       12.0     0.0    5.0  0.002833
# 7    고창군     1   55424.0       37.0     0.0    1.0  0.007574
# 8    관악구     0  509803.0       36.0   171.0    1.0  0.018075
# 9    광산구     1  418776.0      127.0     0.0    0.0  0.065090
# 10   광진구     1  360109.0      154.0   200.0    0.0  0.009700
# 11   구로구     0  432488.0       53.0   243.0    0.0  0.013967
# 12   금천구     0  247835.0       86.0   174.0    0.0  0.005272
# 13    남구     1  219613.0       37.0     0.0    0.0  0.017349
# 14   노원구     0  527032.0      208.0   279.0    0.0  0.015074
# 15   도봉구     0  327361.0       69.0   192.0    0.0  0.004765
# 16    동구     0  100504.0       26.0     0.0    0.0  0.007716
# 17  동대문구     0  357014.0      146.0   179.0    0.0  0.009067
# 18   동작구     0  401572.0      118.0   208.0    0.0  0.009113
# 19   동해시     0   92137.0       24.0     0.0    2.0  0.000806
# 20   마포구     0  381858.0       82.0   186.0    0.0  0.011963
# 21   무주군     1   24252.0       11.0     0.0    1.0  0.001424
# 22    북구     0  438734.0      148.0     0.0    0.0  0.080633
# 23   삼척시     0   69115.0       15.0     0.0    3.0  0.002304
# 24    서구     1  415287.0       94.0     0.0   11.0  0.137475
# 25  서대문구     1  322952.0       60.0   152.0    0.0  0.006442
# 26   서초구     0  493594.0      124.0   224.0    6.0  0.017522
# 27   성동구     0  300505.0       96.0   186.0    0.0  0.005151
# 28   성북구     0  447056.0      200.0   111.0    3.0  0.008702
# 29   속초시     0   82694.0       12.0     0.0    2.0  0.001706
# 30   송파구     0  673926.0      184.0   312.0    0.0  0.026348
# 31   신안군     1   41102.0       30.0     0.0    1.0  0.033065
# 32   아산시     1  333074.0       55.0     0.0    2.0  0.105157
# 33   양구군     0   23666.0       10.0     0.0    3.0  0.001420
# 34   양양군     0   27652.0       15.0     0.0    3.0  0.000190
# 35   양천구     0  456390.0      136.0   244.0    0.0  0.010153
# 36  영등포구     0  407367.0      132.0   111.0    0.0  0.016040
# 37   영월군     0   39998.0       27.0     0.0    1.0  0.000328
# 38   용산구     0  244645.0       52.0   131.0    0.0  0.005362
# 39   원주시     0  347421.0       69.0     0.0    1.0  0.003294
# 40   은평구     0  484043.0       76.0   159.0    2.0  0.012856
# 41   인제군     1   32455.0       25.0     0.0    2.0  0.004645
# 42   정선군     0   37965.0       16.0     0.0    2.0  0.000221
# 43   정읍시     0  111239.0       33.0     0.0    0.0  0.036267
# 44   종로구     0  159032.0       42.0   102.0    0.0  0.004134
# 45    중구     0  134635.0       52.0   109.0    0.0  0.004010
# 46   중랑구     0  399562.0       84.0   196.0    4.0  0.011892
# 47   진천군     1   84265.0       36.0     0.0    0.0  0.070440
# 48   철원군     0   47138.0       26.0     0.0    2.0  0.000994
# 49   춘천시     1  285002.0       84.0     0.0    3.0  0.002413
# 50   태백시     0   45112.0        9.0     0.0    0.0  0.004883
# 51   평창군     0   43021.0       23.0     0.0    6.0  0.000773
# 52   홍천군     0   70898.0       34.0     0.0    2.0  0.000748
# 53   화천군     0   25342.0       28.0     0.0    0.0  0.000696
# 54   횡성군     0   47340.0       19.0     0.0    3.0  0.000279

# %%
import pandas as pd

# %%
pole = pd.read_csv('Dataset/서울스마트가로등(위경도채움).csv')

# %%
pole.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   스마트가로등형태    247 non-null    int64
#  1   시군구명        247 non-null    object
#  2   소재지지번주소     247 non-null    object
#  3   위도          247 non-null    float64
#  4   경도          247 non-null    float64
#  5   점등상태여부      247 non-null    object
#  6   센서종류        247 non-null    object
#  7   센싱정보서비스     247 non-null    object
#  8   CCTV유무      247 non-null    object
#  9   WiFi유무      247 non-null    object
#  10  GPS수신기유무    247 non-null    object
#  11  비콘유무        247 non-null    object
#  12  조명제어여부      247 non-null    object
#  13  위급상황신고가능여부  247 non-null    object
#  14  기타서비스       247 non-null    object
#  15  설치연도        247 non-null    int64
#  16  데이터기준일자     247 non-null    object
# dtypes: float64(2), int64(2), object(13)
# memory usage: 32.9+ KB

# %%
human = pd.read_csv('Dataset/전국인구밀도포함.csv')

# %%
human.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 643 entries, 0 to 642
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시도명     643 non-null    object
#  1   시군구명    643 non-null    object
#  2   읍/면/동   643 non-null    object
#  3   등록인구수   643 non-null    float64
#  4   인구밀도    643 non-null    float64
# dtypes: float64(2), object(3)
# memory usage: 25.2+ KB

# %%
grouped = pole.groupby('시군구명').count()
grouped
# Out:
#       스마트가로등형태  소재지지번주소   위도   경도  점등상태여부  센서종류  센싱정보서비스  CCTV유무  WiFi유무  \
# 시군구명
# 강서구        126      126  126  126     126   126      126     126     126
# 광진구        117      117  117  117     117   117      117     117     117
# 서대문구         4        4    4    4       4     4        4       4       4
#
#       GPS수신기유무  비콘유무  조명제어여부  위급상황신고가능여부  기타서비스  설치연도  데이터기준일자
# 시군구명
# 강서구        126   126     126         126    126   126      126
# 광진구        117   117     117         117    117   117      117
# 서대문구         4     4       4           4      4     4        4

# %%
grouped_h = human.groupby('시군구명').count()

# %%
grouped_h = grouped_h.reset_index()

# %%
grouped_h = grouped_h[['시군구명']]

# %%
grouped
# Out:
#       스마트가로등형태  소재지지번주소   위도   경도  점등상태여부  센서종류  센싱정보서비스  CCTV유무  WiFi유무  \
# 시군구명
# 강서구        126      126  126  126     126   126      126     126     126
# 광진구        117      117  117  117     117   117      117     117     117
# 서대문구         4        4    4    4       4     4        4       4       4
#
#       GPS수신기유무  비콘유무  조명제어여부  위급상황신고가능여부  기타서비스  설치연도  데이터기준일자
# 시군구명
# 강서구        126   126     126         126    126   126      126
# 광진구        117   117     117         117    117   117      117
# 서대문구         4     4       4           4      4     4        4

# %%
pole1 = pd.read_csv('Dataset/전국스마트가로등표준데이터.csv',encoding='cp949')

# %%
pole1 = pole[['시도명','시군구명',]]
# Out:
#      스마트가로등유형    시도명 시군구명        도로명  \
# 0           1   충청남도  홍성군      남부순환로
# 1           1   충청남도  홍성군      남부순환로
# 2           1   충청남도  홍성군      남부순환로
# 3           1   충청남도  홍성군      남부순환로
# 4           1   충청남도  홍성군       홍장북로
# ...       ...    ...  ...        ...
# 3243        2  광주광역시   남구    진다리로6번길
# 3244        2  광주광역시   남구  천변좌로338번길
# 3245        2  광주광역시   남구       천변좌로
# 3246        2  광주광역시   남구       천변좌로
# 3247        2  광주광역시   남구       천변좌로
#
#                                            소재지도로명주소                  소재지지번주소  \
# 0                                               NaN   충청남도 홍성군 홍성읍 옥암리 872-2
# 1                                               NaN   충청남도 홍성군 홍성읍 옥암리 872-2
# 2                                               NaN   충청남도 홍성군 홍성읍 옥암리 872-2
# 3                                               NaN   충청남도 홍성군 홍성읍 옥암리 872-2
# 4                                               NaN  충청남도 홍성군 홍성읍 남장리 102-17
# ...                                             ...                      ...
# 3243                광주광역시 남구 진다리로 6번길 6 (해피니스 원룸 옆)                      NaN
# 3244  광주광역시 남구 천변좌로 338번길 7 (빛고을시민문화관 앞 광주공원 버스정류장)                      NaN
# 3245                    광주광역시 남구 천변좌로 368 (서현동물병원앞)                      NaN
# 3246                   광주광역시 남구 천변좌로 370 (서현동물병원 앞)                      NaN
# 3247                  광주광역시 남구 천변좌로 380 (최재훈웨딩 맞은편)                      NaN
#
#              위도          경도  스마트가로등형태 점등상태여부  ... 위급상황신고가능여부 앱서비스명 앱서비스제공내용  \
# 0     36.599743  126.663126         1      Y  ...          N   NaN      NaN
# 1     36.599327  126.662999         1      Y  ...          N   NaN      NaN
# 2     36.598884  126.662850         1      Y  ...          N   NaN      NaN
# 3     36.594208  126.668597         1      Y  ...          N   NaN      NaN
# 4     36.592903  126.668765         1      Y  ...          N   NaN      NaN
# ...         ...         ...       ...    ...  ...        ...   ...      ...
# 3243  35.136540  126.902082         1      Y  ...          Y   NaN      NaN
# 3244  35.147906  126.907897         1      Y  ...          Y   NaN      NaN
# 3245  35.145789  126.912079         1      Y  ...          Y   NaN      NaN
# 3246  35.145657  126.912158         1      Y  ...          Y   NaN      NaN
# 3247  35.144858  126.912735         1      Y  ...          Y   NaN      NaN
#
#      기타서비스    설치연도      관리기관명      관리기관전화번호     데이터기준일자   제공기관코드     제공기관명
# 0      NaN     NaN        홍성군  041-630-1582  2020-07-07  4600000  충청남도 홍성군
# 1      NaN     NaN        홍성군  041-630-1582  2020-07-07  4600000  충청남도 홍성군
# 2      NaN     NaN        홍성군  041-630-1582  2020-07-07  4600000  충청남도 홍성군
# 3      NaN     NaN        홍성군  041-630-1582  2020-07-07  4600000  충청남도 홍성군
# 4      NaN     NaN        홍성군  041-630-1582  2020-07-07  4600000  충청남도 홍성군
# ...    ...     ...        ...           ...         ...      ...       ...
# 3243   NaN  2015.0  광주광역시 남구청  062-607-3832  2020-09-25  3610000  광주광역시 남구
# 3244   NaN  2015.0  광주광역시 남구청  062-607-3832  2020-09-25  3610000  광주광역시 남구
# 3245   NaN  2015.0  광주광역시 남구청  062-607-3832  2020-09-25  3610000  광주광역시 남구
# 3246   NaN  2015.0  광주광역시 남구청  062-607-3832  2020-09-25  3610000  광주광역시 남구
# 3247   NaN  2015.0  광주광역시 남구청  062-607-3832  2020-09-25  3610000  광주광역시 남구
#
# [3248 rows x 27 columns]

# %%
data = pd.read_csv('Dataset/전국스마트가로등표준데이터.csv',encoding='cp949')
# data = pd.read_csv('Dataset/부산스마트가로등표준데이터.csv')
data.isnull().sum()

data.columns

data['시도명'].unique()

data['시도명'] = data['시도명'].replace('14','전라남도')

data[data['시도명']==검색할시도명]['시군구명'].unique()

data1 = data[data['시도명']==검색할시도명]
detail_1 = data1[data1['시군구명']==검색할시군구명]


detail_1['읍/면/동'] = detail_1['소재지지번주소'].apply(lambda x : dong(x))

detail_1['설치유무'] = 1

get_col = ['시도명','시군구명','소재지지번주소','읍/면/동','설치유무']
detail_1 = detail_1[get_col]


u2 = detail_1['읍/면/동'].unique().tolist()
us = pd.Series(u1)

detail = pd.DataFrame(us)
detail['설치유무'] = np.nan
detail['시도명'] = data[data['시도명']==검색할시도명]['시도명'].unique()[0]
detail['시군구명'] = data[data['시군구명']==검색할시군구명]['시군구명'].unique()[0]

def 설치유무(x):
    y = ''
    for i in u2 :
        if x == i :
            y = 1
    return y


detail['설치유무'].update(detail[0].apply(설치유무))
detail['설치유무'] = detail['설치유무'].replace("",0)
detail = detail.rename(columns={0:'읍/면/동'})

detail = detail[['시도명','시군구명','읍/면/동','설치유무']]
display(detail)
len(detail)
