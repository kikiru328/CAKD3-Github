# %%
import os
import pandas as pd
pd.set_option('display.max_row', 1900)
path = 'Dataset/pole'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.csv')]
df = pd.DataFrame()
for i in file_list_py:
    data = pd.read_csv(path + '/'+ i,index_col=0)
    df = pd.concat([df,data])

# %%
df.to_csv('Dataset/스마트폴설치가로등위경도.csv')

# %%
tour = df.copy()

# %%
tour
# Out:
#        시군구명     읍/면/동     등록인구수      인구밀도  관광지개수
# 시도명
# 강원도     강릉시      주문진읍   17085.0  0.010943    1.0
# 강원도     강릉시       성산면    3393.0  0.002173    1.0
# 강원도     강릉시       왕산면    1648.0  0.001056    NaN
# 강원도     강릉시       구정면    4096.0  0.002623    NaN
# 강원도     강릉시       강동면    4690.0  0.003004    NaN
# 강원도     강릉시       옥계면    3857.0  0.002470    1.0
# 강원도     강릉시       사천면    4601.0  0.002947    NaN
# 강원도     강릉시       연곡면    6871.0  0.004401    1.0
# 강원도     강릉시       홍제동   14729.0  0.009434    NaN
# 강원도     강릉시       중앙동    5425.0  0.003475    NaN
# 강원도     강릉시       옥천동    3694.0  0.002366    NaN
# 강원도     강릉시       교1동   27236.0  0.017444    NaN
# 강원도     강릉시       교2동    8284.0  0.005306    NaN
# 강원도     강릉시      포남1동   11184.0  0.007163    NaN
# 강원도     강릉시      포남2동   14191.0  0.009089    NaN
# 강원도     강릉시       초당동    5146.0  0.003296    NaN
# 강원도     강릉시       송정동    7093.0  0.004543    NaN
# 강원도     강릉시       내곡동   16059.0  0.010286    NaN
# ...

# %%
Last2 = pd.read_csv('Dataset/total/진짜최종_1.csv')

# %%
tour.head(1)
# Out:
#     시군구명 읍/면/동    등록인구수      인구밀도  관광지개수
# 시도명
# 강원도  강릉시  주문진읍  17085.0  0.010943    1.0

# %%
tour=tour.drop('인구밀도',axis=1)

# %%
Last2
# Out:
#        시도명  시군구명     읍/면/동  설치유무     등록인구수  어린이보호구역개수  화재발생횟수  인구밀도  범죄총계(구)  \
# 0      강원도   강릉시      주문진읍   1.0   17085.0        8.0     0.0  0.01    328.0
# 1      강원도   강릉시       성산면   0.0    3393.0        3.0     0.0  0.00    328.0
# 2      강원도   강릉시       왕산면   0.0    1648.0        2.0     0.0  0.00    328.0
# 3      강원도   강릉시       구정면   0.0    4096.0        5.0     0.0  0.00    328.0
# 4      강원도   강릉시       강동면   1.0    4690.0        3.0     0.0  0.00    328.0
# 5      강원도   강릉시       옥계면   0.0    3857.0        4.0     0.0  0.00    328.0
# 6      강원도   강릉시       사천면   0.0    4601.0        3.0     0.0  0.00    328.0
# 7      강원도   강릉시       연곡면   0.0    6871.0        3.0     0.0  0.00    328.0
# 8      강원도   강릉시       홍제동   0.0   14729.0        2.0     0.0  0.01    328.0
# 9      강원도   강릉시       중앙동   0.0    5425.0        0.0     0.0  0.00    328.0
# 10     강원도   강릉시       옥천동   0.0    3694.0        2.0     0.0  0.00    328.0
# ...

# %%
X = pd.merge(Last2,tour,on=['시도명','시군구명','읍/면/동','등록인구수'],how='left')

# %%
X
# Out:
#        시도명  시군구명     읍/면/동  설치유무     등록인구수  어린이보호구역개수  화재발생횟수  인구밀도  범죄총계(구)  \
# 0      강원도   강릉시      주문진읍   1.0   17085.0        8.0     0.0  0.01    328.0
# 1      강원도   강릉시       성산면   0.0    3393.0        3.0     0.0  0.00    328.0
# 2      강원도   강릉시       왕산면   0.0    1648.0        2.0     0.0  0.00    328.0
# 3      강원도   강릉시       구정면   0.0    4096.0        5.0     0.0  0.00    328.0
# 4      강원도   강릉시       강동면   1.0    4690.0        3.0     0.0  0.00    328.0
# 5      강원도   강릉시       옥계면   0.0    3857.0        4.0     0.0  0.00    328.0
# 6      강원도   강릉시       사천면   0.0    4601.0        3.0     0.0  0.00    328.0
# 7      강원도   강릉시       연곡면   0.0    6871.0        3.0     0.0  0.00    328.0
# 8      강원도   강릉시       홍제동   0.0   14729.0        2.0     0.0  0.01    328.0
# 9      강원도   강릉시       중앙동   0.0    5425.0        0.0     0.0  0.00    328.0
# 10     강원도   강릉시       옥천동   0.0    3694.0        2.0     0.0  0.00    328.0
# ...

# %%
X = pd.merge(Last2,tour,on=['시도명','시군구명','읍/면/동','등록인구수'],how='left')

# %%
X = X.fillna(0)

# %%
X['관광지개수'].sum()
# Out:
# 82.0

# %%
X
# Out:
#        시도명  시군구명     읍/면/동  설치유무     등록인구수  어린이보호구역개수  화재발생횟수  인구밀도  범죄총계(구)  \
# 0      강원도   강릉시      주문진읍   1.0   17085.0        8.0     0.0  0.01    328.0
# 1      강원도   강릉시       성산면   0.0    3393.0        3.0     0.0  0.00    328.0
# 2      강원도   강릉시       왕산면   0.0    1648.0        2.0     0.0  0.00    328.0
# 3      강원도   강릉시       구정면   0.0    4096.0        5.0     0.0  0.00    328.0
# 4      강원도   강릉시       강동면   1.0    4690.0        3.0     0.0  0.00    328.0
# 5      강원도   강릉시       옥계면   0.0    3857.0        4.0     0.0  0.00    328.0
# 6      강원도   강릉시       사천면   0.0    4601.0        3.0     0.0  0.00    328.0
# 7      강원도   강릉시       연곡면   0.0    6871.0        3.0     0.0  0.00    328.0
# 8      강원도   강릉시       홍제동   0.0   14729.0        2.0     0.0  0.01    328.0
# 9      강원도   강릉시       중앙동   0.0    5425.0        0.0     0.0  0.00    328.0
# 10     강원도   강릉시       옥천동   0.0    3694.0        2.0     0.0  0.00    328.0
# ...

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 643 entries, 0 to 642
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   시도명        643 non-null    object
#  1   시군구명       643 non-null    object
#  2   읍/면/동      643 non-null    object
#  3   설치유무       643 non-null    float64
#  4   등록인구수      643 non-null    float64
#  5   어린이보호구역개수  643 non-null    float64
#  6   화재발생횟수     643 non-null    float64
#  7   인구밀도       643 non-null    float64
#  8   범죄총계(구)    643 non-null    float64
#  9   범죄발생비율     643 non-null    float64
#  10  관광지개수      643 non-null    float64
# dtypes: float64(8), object(3)
# memory usage: 60.3+ KB

# %%
X.to_csv('Dataset/total/찐최종.csv',index=0)

# %%
pd.read_csv('Dataset/total/찐최종.csv').head(5)
# Out:
#    시도명 시군구명 읍/면/동  설치유무    등록인구수  어린이보호구역개수  화재발생횟수  인구밀도  범죄총계(구)  범죄발생비율  \
# 0  강원도  강릉시  주문진읍   1.0  17085.0        8.0     0.0  0.01    328.0    3.59
# 1  강원도  강릉시   성산면   0.0   3393.0        3.0     0.0  0.00    328.0    0.71
# 2  강원도  강릉시   왕산면   0.0   1648.0        2.0     0.0  0.00    328.0    0.35
# 3  강원도  강릉시   구정면   0.0   4096.0        5.0     0.0  0.00    328.0    0.86
# 4  강원도  강릉시   강동면   1.0   4690.0        3.0     0.0  0.00    328.0    0.99
#
#    관광지개수
# 0    1.0
# 1    1.0
# 2    0.0
# 3    0.0
# 4    0.0

# %%
pole = pd.read_csv('Dataset/total/스마트폴_인구총합.csv')

# %%
pole.head(1)
# Out:
#    시도명 시군구명 읍/면/동  설치유무  등록인구수
# 0  강원도  강릉시  주문진읍   1.0  17085

# %%
child = pd.read_csv('Dataset/total/어린이보호구역.csv')

# %%
child
# Out:
#        시도명  시군구명     읍/면/동     등록인구수  어린이보호구역개수
# 0      강원도   강릉시       강남동   19111.0        0.0
# 1      강원도   강릉시       강동면    4690.0        3.0
# 2      강원도   강릉시       경포동    7746.0        0.0
# 3      강원도   강릉시       교1동   27236.0        3.0
# 4      강원도   강릉시       교2동    8284.0        4.0
# 5      강원도   강릉시       구정면    4096.0        5.0
# 6      강원도   강릉시       내곡동   16059.0        2.0
# 7      강원도   강릉시       사천면    4601.0        3.0
# 8      강원도   강릉시       성덕동   29100.0        0.0
# 9      강원도   강릉시       성산면    3393.0        3.0
# 10     강원도   강릉시       송정동    7093.0        2.0
# 11     강원도   강릉시       연곡면    6871.0        3.0
# 12     강원도   강릉시       옥계면    3857.0        4.0
# 13     강원도   강릉시       옥천동    3694.0        2.0
# 14     강원도   강릉시       왕산면    1648.0        2.0
# 15     강원도   강릉시      주문진읍   17085.0        8.0
# 16     강원도   강릉시       중앙동    5425.0        0.0
# 17     강원도   강릉시       초당동    5146.0        1.0
# 18     강원도   강릉시      포남1동   11184.0        3.0
# ...

# %%
# child = child.reset_index(drop=True)
child = child.drop('Unnamed: 0',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-284-7fc896a57394> in <module>
#       1 # child = child.reset_index(drop=True)
# ----> 2 child = child.drop('Unnamed: 0',axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
child = child.drop('인구밀도',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-285-33dc7d8acd4b> in <module>
# ----> 1 child = child.drop('인구밀도',axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
child.head(1)
# Out:
#    시도명 시군구명 읍/면/동    등록인구수  어린이보호구역개수
# 0  강원도  강릉시   강남동  19111.0        0.0

# %%
tour['등록인구수']
# Out:
# 0       17085.0
# 1        3393.0
# 2        1648.0
# 3        4096.0
# 4        4690.0
# 5        3857.0
# 6        4601.0
# 7        6871.0
# 8       14729.0
# 9        5425.0
# 10       3694.0
# 11      27236.0
# 12       8284.0
# 13      11184.0
# 14      14191.0
# 15       5146.0
# 16       7093.0
# 17      16059.0
# 18      19111.0
# 19      29100.0
# 20       7746.0
# 21       7408.0
# 22       6911.0
# 23       2528.0
# 24       4004.0
# 25       8267.0
# 26      30768.0
# 27       4575.0
# 28      20554.0
# 29       5691.0
# 30       4982.0
# 31       4019.0
# 32       3668.0
# 33      10651.0
# 34       4035.0
# 35       3194.0
# 36      11507.0
# 37       5412.0
# 38       5565.0
# 39       1366.0
# 40        723.0
# 41       1947.0
# 42        735.0
# 43        674.0
# 44       8142.0
# 45      14802.0
# 46       9616.0
# 47       8626.0
# 48       5026.0
# 49       4312.0
# 50       6862.0
# 51      10357.0
# 52      22790.0
# 53      25042.0
# 54       4879.0
# ...

# %%
tour['등록인구수'] = tour['등록인구수'].apply(lambda x : dollar_to_float(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-a2422e488af6> in <module>
# ----> 1 tour['등록인구수'] = tour['등록인구수'].apply(lambda x : dollar_to_float(x))
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-22-a2422e488af6> in <lambda>(x)
# ----> 1 tour['등록인구수'] = tour['등록인구수'].apply(lambda x : dollar_to_float(x))
#
# <ipython-input-20-738c0897c87c> in dollar_to_float(x)
#       1 import re
#       2 def dollar_to_float(x):
# ----> 3     new=re.sub(',',"",x)
#       4     new=float(new)
# ...

# %%
import re
def dollar_to_float(x):
    new=re.sub(',',"",x)
    new=float(new)
    return new

# %%
tour['등록인구수'] = tour['등록인구수'].agg(dollar_to_float)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\series.py in aggregate(self, func, axis, *args, **kwargs)
#    3990             try:
# -> 3991                 result = self.apply(func, *args, **kwargs)
#    3992             except (ValueError, AttributeError, TypeError):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-92-738c0897c87c> in dollar_to_float(x)
#       2 def dollar_to_float(x):
# ----> 3     new=re.sub(',',"",x)
#       4     new=float(new)
#
# ~\anaconda3\lib\re.py in sub(pattern, repl, string, count, flags)
# ...

# %%
tour.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 643 entries, 강원도 to 충청북도
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시군구명    643 non-null    object
#  1   읍/면/동   643 non-null    object
#  2   등록인구수   643 non-null    float64
#  3   인구밀도    643 non-null    float64
#  4   관광지개수   58 non-null     float64
# dtypes: float64(3), object(2)
# memory usage: 46.3+ KB

# %%
A = pd.merge(pole,child,on=['시도명','시군구명','읍/면/동','등록인구수'],how='outer')

# %%
A.head(1)
# Out:
#    시도명 시군구명 읍/면/동  설치유무    등록인구수  어린이보호구역개수
# 0  강원도  강릉시  주문진읍   1.0  17085.0        8.0

# %%
B = pd.read_csv('Dataset/total/어보제외범죄통합본.csv')

# %%
B.head(1)
# Out:
#    시도명 시군구명 읍/면/동  설치유무    등록인구수  화재발생횟수  인구밀도  범죄총계(구)  범죄발생비율
# 0  강원도  강릉시   강남동   0.0  19111.0     0.0  0.01    328.0    4.01

# %%
tour = tour.reset_index()
tour.columns
# Out:
# Index(['시도명', '시군구명', '읍/면/동', '등록인구수', '인구밀도', '관광지개수'], dtype='object')

# %%
# C = pd.merge(A,B,on=['시도명','시군구명','읍/면/동','등록인구수','설치유무'],how='outer')

# %%
D = pd.merge(C,tour,on=(['시도명','시군구명','읍/면/동','등록인구수','인구밀도']),how='left')

# %%
C.to_csv('Dataset/total/진짜통합.csv',index=0)

# %%
Total = pd.read_csv('Dataset/total/진짜통합.csv')

# %%
Total.sort_values('화재발생횟수',ascending=False)
# Out:
#        시도명  시군구명     읍/면/동  설치유무     등록인구수  어린이보호구역개수  화재발생횟수  인구밀도  범죄총계(구)  \
# 351  서울특별시   관악구       신림동   0.0   22667.0       34.0   152.0  0.00   4920.0
# 334  서울특별시   강서구       화곡동   0.0  201246.0       33.0   141.0  0.02   4618.0
# 306  서울특별시   강남구       역삼동   0.0   74062.0        6.0   121.0  0.01   6638.0
# 383  서울특별시   노원구       상계동   0.0  207334.0       80.0   116.0  0.02   3969.0
# 369  서울특별시   구로구       구로동   0.0  137774.0       16.0   114.0  0.01   4481.0
# 475  서울특별시   양천구       신월동   0.0  125465.0       46.0    93.0  0.01   3087.0
# 476  서울특별시   양천구       신정동   0.0  177372.0       50.0    86.0  0.02   3087.0
# 303  서울특별시   강남구       논현동   0.0   45731.0        7.0    77.0  0.00   6638.0
# 377  서울특별시   금천구       독산동   0.0  110856.0       40.0    75.0  0.01   2952.0
# 560  서울특별시   중랑구       면목동   0.0  143278.0       28.0    72.0  0.01   4130.0
# 427  서울특별시   서초구       서초동   0.0  171512.0       32.0    72.0  0.02   4926.0
# ...

# %%
Total = Total.fillna(0)

# %%
Total.to_csv('Dataset/total/진짜최종_1.csv',index=0)

# %%
Total = pd.read_csv('Dataset/total/진짜최종_1.csv')

# %%
Total.columns
# Out:
# Index(['시도명', '시군구명', '읍/면/동', '설치유무', '등록인구수', '어린이보호구역개수', '화재발생횟수', '인구밀도',
#        '범죄총계(구)', '범죄발생비율'],
#       dtype='object')

# %%
Total['설치유무'] = Total['설치유무'].astype(float)

# %%
Total['등록인구수']=Total['등록인구수'].astype(float)

# %%
Total['어린이보호구역개수']=Total['어린이보호구역개수'].astype(float)

# %%
Total['화재발생횟수']=Total['화재발생횟수'].astype(float)

# %%
Total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 643 entries, 0 to 642
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   시도명        643 non-null    object
#  1   시군구명       643 non-null    object
#  2   읍/면/동      643 non-null    object
#  3   설치유무       643 non-null    int32
#  4   등록인구수      643 non-null    int32
#  5   어린이보호구역개수  643 non-null    int32
#  6   화재발생횟수     643 non-null    int32
#  7   인구밀도       643 non-null    float64
#  8   범죄총계(구)    643 non-null    float64
#  9   범죄발생비율     643 non-null    float64
# dtypes: float64(3), int32(4), object(3)
# memory usage: 40.3+ KB

# %%
Total.to_csv('Dataset/total/진짜최종_2.csv',index=0)

# %%
Total = pd.read_csv('Dataset/total/진짜최종_2.csv')

# %%
Total.head(1)
# Out:
#    시도명 시군구명 읍/면/동  설치유무    등록인구수  어린이보호구역개수  화재발생횟수  인구밀도  범죄총계(구)  범죄발생비율
# 0  강원도  강릉시  주문진읍   1.0  17085.0        8.0     0.0  0.01    328.0    3.59

# %%
tour = df

# %%
tour = tour.reset_index(drop=False)

# %%
tour.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 656 entries, 0 to 655
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시도명     656 non-null    object
#  1   시군구명    656 non-null    object
#  2   읍/면/동   656 non-null    object
#  3   등록인구수   656 non-null    float64
#  4   인구밀도    656 non-null    float64
#  5   관광지개수   58 non-null     float64
# dtypes: float64(3), object(3)
# memory usage: 30.9+ KB

# %%
Total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 643 entries, 0 to 642
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   시도명        643 non-null    object
#  1   시군구명       643 non-null    object
#  2   읍/면/동      643 non-null    object
#  3   설치유무       643 non-null    float64
#  4   등록인구수      643 non-null    float64
#  5   어린이보호구역개수  643 non-null    float64
#  6   화재발생횟수     643 non-null    float64
#  7   인구밀도       643 non-null    float64
#  8   범죄총계(구)    643 non-null    float64
#  9   범죄발생비율     643 non-null    float64
# dtypes: float64(7), object(3)
# memory usage: 50.4+ KB

# %%
tour.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 656 entries, 0 to 655
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시도명     656 non-null    object
#  1   시군구명    656 non-null    object
#  2   읍/면/동   656 non-null    object
#  3   등록인구수   656 non-null    float64
#  4   인구밀도    656 non-null    float64
#  5   관광지개수   58 non-null     float64
# dtypes: float64(3), object(3)
# memory usage: 30.9+ KB

# %%
import re
def dollar_to_float(x):
    new=re.sub(',',"",x)
    new=float(new)
    return new

# %%
D = pd.merge(Total,tour,on=(['시도명','시군구명','읍/면/동','등록인구수','인구밀도']),how='left')

# %%
Total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 643 entries, 0 to 642
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   시도명        643 non-null    object
#  1   시군구명       643 non-null    object
#  2   읍/면/동      643 non-null    object
#  3   설치유무       643 non-null    float64
#  4   등록인구수      643 non-null    float64
#  5   어린이보호구역개수  643 non-null    float64
#  6   화재발생횟수     643 non-null    float64
#  7   인구밀도       643 non-null    float64
#  8   범죄총계(구)    643 non-null    float64
#  9   범죄발생비율     643 non-null    float64
# dtypes: float64(7), object(3)
# memory usage: 50.4+ KB

# %%
D.isnull().sum()
# Out:
# 시도명            0
# 시군구명           0
# 읍/면/동          0
# 설치유무           0
# 등록인구수          0
# 어린이보호구역개수      0
# 화재발생횟수         0
# 인구밀도           0
# 범죄총계(구)        0
# 범죄발생비율         0
# 관광지개수        643
# dtype: int64

# %%
Total = Total.rename({'범죄발생비율':'예상범죄횟수'},axis=1)
Total
# Out:
#        시도명  시군구명     읍/면/동  설치유무   등록인구수  어린이보호구역개수  화재발생횟수  인구밀도  범죄총계(구)  \
# 0      강원도   강릉시      주문진읍     1   17085          8       0  0.01    328.0
# 1      강원도   강릉시       성산면     0    3393          3       0  0.00    328.0
# 2      강원도   강릉시       왕산면     0    1648          2       0  0.00    328.0
# 3      강원도   강릉시       구정면     0    4096          5       0  0.00    328.0
# 4      강원도   강릉시       강동면     1    4690          3       0  0.00    328.0
# 5      강원도   강릉시       옥계면     0    3857          4       0  0.00    328.0
# 6      강원도   강릉시       사천면     0    4601          3       0  0.00    328.0
# 7      강원도   강릉시       연곡면     0    6871          3       0  0.00    328.0
# 8      강원도   강릉시       홍제동     0   14729          2       0  0.01    328.0
# 9      강원도   강릉시       중앙동     0    5425          0       0  0.00    328.0
# 10     강원도   강릉시       옥천동     0    3694          2       0  0.00    328.0
# ...

# %%
Total = Total.drop('인구밀도',axis=1)

# %%
Total
# Out:
#        시도명  시군구명     읍/면/동  설치유무   등록인구수  어린이보호구역개수  화재발생횟수  범죄총계(구)  예상범죄횟수
# 0      강원도   강릉시      주문진읍     1   17085          8       0    328.0    3.59
# 1      강원도   강릉시       성산면     0    3393          3       0    328.0    0.71
# 2      강원도   강릉시       왕산면     0    1648          2       0    328.0    0.35
# 3      강원도   강릉시       구정면     0    4096          5       0    328.0    0.86
# 4      강원도   강릉시       강동면     1    4690          3       0    328.0    0.99
# 5      강원도   강릉시       옥계면     0    3857          4       0    328.0    0.81
# 6      강원도   강릉시       사천면     0    4601          3       0    328.0    0.97
# 7      강원도   강릉시       연곡면     0    6871          3       0    328.0    1.44
# 8      강원도   강릉시       홍제동     0   14729          2       0    328.0    3.09
# 9      강원도   강릉시       중앙동     0    5425          0       0    328.0    1.14
# 10     강원도   강릉시       옥천동     0    3694          2       0    328.0    0.78
# ...

# %%
Total = Total.drop('범죄총계(구)',axis=1)

# %%
Total['전국범죄총계'] = Total['예상범죄횟수'].sum()

# %%
Total['예상범죄비율'] = Total['예상범죄횟수'] / Total['전국범죄총계']

# %%
Total = Total.drop(['전국범죄총계'],axis=1)

# %%
Total.head(1)
# Out:
#    시도명 시군구명 읍/면/동  설치유무  등록인구수  어린이보호구역개수  화재발생횟수  예상범죄횟수    예상범죄비율
# 0  강원도  강릉시  주문진읍     1  17085          8       0    3.59  0.000258

# %%
Total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 643 entries, 0 to 642
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   시도명        643 non-null    object
#  1   시군구명       643 non-null    object
#  2   읍/면/동      643 non-null    object
#  3   설치유무       643 non-null    int64
#  4   등록인구수      643 non-null    int64
#  5   어린이보호구역개수  643 non-null    int64
#  6   화재발생횟수     643 non-null    int64
#  7   예상범죄횟수     643 non-null    float64
#  8   예상범죄비율     643 non-null    float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 45.3+ KB

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
features=[['등록인구수','어린이보호구역개수','화재발생횟수']]
for feature in features:
    Total[feature] = scaler.fit_transform(Total[feature])
Total.head(2)
# Out:
#    시도명 시군구명 읍/면/동  설치유무     등록인구수  어린이보호구역개수  화재발생횟수  예상범죄횟수    예상범죄비율
# 0  강원도  강릉시  주문진읍   1.0  0.081903     0.1000     0.0    3.59  0.000258
# 1  강원도  강릉시   성산면   0.0  0.015829     0.0375     0.0    0.71  0.000051

# %%
Total = Total.drop('예상범죄횟수',axis=1)

# %%
Total.to_csv('Dataset/Acc/정규화완료.csv',index=0)

# %%
Total = pd.read_csv('Dataset/Acc/정규화완료.csv')

# %%
Total
# Out:
#        시도명  시군구명     읍/면/동  설치유무     등록인구수  어린이보호구역개수    화재발생횟수    예상범죄비율
# 0      강원도   강릉시      주문진읍   1.0  0.081903     0.1000  0.000000  0.000258
# 1      강원도   강릉시       성산면   0.0  0.015829     0.0375  0.000000  0.000051
# 2      강원도   강릉시       왕산면   0.0  0.007408     0.0250  0.000000  0.000025
# 3      강원도   강릉시       구정면   0.0  0.019221     0.0625  0.000000  0.000062
# 4      강원도   강릉시       강동면   1.0  0.022088     0.0375  0.000000  0.000071
# 5      강원도   강릉시       옥계면   0.0  0.018068     0.0500  0.000000  0.000058
# 6      강원도   강릉시       사천면   0.0  0.021658     0.0375  0.000000  0.000070
# 7      강원도   강릉시       연곡면   0.0  0.032613     0.0375  0.000000  0.000104
# 8      강원도   강릉시       홍제동   0.0  0.070533     0.0250  0.000000  0.000222
# 9      강원도   강릉시       중앙동   0.0  0.025634     0.0000  0.000000  0.000082
# 10     강원도   강릉시       옥천동   0.0  0.017281     0.0250  0.000000  0.000056
# 11     강원도   강릉시       교1동   0.0  0.130889     0.0375  0.000000  0.000411
# ...

# %%
Test4 = Total[['설치유무','등록인구수','어린이보호구역개수','화재발생횟수']]

# %%
Test4.to_csv('Dataset/Acc/Test4.csv',index=0)

# %%
# 모델 평가 준비 작업
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

# 독립변수, 종속변수 분리
y_t_df = Test5['설치유무'] # 종속변수
X_t_df = Test5.drop('설치유무', axis = 1) # 독립변수

# 독립변수 정규화
# X_t_df = preprocessing.StandardScaler().fit(X_t_df).transform(X_t_df)

# 학습용 데이터와 평가용 데이터를 8:2 혹은 7:3으로 분리
X_train, X_test, y_train, y_test = train_test_split(X_t_df, y_t_df, test_size = 0.2,
                                                   random_state = 5)

print(X_train.shape)
print(X_test.shape)
# Out:
# (514, 3)
# (129, 3)

# %%
# 모델 학습 및 평가
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier()
rf_model.fit(X_train, y_train)
rf_pred = rf_model.predict(X_test)
accuracy_rf = accuracy_score(y_test, rf_pred)

lr_model = LogisticRegression()
lr_model.fit(X_train,y_train)
lr_pred = lr_model.predict(X_test)
accuracy_lr = accuracy_score(y_test,lr_pred)

print('rf 정확도:{}, lr 정확도:{}'.format(accuracy_rf,accuracy_lr))
# Out:
# rf 정확도:0.8837209302325582, lr 정확도:0.8604651162790697

# %%
A = pd.read_csv('Dataset/Acc/Test1.csv')

# %%
A.corr()
# Out:
#                설치유무     등록인구수  어린이보호구역개수    화재발생횟수    예상범죄비율
# 설치유무       1.000000 -0.094284  -0.006521 -0.096913  0.231305
# 등록인구수     -0.094284  1.000000   0.811589  0.788874  0.235147
# 어린이보호구역개수 -0.006521  0.811589   1.000000  0.741144  0.170189
# 화재발생횟수    -0.096913  0.788874   0.741144  1.000000  0.080852
# 예상범죄비율     0.231305  0.235147   0.170189  0.080852  1.000000

# %%
kids= pd.read_csv('Dataset/total_2/어린이보호총합.csv')

# %%
kids.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 428 entries, 0 to 427
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   시도명        428 non-null    object
#  1   시군구명       428 non-null    object
#  2   읍/면/동      428 non-null    object
#  3   등록인구수      428 non-null    float64
#  4   인구밀도       428 non-null    float64
#  5   어린이보호구역개수  428 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 20.2+ KB

# %%
kids
# Out:
#        시도명  시군구명     읍/면/동     등록인구수      인구밀도  어린이보호구역개수
# 0      강원도   강릉시       강남동   19111.0  0.012240        0.0
# 1      강원도   강릉시       강동면    4690.0  0.003004        5.0
# 2      강원도   강릉시       경포동    7746.0  0.004961        0.0
# 3      강원도   강릉시       교1동   27236.0  0.017444        3.0
# 4      강원도   강릉시       교2동    8284.0  0.005306        4.0
# 5      강원도   강릉시       구정면    4096.0  0.002623        5.0
# 6      강원도   강릉시       내곡동   16059.0  0.010286        2.0
# 7      강원도   강릉시       사천면    4601.0  0.002947        3.0
# 8      강원도   강릉시       성덕동   29100.0  0.018638        0.0
# 9      강원도   강릉시       성산면    3393.0  0.002173        3.0
# 10     강원도   강릉시       송정동    7093.0  0.004543        2.0
# 11     강원도   강릉시       연곡면    6871.0  0.004401        3.0
# 12     강원도   강릉시       옥계면    3857.0  0.002470        4.0
# 13     강원도   강릉시       옥천동    3694.0  0.002366        2.0
# 14     강원도   강릉시       왕산면    1648.0  0.001056        2.0
# ...

# %%
X = pd.merge(crime,kids,on=(['시도명','시군구명','읍/면/동','등록인구수','인구밀도']),how='left')

# %%
X
# Out:
#        시도명  시군구명     읍/면/동  설치유무     등록인구수  화재발생횟수  인구밀도  범죄총계(구)  범죄발생비율  \
# 0      강원도   강릉시       강남동   0.0   19111.0     0.0  0.01    328.0    4.01
# 1      강원도   강릉시       강동면   1.0    4690.0     0.0  0.00    328.0    0.99
# 2      강원도   강릉시       경포동   0.0    7746.0     0.0  0.00    328.0    1.63
# 3      강원도   강릉시       교1동   0.0   27236.0     0.0  0.02    328.0    5.72
# 4      강원도   강릉시       교2동   0.0    8284.0     0.0  0.01    328.0    1.74
# 5      강원도   강릉시       구정면   0.0    4096.0     0.0  0.00    328.0    0.86
# 6      강원도   강릉시       내곡동   0.0   16059.0     0.0  0.01    328.0    3.37
# 7      강원도   강릉시       사천면   0.0    4601.0     0.0  0.00    328.0    0.97
# 8      강원도   강릉시       성덕동   0.0   29100.0     0.0  0.02    328.0    6.11
# 9      강원도   강릉시       성산면   0.0    3393.0     0.0  0.00    328.0    0.71
# 10     강원도   강릉시       송정동   0.0    7093.0     0.0  0.00    328.0    1.49
# 11     강원도   강릉시       연곡면   0.0    6871.0     0.0  0.00    328.0    1.44
# ...

# %%
import pandas as pd

# %%
pd.read_csv('X.csv')
# Out:
#    20200203  00  F  age_00  11260655   5
# 0  20200203   0  F  age_00  11590605  15
# 1  20200203   0  F  age_00  11620595   3
# 2  20200203   0  F  age_00  26170530   4
# 3  20200203   0  F  age_00  27290572   8
# 4  20200203   0  F  age_00  28185830  18
# 5  20200203   0  F  age_00  28710320   1
# 6  20200203   0  F  age_00  28720380   1
# 7  20200203   0  F  age_00  29200680   1
# 8  20200203   0  F  age_00  30140670   9
# 9  20200203   0  F  age_00  31140635   7

# %%
find='충청북도'
print(len(pole[pole['시도명']==f'{find}']))
print(len(tour[tour['시도명']==f'{find}']))
print((len(pole[pole['시도명']==f'{find}']))-len(tour[tour['시도명']==f'{find}']))
# Out:
# 7
# 7
# 0

# %%
find='부산광역시'

시군구명 = list(pole[pole['시도명']==f'{find}']['시군구명'].unique())
print(f'#{find}','\n')
for city in 시군구명:
#     find=city
    print(f'pole.{city}',len(pole[pole['시군구명']==f'{city}']))
    print(f'tour.{city}',len(tour[tour['시군구명']==f'{city}']))
    print('차이',(len(pole[pole['시군구명']==f'{city}']))-len(tour[tour['시군구명']==f'{city}']))
# Out:
# #부산광역시
#
# pole.서구 31
# tour.서구 44
# 차이 -13

# %%
len(tour[tour['시도명']=='부산광역시']) #
# Out:
# 26

# %%
G = pd.read_csv('Dataset/tour/광주광역시서구관광지.csv')

# %%
G = G[G['시도명'] == '광주광역시']

# %%
G.to_csv('Dataset/tour/광주광역시서구관광지.csv',index=0)

# %%
G = pd.read_csv('Dataset/tour/광주광역시서구관광지.csv')

# %%
B = pd.read_csv('Dataset/tour/부산광역시서구관광지.csv')

# %%
B
# Out:
#       시도명 시군구명  읍/면/동    등록인구수      인구밀도  관광지개수
# 0   부산광역시   서구  동대신1동   4769.0  0.042346    NaN
# 1   부산광역시   서구  동대신2동   8225.0  0.073033    NaN
# 2   부산광역시   서구  동대신3동   6956.0  0.061765    NaN
# 3   부산광역시   서구  서대신1동  12051.0  0.107005    NaN
# 4   부산광역시   서구  서대신3동   8991.0  0.079834    3.0
# 5   부산광역시   서구  서대신4동   8250.0  0.073255    NaN
# 6   부산광역시   서구    부민동   8337.0  0.074027    1.0
# 7   부산광역시   서구    아미동   8071.0  0.071665    NaN
# 8   부산광역시   서구    초장동   5109.0  0.045365    NaN
# 9   부산광역시   서구    충무동  10435.0  0.092656    NaN
# 10  부산광역시   서구  남부민1동   5412.0  0.048055    1.0
# 11  부산광역시   서구  남부민2동  10544.0  0.093624    1.0
# 12  부산광역시   서구    암남동  15471.0  0.137372    5.0

# %%
Tour = pd.read_csv('Dataset/관광지데이터자료.csv')

# %%
Tour[Tour['제공기관명'] == '부산광역시 서구']
# Out:
#      Unnamed: 0      관광지명 관광지구분                                 소재지도로명주소  \
# 529         529   부산공동어시장   관광지                        부산광역시 서구 충무대로 202
# 530         530   천마산조각공원   관광지                   부산광역시 서구 천마산로 209번길 94
# 531         531     구덕운동장   관광지  부산광역시 서구 망양로 57 (씨름체육관 서구 꽃마을로 156번길12)
# 532         532   임시수도기념관   관광지                      부산광역시 서구 임시수도기념로 45
# 533         533    송도오션파크   관광지                                      NaN
# 547         547  송도해상케이블카   관광지                       부산광역시 서구 송도해변로 171
# 548         548    송도해수욕장   관광지                       부산광역시 서구 송도해변로 100
# 549         549      암남공원   관광지                       부산광역시 서구 암남공원로 185
# 550         550    구덕문화공원   관광지                   부산광역시 서구 꽃마을로 163번길 73
# 551         551   송도해안산책로   관광지                       부산광역시 서구 암남공원로 185
# 552         552      대신공원   관광지                     부산광역시 서구 대신공원로 37-18
#
#                       소재지지번주소         위도          경도         면적 공공편익시설정보  \
# ...

# %%
시군구명
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-9fe71f2db50e> in <module>
# ----> 1 시군구명
#
# NameError: name '시군구명' is not defined

# %%
시군구명
# Out:
# ['강릉시',
#  '고성군',
#  '동해시',
#  '삼척시',
#  '속초시',
#  '양구군',
#  '양양군',
#  '영월군',
#  '원주시',
#  '인제군',
#  '정선군',
#  '철원군',
#  '춘천시',
#  '태백시',
#  '평창군',
#  '홍천군',
#  '화천군',
#  '횡성군']

# %%
읍면동 = list(crime[(crime['시도명']=='강원도')&(crime['시군구명']=='강릉시')]['읍/면/동'].unique())

# %%
읍면동
# Out:
# ['강남동',
#  '강동면',
#  '경포동',
#  '교1동',
#  '교2동',
#  '구정면',
#  '내곡동',
#  '사천면',
#  '성덕동',
#  '성산면',
#  '송정동',
#  '연곡면',
#  '옥계면',
#  '옥천동',
#  '왕산면',
#  '주문진읍',
#  '중앙동',
#  '초당동',
#  '포남1동',
#  '포남2동',
#  '홍제동']

# %%
for i in 시군구명:
    for j in 읍면동:
        print(i,j,len(crime[(crime['시군구명']==f'{i}') & (crime['읍/면/동']==f'{j}')]))
        print(i,j,len(kids[(kids['시군구명']==f'{i}') & (kids['읍/면/동']==f'{j}')]))
        print('차이',len(crime[(crime['시군구명']==f'{i}') & (crime['읍/면/동']==f'{j}')])-len(kids[(kids['시군구명']==f'{i}') & (kids['읍/면/동']==f'{j}')]))
# Out:
# 강릉시 강남동 1
# 강릉시 강남동 1
# 차이 0
# 강릉시 강동면 1
# 강릉시 강동면 1
# 차이 0
# 강릉시 경포동 1
# 강릉시 경포동 1
# 차이 0
# 강릉시 교1동 1
# 강릉시 교1동 1
# 차이 0
# 강릉시 교2동 1
# 강릉시 교2동 1
# 차이 0
# 강릉시 구정면 1
# 강릉시 구정면 1
# 차이 0
# 강릉시 내곡동 1
# 강릉시 내곡동 1
# 차이 0
# 강릉시 사천면 1
# 강릉시 사천면 1
# 차이 0
# 강릉시 성덕동 1
# 강릉시 성덕동 1
# 차이 0
# 강릉시 성산면 1
# 강릉시 성산면 1
# 차이 0
# 강릉시 송정동 1
# 강릉시 송정동 1
# 차이 0
# 강릉시 연곡면 1
# 강릉시 연곡면 1
# 차이 0
# 강릉시 옥계면 1
# 강릉시 옥계면 1
# 차이 0
# 강릉시 옥천동 1
# 강릉시 옥천동 1
# 차이 0
# 강릉시 왕산면 1
# 강릉시 왕산면 1
# 차이 0
# 강릉시 주문진읍 1
# 강릉시 주문진읍 1
# 차이 0
# 강릉시 중앙동 1
# 강릉시 중앙동 1
# 차이 0
# 강릉시 초당동 1
# 강릉시 초당동 1
# 차이 0
# 강릉시 포남1동 1
# 강릉시 포남1동 1
# 차이 0
# 강릉시 포남2동 1
# 강릉시 포남2동 1
# 차이 0
# 강릉시 홍제동 1
# 강릉시 홍제동 1
# 차이 0
# 고성군 강남동 0
# 고성군 강남동 0
# 차이 0
# 고성군 강동면 0
# 고성군 강동면 0
# 차이 0
# 고성군 경포동 0
# 고성군 경포동 0
# 차이 0
# 고성군 교1동 0
# 고성군 교1동 0
# 차이 0
# 고성군 교2동 0
# 고성군 교2동 0
# 차이 0
# 고성군 구정면 0
# 고성군 구정면 0
# 차이 0
# 고성군 내곡동 0
# 고성군 내곡동 0
# 차이 0
# 고성군 사천면 0
# 고성군 사천면 0
# 차이 0
# 고성군 성덕동 0
# 고성군 성덕동 0
# 차이 0
# 고성군 성산면 0
# 고성군 성산면 0
# 차이 0
# 고성군 송정동 0
# 고성군 송정동 0
# 차이 0
# ...

# %%
읍면동
# Out:
# []

# %%
136+42+26+14+17
# Out:
# 235

# %%
235+428
# Out:
# 663

# %%
643-428
# Out:
# 215

# %%
len(crime[crime['시도명'] == '충청북도'])
# Out:
# 7

# %%
# 강원도
# 고성군 어보 데이터 업음
# 동해시 어보 데이터 없음
# 삼척시 어보 데이터 없음
# 양구군 어보 데이터 없음

# %%
#광주 남구
#통합본 < 어보통합 ; 약 +16개

# %%
child = df

# %%
human = pd.read_csv('Dataset/전국인구밀도포함.csv')

# %%
human[['등록인구수','인구밀도']] = human[['등록인구수','인구밀도']].astype(int)

# %%
human = human.drop(['인구밀도'],axis=1)

# %%
len(human)
# Out:
# 643

# %%
df
# Out:
#        시군구명     읍/면/동   등록인구수
# 시도명
# 강원도     춘천시       신북읍    8080
# 강원도     춘천시        동면   20120
# 강원도     춘천시       동산면    1560
# 강원도     춘천시       신동면    2594
# 강원도     춘천시        남면    1123
# 강원도     춘천시        서면    4071
# 강원도     춘천시       사북면    2674
# 강원도     춘천시       북산면     992
# 강원도     춘천시       동내면   17901
# 강원도     춘천시       남산면    3742
# 강원도     춘천시        교동    4369
# 강원도     춘천시       조운동    3231
# 강원도     춘천시      약사명동    2758
# 강원도     춘천시       근화동    9196
# 강원도     춘천시       소양동   10931
# 강원도     춘천시      후평1동   13013
# 강원도     춘천시      후평2동   15730
# 강원도     춘천시      후평3동   18286
# 강원도     춘천시      효자1동    5073
# 강원도     춘천시      효자2동   12918
# 강원도     춘천시      효자3동    5335
# 강원도     춘천시       석사동   38051
# 강원도     춘천시       퇴계동   44442
# 강원도     춘천시       강남동   17944
# 강원도     춘천시      신사우동   20868
# 강원도     원주시       문막읍   19728
# 강원도     원주시       소초면    9420
# 강원도     원주시       호저면    4088
# 강원도     원주시       지정면    9638
# 강원도     원주시       부론면    2391
# ...

# %%
df.equals(human)
# Out:
# False

# %%
df = df.reset_index()

# %%
시,구 = '강원도','강릉시'

# %%
find = 시
x = 구

# %%
# display(df[df['시도명']==f'{find}'])
display(df[(df['시도명']==f'{find}') & (df['시군구명']==f'{x}')].sort_values(by='읍/면/동'))
len(df[(df['시도명']==f'{find}') & (df['시군구명']==f'{x}')])
# Out:
#     시도명 시군구명 읍/면/동  등록인구수
# 68  강원도  강릉시   강남동  19111
# 54  강원도  강릉시   강동면   4690
# 70  강원도  강릉시   경포동   7746
# 61  강원도  강릉시   교1동  27236
# 62  강원도  강릉시   교2동   8284
# 53  강원도  강릉시   구정면   4096
# 67  강원도  강릉시   내곡동  16059
# 56  강원도  강릉시   사천면   4601
# 69  강원도  강릉시   성덕동  29100
# 51  강원도  강릉시   성산면   3393
# 66  강원도  강릉시   송정동   7093
# 57  강원도  강릉시   연곡면   6871
# 55  강원도  강릉시   옥계면   3857
# 60  강원도  강릉시   옥천동   3694
# 52  강원도  강릉시   왕산면   1648
# 50  강원도  강릉시  주문진읍  17085
# 59  강원도  강릉시   중앙동   5425
# 65  강원도  강릉시   초당동   5146
# 63  강원도  강릉시  포남1동  11184
# 64  강원도  강릉시  포남2동  14191
# 58  강원도  강릉시   홍제동  14729
# 21

# %%
# display(df[df['시도명']==f'{find}'])
display(human[(human['시도명']==f'{find}') & (human['시군구명']==f'{x}')].sort_values(by='읍/면/동'))
len(human[(human['시도명']==f'{find}') & (human['시군구명']==f'{x}')])
# Out:
#      시도명 시군구명 읍/면/동  등록인구수
# 328  강원도  강릉시   강남동  19111
# 314  강원도  강릉시   강동면   4690
# 330  강원도  강릉시   경포동   7746
# 321  강원도  강릉시   교1동  27236
# 322  강원도  강릉시   교2동   8284
# 313  강원도  강릉시   구정면   4096
# 327  강원도  강릉시   내곡동  16059
# 316  강원도  강릉시   사천면   4601
# 329  강원도  강릉시   성덕동  29100
# 311  강원도  강릉시   성산면   3393
# 326  강원도  강릉시   송정동   7093
# 317  강원도  강릉시   연곡면   6871
# 315  강원도  강릉시   옥계면   3857
# 320  강원도  강릉시   옥천동   3694
# 312  강원도  강릉시   왕산면   1648
# 310  강원도  강릉시  주문진읍  17085
# 319  강원도  강릉시   중앙동   5425
# 325  강원도  강릉시   초당동   5146
# 323  강원도  강릉시  포남1동  11184
# 324  강원도  강릉시  포남2동  14191
# 318  강원도  강릉시   홍제동  14729
# 21

# %%
# display(df[df['시도명']==f'{find}'])
display(어보[(어보['시도명']==f'{find}') & (어보['시군구명']==f'{x}')].sort_values(by='읍/면/동'))
len(어보[(어보['시도명']==f'{find}') & (어보['시군구명']==f'{x}')])
# Out:
#     시도명 시군구명 읍/면/동  등록인구수      인구밀도  어린이보호구역개수
# 0   강원도  강릉시   강남동  19111  0.012240          0
# 1   강원도  강릉시   강동면   4690  0.003004          5
# 2   강원도  강릉시   경포동   7746  0.004961          0
# 3   강원도  강릉시   교1동  27236  0.017444          3
# 4   강원도  강릉시   교2동   8284  0.005306          4
# 5   강원도  강릉시   구정면   4096  0.002623          5
# 6   강원도  강릉시   내곡동  16059  0.010286          2
# 7   강원도  강릉시   사천면   4601  0.002947          3
# 8   강원도  강릉시   성덕동  29100  0.018638          0
# 9   강원도  강릉시   성산면   3393  0.002173          3
# 10  강원도  강릉시   송정동   7093  0.004543          2
# 11  강원도  강릉시   연곡면   6871  0.004401          3
# 12  강원도  강릉시   옥계면   3857  0.002470          4
# 13  강원도  강릉시   옥천동   3694  0.002366          2
# 14  강원도  강릉시   왕산면   1648  0.001056          2
# 15  강원도  강릉시  주문진읍  17085  0.010943          8
# 16  강원도  강릉시   중앙동   5425  0.003475          0
# 17  강원도  강릉시   초당동   5146  0.003296          1
# 18  강원도  강릉시  포남1동  11184  0.007163          3
# ...

# %%
A = list(df[(df['시도명']==f'{find}') & (df['시군구명']==f'{x}')]['읍/면/동'].unique())
A = pd.DataFrame(A)
A = A.rename(columns={0:'읍/면/동'})
A = A.sort_values('읍/면/동')
a = A['읍/면/동']
display(A)
# Out:
#    읍/면/동
# 18   강남동
# 4    강동면
# 20   경포동
# 11   교1동
# 12   교2동
# 3    구정면
# 17   내곡동
# 6    사천면
# 19   성덕동
# 1    성산면
# 16   송정동
# 7    연곡면
# 5    옥계면
# 10   옥천동
# 2    왕산면
# 0   주문진읍
# 9    중앙동
# 15   초당동
# 13  포남1동
# 14  포남2동
# 8    홍제동

# %%
B = list(human[(human['시도명']==f'{find}') & (human['시군구명']==f'{x}')]['읍/면/동'].unique())
B = pd.DataFrame(B)
B = B.rename(columns={0:'읍/면/동'})
B = B.sort_values('읍/면/동')
b = B['읍/면/동']
display(B)
# Out:
#    읍/면/동
# 18   강남동
# 4    강동면
# 20   경포동
# 11   교1동
# 12   교2동
# 3    구정면
# 17   내곡동
# 6    사천면
# 19   성덕동
# 1    성산면
# 16   송정동
# 7    연곡면
# 5    옥계면
# 10   옥천동
# 2    왕산면
# 0   주문진읍
# 9    중앙동
# 15   초당동
# 13  포남1동
# 14  포남2동
# 8    홍제동

# %%
D = pd.concat(a,b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-242-c8a3eba46a7c> in <module>
# ----> 1 D = pd.concat(a,b)
#
# D:\Tools\envs\cakd3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     283     ValueError: Indexes have overlapping values: ['a']
#     284     """
# --> 285     op = _Concatenator(
#     286         objs,
#     287         axis=axis,
#
# D:\Tools\envs\cakd3\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     318     ):
#     319         if isinstance(objs, (ABCSeries, ABCDataFrame, str)):
# --> 320             raise TypeError(
#     321                 "first argument must be an iterable of pandas "
# ...

# %%
C = list(어보[(어보['시도명']==f'{find}') & (어보['시군구명']==f'{x}')]['읍/면/동'].unique())
print(C)
# Out:
# ['강남동', '강동면', '경포동', '교1동', '교2동', '구정면', '내곡동', '사천면', '성덕동', '성산면', '송정동', '연곡면', '옥계면', '옥천동', '왕산면', '주문진읍', '중앙동', '초당동', '포남1동', '포남2동', '홍제동']

# %%
a is b
# Out:
# False

# %%
어보 = pd.read_csv(f'Dataset/child/{시}{구}어린이보호구역.csv')

# %%
어보 = 어보.
# Out:
#     시도명 시군구명 읍/면/동  등록인구수      인구밀도  어린이보호구역개수
# 0   강원도  강릉시   강남동  19111  0.012240          0
# 1   강원도  강릉시   강동면   4690  0.003004          5
# 2   강원도  강릉시   경포동   7746  0.004961          0
# 3   강원도  강릉시   교1동  27236  0.017444          3
# 4   강원도  강릉시   교2동   8284  0.005306          4
# 5   강원도  강릉시   구정면   4096  0.002623          5
# 6   강원도  강릉시   내곡동  16059  0.010286          2
# 7   강원도  강릉시   사천면   4601  0.002947          3
# 8   강원도  강릉시   성덕동  29100  0.018638          0
# 9   강원도  강릉시   성산면   3393  0.002173          3
# 10  강원도  강릉시   송정동   7093  0.004543          2
# 11  강원도  강릉시   연곡면   6871  0.004401          3
# 12  강원도  강릉시   옥계면   3857  0.002470          4
# 13  강원도  강릉시   옥천동   3694  0.002366          2
# 14  강원도  강릉시   왕산면   1648  0.001056          2
# 15  강원도  강릉시  주문진읍  17085  0.010943          8
# 16  강원도  강릉시   중앙동   5425  0.003475          0
# 17  강원도  강릉시   초당동   5146  0.003296          1
# 18  강원도  강릉시  포남1동  11184  0.007163          3
# ...
