# %%
검색할시도명 = '검색할시도명'
검색할시군구명 = '검색할시군구명'
# 검색할시도명 = '전라북도'
# 검색할시군구명 = '고창군'

# 이거 띄어쓰기 잘해야함 '전라남도 신안군',"",x
import re
def umd(x):
    umd = re.sub('검색할시도명 검색할시군구명',"",x)
    umd = umd.lstrip()
    comp = re.compile('[가-힣]+')
    umd = comp.match(umd)
    umd = umd.group()
    return umd

# import re
# def umd(x):
#     umd = re.sub('전라북도 고창군',"",x)
#     umd = umd.lstrip()
#     comp = re.compile('[가-힣]+')
#     umd = comp.match(umd)
#     umd = umd.group()
#     return umd

u1 = ['해당지역 읍/면/동 리스트 만들어서 넣으세요']
# u1 =['고창읍','고수면','아산면','무장면','공음면','상하면','해리면','성송면','대산면','심원면','흥덕면','성내면','신림면','부안면']

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')


data = pd.read_csv('Dataset/전국스마트가로등표준데이터.csv',encoding='cp949')

data.isnull().sum()

data.columns

data['시도명'].unique()

data['시도명'] = data['시도명'].replace('14','전라남도')

data[data['시도명']==검색할시도명]['시군구명'].unique()

data1 = data[data['시도명']==검색할시도명]
detail_1 = data1[data1['시군구명']==검색할시군구명]


detail_1['읍/면/동'] = detail_1['소재지지번주소'].apply(lambda x : umd(x))

detail_1['설치유무'] = 1

get_col = ['시도명','시군구명','소재지지번주소','읍/면/동','설치유무']
detail_1 = detail_1[get_col]


u2 = detail_1['읍/면/동'].unique().tolist()
us = pd.Series(u1)

detail = pd.DataFrame(us)
detail['설치유무'] = np.nan
detail['시도명'] = data[data['시도명']==검색할시도명]['시도명'].unique()[0]
detail['시군구명'] = data[data['시군구명']==검색할시군구명]['시군구명'].unique()[0]

def 설치유무(x):
    y = ''
    for i in u2 :
        if x == i :
            y = 1
    return y


detail['설치유무'].update(detail[0].apply(설치유무))
detail['설치유무'] = detail['설치유무'].replace("",0)
detail = detail.rename(columns={0:'읍/면/동'})

detail = detail[['시도명','시군구명','읍/면/동','설치유무']]

detail
# Out:
#      시도명 시군구명 읍/면/동  설치유무
# 0   전라북도  고창군   고창읍   1.0
# 1   전라북도  고창군   고수면   1.0
# 2   전라북도  고창군   아산면   1.0
# 3   전라북도  고창군   무장면   1.0
# 4   전라북도  고창군   공음면   1.0
# 5   전라북도  고창군   상하면   1.0
# 6   전라북도  고창군   해리면   1.0
# 7   전라북도  고창군   성송면   1.0
# 8   전라북도  고창군   대산면   1.0
# 9   전라북도  고창군   심원면   1.0
# 10  전라북도  고창군   흥덕면   1.0
# 11  전라북도  고창군   성내면   1.0
# 12  전라북도  고창군   신림면   1.0
# 13  전라북도  고창군   부안면   1.0

# %%
detail_1[detail_1['읍/면/동']=='고창읍'].value_counts()
# Out:
# 시도명   시군구명  소재지지번주소                   읍/면/동  설치유무
# 전라북도  고창군   전라북도 고창군 고창읍 교촌리 113      고창읍    1       1
#             전라북도 고창군 고창읍 교촌리 168      고창읍    1       1
#             전라북도 고창군 고창읍 월곡리 844      고창읍    1       1
#             전라북도 고창군 고창읍 월산리 116      고창읍    1       1
#             전라북도 고창군 고창읍 월산리 32-5     고창읍    1       1
#             전라북도 고창군 고창읍 월산리 426-30   고창읍    1       1
#             전라북도 고창군 고창읍 월암리 159-1    고창읍    1       1
#             전라북도 고창군 고창읍 읍내리 109      고창읍    1       1
#             전라북도 고창군 고창읍 읍내리 1213     고창읍    1       1
#             전라북도 고창군 고창읍 읍내리 18       고창읍    1       1
#             전라북도 고창군 고창읍 읍내리 191-6    고창읍    1       1
#             전라북도 고창군 고창읍 읍내리 324-14   고창읍    1       1
#             전라북도 고창군 고창읍 읍내리 380-4    고창읍    1       1
#             전라북도 고창군 고창읍 읍내리 41-5     고창읍    1       1
#             전라북도 고창군 고창읍 읍내리 415-19   고창읍    1       1
#             전라북도 고창군 고창읍 읍내리 545-7    고창읍    1       1
#             전라북도 고창군 고창읍 읍내리 563-3    고창읍    1       1
#             전라북도 고창군 고창읍 읍내리 611-6    고창읍    1       1
#             전라북도 고창군 고창읍 읍내리 652-3    고창읍    1       1
#             전라북도 고창군 고창읍 읍내리 658-7    고창읍    1       1
#             전라북도 고창군 고창읍 읍내리 662      고창읍    1       1
#             전라북도 고창군 고창읍 읍내리 805-2    고창읍    1       1
#             전라북도 고창군 고창읍 읍내리 83-1     고창읍    1       1
#             전라북도 고창군 고창읍 읍내리 863-209  고창읍    1       1
#             전라북도 고창군 고창읍 읍내리 87-14    고창읍    1       1
#             전라북도 고창군 고창읍 월곡리 793      고창읍    1       1
#             전라북도 고창군 고창읍 월곡리 738      고창읍    1       1
#             전라북도 고창군 고창읍 월곡리 634      고창읍    1       1
#             전라북도 고창군 고창읍 교촌리 475      고창읍    1       1
#             전라북도 고창군 고창읍 교촌리 218-7    고창읍    1       1
#             전라북도 고창군 고창읍 교촌리 221-1    고창읍    1       1
#             전라북도 고창군 고창읍 교촌리 222-17   고창읍    1       1
#             전라북도 고창군 고창읍 교촌리 232-7    고창읍    1       1
#             전라북도 고창군 고창읍 교촌리 355      고창읍    1       1
#             전라북도 고창군 고창읍 교촌리 37       고창읍    1       1
#             전라북도 고창군 고창읍 교촌리 377      고창읍    1       1
#             전라북도 고창군 고창읍 교촌리 40       고창읍    1       1
#             전라북도 고창군 고창읍 교촌리 432      고창읍    1       1
#             전라북도 고창군 고창읍 교촌리 443      고창읍    1       1
#             전라북도 고창군 고창읍 교촌리 492      고창읍    1       1
#             전라북도 고창군 고창읍 월곡리 602      고창읍    1       1
#             전라북도 고창군 고창읍 교촌리 67-3     고창읍    1       1
#             전라북도 고창군 고창읍 노동리 72-6     고창읍    1       1
#             전라북도 고창군 고창읍 덕산리 161-2    고창읍    1       1
#             전라북도 고창군 고창읍 덕산리 3-5      고창읍    1       1
#             전라북도 고창군 고창읍 덕산리 303-1    고창읍    1       1
#             전라북도 고창군 고창읍 석교리 10-8     고창읍    1       1
#             전라북도 고창군 고창읍 석정리 489-8    고창읍    1       1
#             전라북도 고창군 고창읍 성두리 368-1    고창읍    1       1
#             전라북도 고창군 고창읍 월곡리 280-4    고창읍    1       1
#             전라북도 고창군 고창읍 월곡리 567      고창읍    1       1
#             전라북도 고창군 고창읍 화산리 236-2    고창읍    1       1
# dtype: int64

# %%
fire = pd.read_csv('dataset/화재발생정보.csv', encoding='cp949',index_col='연번')
fire = fire[(fire['시도']==검색할시도명) & (fire['시군구'] == 검색할시군구명)]
fire['읍면동'].value_counts()
group = fire.groupby('읍면동').count()
group = group.reset_index(drop = False)
group['화재발생횟수'] = group['사망']
fire = group[['읍면동','화재발생횟수']]
fire = fire.rename(columns={'읍면동':'읍/면/동'})
fire['화재발생비율'] = fire['화재발생횟수']/fire['화재발생횟수'].sum()
fire['화재발생비율'] = fire['화재발생비율'].round(2)
df = pd.merge(detail,fire,on='읍/면/동',how='outer')
df
# Out:
#      시도명 시군구명 읍/면/동  설치유무  화재발생횟수  화재발생비율
# 0   전라북도  고창군   고창읍   1.0      24    0.17
# 1   전라북도  고창군   고수면   1.0       9    0.06
# 2   전라북도  고창군   아산면   1.0      10    0.07
# 3   전라북도  고창군   무장면   1.0      13    0.09
# 4   전라북도  고창군   공음면   1.0       8    0.06
# 5   전라북도  고창군   상하면   1.0       9    0.06
# 6   전라북도  고창군   해리면   1.0       8    0.06
# 7   전라북도  고창군   성송면   1.0       8    0.06
# 8   전라북도  고창군   대산면   1.0      12    0.09
# 9   전라북도  고창군   심원면   1.0       4    0.03
# 10  전라북도  고창군   흥덕면   1.0      13    0.09
# 11  전라북도  고창군   성내면   1.0       7    0.05
# 12  전라북도  고창군   신림면   1.0       4    0.03
# 13  전라북도  고창군   부안면   1.0      11    0.08

# %%
df.to_csv(f'Dataset/{검색할시군구명}.csv',index=0)
df = pd.read_csv(f'Dataset/{검색할시군구명}.csv')
df
