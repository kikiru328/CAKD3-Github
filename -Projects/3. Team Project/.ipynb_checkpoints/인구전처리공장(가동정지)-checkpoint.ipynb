# %%
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

전처리파일 = '충남아산시인구'

# %%
dd = pd.read_csv(f'New1/{전처리파일}.csv',index_col=0,encoding='cp949')
dd =dd.reset_index(drop=False)
dd['읍면동별(1)']. unique()
dd = dd[['읍면동별(1)','읍면동별(2)','2018.1']]
dd = dd.rename(columns={'읍면동별(1)':'시군구명','읍면동별(2)':'읍/면/동','2018.1':'등록인구수'})
읍면동 = [index for index, row in dd[dd['읍/면/동']=='소계'].iterrows()]
불필요시군구 = [index for index, row in dd[dd['읍/면/동']=='읍면동별(2)'].iterrows()]
dd = dd.drop(읍면동)
dd = dd.drop(불필요시군구)
dd['시도명'] = f'{전처리파일}'
dd = dd[['시도명','시군구명','읍/면/동','등록인구수']]
dd.to_csv(f'Dataset/human/{전처리파일}.csv',index=0)
data = pd.read_csv(f'Dataset/human/{전처리파일}.csv')
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-129-c504c848e3ca> in <module>
#       2 dd =dd.reset_index(drop=False)
#       3 dd['읍면동별(1)']. unique()
# ----> 4 dd = dd[['읍면동별(1)','읍면동별(2)','2018.1']]
#       5 dd = dd.rename(columns={'읍면동별(1)':'시군구명','읍면동별(2)':'읍/면/동','2018.1':'등록인구수'})
#       6 읍면동 = [index for index, row in dd[dd['읍/면/동']=='소계'].iterrows()]
#
# D:\Tools\envs\cakd3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# D:\Tools\envs\cakd3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# D:\Tools\envs\cakd3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1314             if raise_missing:
#    1315                 not_found = list(set(key) - set(ax))
# -> 1316                 raise KeyError(f"{not_found} not in index")
#    1317
#    1318             not_found = key[missing_mask]
#
# KeyError: "['읍면동별(2)', '2018.1'] not in index"

# %%
# 아산라인

# %%
dd = pd.read_csv(f'New1/{전처리파일}.csv',index_col=0,encoding='cp949')
dd =dd.reset_index(drop=False)
dd['읍면동별(1)']. unique()
dd = dd[['읍면동별(1)','2019.1']]
dd = dd.rename(columns={'읍면동별(1)':'읍/면/동','2019.1':'등록인구수'})
# 읍면동 = [index for index, row in dd[dd['읍/면/동']=='소계'].iterrows()]
# 불필요시군구 = [index for index, row in dd[dd['읍/면/동']=='읍면동별(2)'].iterrows()]
# dd = dd.drop(읍면동)
# dd = dd.drop(불필요시군구)
# dd['시도명'] = f'{전처리파일}'
# dd = dd[['시도명','시군구명','읍/면/동','등록인구수']]
# dd.to_csv(f'Dataset/human/{전처리파일}.csv',index=0)
# data = pd.read_csv(f'Dataset/human/{전처리파일}.csv')
# data

# %%
dd
# Out:
#       읍/면/동   등록인구수  시도명
# 0   읍면동별(1)  인구 (명)  강원도
# 1   읍면동별(1)      합계  강원도
# 2   읍면동별(1)      소계  강원도
# 3        합계  333074  강원도
# 4       염치읍    6980  강원도
# 5       배방읍   74906  강원도
# 6       송악면    4355  강원도
# 7       탕정면   21879  강원도
# 8       음봉면   20996  강원도
# 9       둔포면   25135  강원도
# 10      영인면    6397  강원도
# 11      인주면    7478  강원도
# 12      선장면    3664  강원도
# 13      도고면    4630  강원도
# 14      신창면   25247  강원도
# 15     온양1동   10085  강원도
# 16     온양2동    7869  강원도
# 17     온양3동   37848  강원도
# 18     온양4동   19078  강원도
# 19     온양5동   26973  강원도
# 20     온양6동   29554  강원도

# %%
# encoding 라인

# %%
dd = pd.read_csv(f'New1/{전처리파일}.csv',index_col=0)
dd =dd.reset_index(drop=False)
dd['읍면동별(1)']. unique()
dd = dd[['읍면동별(1)','읍면동별(2)','2018.1']]
dd = dd.rename(columns={'읍면동별(1)':'시군구명','읍면동별(2)':'읍/면/동','2018.1':'등록인구수'})
읍면동 = [index for index, row in dd[dd['읍/면/동']=='소계'].iterrows()]
불필요시군구 = [index for index, row in dd[dd['읍/면/동']=='읍면동별(2)'].iterrows()]
dd = dd.drop(읍면동)
dd = dd.drop(불필요시군구)
dd['시도명'] = f'{전처리파일}'
dd = dd[['시도명','시군구명','읍/면/동','등록인구수']]
dd
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Tools\envs\cakd3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '읍면동별(1)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-131-ce7d2b87ff79> in <module>
#       1 dd = pd.read_csv(f'New1/{전처리파일}.csv',index_col=0)
#       2 dd =dd.reset_index(drop=False)
# ----> 3 dd['읍면동별(1)']. unique()
#       4 dd = dd[['읍면동별(1)','읍면동별(2)','2018.1']]
#       5 dd = dd.rename(columns={'읍면동별(1)':'시군구명','읍면동별(2)':'읍/면/동','2018.1':'등록인구수'})
#
# D:\Tools\envs\cakd3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# D:\Tools\envs\cakd3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: '읍면동별(1)'

# %%
# 컬럼오류라인

# %%
dd = pd.read_csv(f'New1/{전처리파일}.csv',index_col=0)
dd =dd.reset_index(drop=False)
dd['읍면동별(1)']. unique()
dd = dd[['읍면동별(1)','읍면동별(2)','2019.1']]
dd = dd.rename(columns={'읍면동별(1)':'시군구명','읍면동별(2)':'읍/면/동','2019.1':'등록인구수'})
읍면동 = [index for index, row in dd[dd['읍/면/동']=='소계'].iterrows()]
불필요시군구 = [index for index, row in dd[dd['읍/면/동']=='읍면동별(2)'].iterrows()]
dd = dd.drop(읍면동)
dd = dd.drop(불필요시군구)
dd['시도명'] = f'{전처리파일}'
dd = dd[['시도명','시군구명','읍/면/동','등록인구수']]
dd.to_csv(f'Dataset/human/{전처리파일}.csv',index=0)
data = pd.read_csv(f'Dataset/human/{전처리파일}.csv')
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Tools\envs\cakd3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '읍면동별(1)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-133-f4978f77d666> in <module>
#       1 dd = pd.read_csv(f'New1/{전처리파일}.csv',index_col=0)
#       2 dd =dd.reset_index(drop=False)
# ----> 3 dd['읍면동별(1)']. unique()
#       4 dd = dd[['읍면동별(1)','읍면동별(2)','2019.1']]
#       5 dd = dd.rename(columns={'읍면동별(1)':'시군구명','읍면동별(2)':'읍/면/동','2019.1':'등록인구수'})
#
# D:\Tools\envs\cakd3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# D:\Tools\envs\cakd3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: '읍면동별(1)'

# %%
# 읍면동별(1) 오류 라인

# %%
dd = pd.read_csv(f'New1/{전처리파일}.csv',index_col=0,encoding='cp949')
dd =dd.reset_index(drop=False)
dd['행정구역(읍면동)별(1)']. unique()
dd = dd[['행정구역(읍면동)별(1)','행정구역(읍면동)별(2)','2019.1']]
dd = dd.rename(columns={'행정구역(읍면동)별(1)':'시군구명','행정구역(읍면동)별(2)':'읍/면/동','2019.1':'등록인구수'})
읍면동 = [index for index, row in dd[dd['읍/면/동']=='소계'].iterrows()]
읍면동1 = [index for index, row in dd[dd['읍/면/동']=='행정구역(읍면동)별(2)'].iterrows()]
불필요시군구 = [index for index, row in dd[dd['읍/면/동']=='읍면동별(2)'].iterrows()]
dd = dd.drop(읍면동)
dd = dd.drop(읍면동1)
dd = dd.drop(불필요시군구)
dd['시도명'] = f'{전처리파일}'
dd = dd[['시도명','시군구명','읍/면/동','등록인구수']]
dd.to_csv(f'Dataset/human/{전처리파일}.csv',index=0)
data = pd.read_csv(f'Dataset/human/{전처리파일}.csv')
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Tools\envs\cakd3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '행정구역(읍면동)별(1)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-135-8ffa8c8d99a1> in <module>
#       1 dd = pd.read_csv(f'New1/{전처리파일}.csv',index_col=0,encoding='cp949')
#       2 dd =dd.reset_index(drop=False)
# ----> 3 dd['행정구역(읍면동)별(1)']. unique()
#       4 dd = dd[['행정구역(읍면동)별(1)','행정구역(읍면동)별(2)','2019.1']]
#       5 dd = dd.rename(columns={'행정구역(읍면동)별(1)':'시군구명','행정구역(읍면동)별(2)':'읍/면/동','2019.1':'등록인구수'})
#
# D:\Tools\envs\cakd3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# D:\Tools\envs\cakd3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: '행정구역(읍면동)별(1)'

# %%
#추가오류라인

# %%
dd = pd.read_csv(f'New1/{전처리파일}.csv',index_col=0,encoding='cp949')
dd =dd.reset_index(drop=False)
dd['행정구역(읍면동)별(1)']. unique()
dd = dd[['행정구역(읍면동)별(1)','행정구역(읍면동)별(2)','2019.1']]
dd = dd.rename(columns={'행정구역(읍면동)별(1)':'시군구명','행정구역(읍면동)별(2)':'읍/면/동','2019.1':'등록인구수'})
읍면동 = [index for index, row in dd[dd['읍/면/동']=='소계'].iterrows()]
불필요시군구 = [index for index, row in dd[dd['읍/면/동']=='읍면동별(2)'].iterrows()]
dd = dd.drop(읍면동)
dd = dd.drop(불필요시군구)
dd['시도명'] = f'{전처리파일}'
dd = dd[['시도명','시군구명','읍/면/동','등록인구수']]
dd.to_csv(f'Dataset/human/{전처리파일}.csv',index=0)
data = pd.read_csv(f'Dataset/human/{전처리파일}.csv')
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Tools\envs\cakd3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '행정구역(읍면동)별(1)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-137-8d6085eddb5e> in <module>
#       1 dd = pd.read_csv(f'New1/{전처리파일}.csv',index_col=0,encoding='cp949')
#       2 dd =dd.reset_index(drop=False)
# ----> 3 dd['행정구역(읍면동)별(1)']. unique()
#       4 dd = dd[['행정구역(읍면동)별(1)','행정구역(읍면동)별(2)','2019.1']]
#       5 dd = dd.rename(columns={'행정구역(읍면동)별(1)':'시군구명','행정구역(읍면동)별(2)':'읍/면/동','2019.1':'등록인구수'})
#
# D:\Tools\envs\cakd3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# D:\Tools\envs\cakd3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: '행정구역(읍면동)별(1)'

# %%
#2018 오류 라인

# %%
dd = pd.read_csv(f'New1/{전처리파일}.csv',index_col=0,encoding='cp949')
dd =dd.reset_index(drop=False)
dd['행정구역(읍면동)별(1)']. unique()
dd = dd[['행정구역(읍면동)별(1)','행정구역(읍면동)별(2)','2018.1']]
dd = dd.rename(columns={'읍면동별(1)':'시군구명','읍면동별(2)':'읍/면/동','2019.1':'등록인구수'})
읍면동 = [index for index, row in dd[dd['읍/면/동']=='소계'].iterrows()]
불필요시군구 = [index for index, row in dd[dd['읍/면/동']=='읍면동별(2)'].iterrows()]
dd = dd.drop(읍면동)
dd = dd.drop(불필요시군구)
dd['시도명'] = f'{전처리파일}'
dd = dd[['시도명','시군구명','읍/면/동','등록인구수']]
dd.to_csv(f'Dataset/human/{전처리파일}.csv',index=0)
data = pd.read_csv(f'Dataset/human/{전처리파일}.csv')
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Tools\envs\cakd3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '행정구역(읍면동)별(1)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-139-e36a7b94f61c> in <module>
#       1 dd = pd.read_csv(f'New1/{전처리파일}.csv',index_col=0,encoding='cp949')
#       2 dd =dd.reset_index(drop=False)
# ----> 3 dd['행정구역(읍면동)별(1)']. unique()
#       4 dd = dd[['행정구역(읍면동)별(1)','행정구역(읍면동)별(2)','2018.1']]
#       5 dd = dd.rename(columns={'읍면동별(1)':'시군구명','읍면동별(2)':'읍/면/동','2019.1':'등록인구수'})
#
# D:\Tools\envs\cakd3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# D:\Tools\envs\cakd3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: '행정구역(읍면동)별(1)'

# %%
#아예 다른라인

# %%
#확인검차

# %%
dd = pd.read_csv(f'New1/{전처리파일}.csv',index_col=0,encoding='cp949')
dd
# Out:
#              2019  2019.1  2019.2  2019.3  2019.4  2019.5  2019.6  2019.7  \
# 읍면동별(1)
# 읍면동별(1)  세대수 (세대)  인구 (명)  인구 (명)  인구 (명)  인구 (명)  인구 (명)  인구 (명)  인구 (명)
# 읍면동별(1)        소계      합계      합계      합계     한국인     한국인     한국인     외국인
# 읍면동별(1)        소계      소계       남       여      소계       남       여      소계
# 합계         135159  333074  174133  158941  314395  162694  151701   18679
# 염치읍          3219    6980    3702    3278    6734    3506    3228     246
# 배방읍         29969   74906   38461   36445   73407   37687   35720    1499
# 송악면          1931    4355    2245    2110    4313    2221    2092      42
# 탕정면          8661   21879   11624   10255   20891   11187    9704     988
# 음봉면          8664   20996   11587    9409   19834   10642    9192    1162
# 둔포면         10531   25135   14504   10631   21121   11777    9344    4014
# 영인면          2754    6397    3635    2762    5677    3001    2676     720
# 인주면          3583    7478    4351    3127    6667    3671    2996     811
# 선장면          1661    3664    2054    1610    3275    1709    1566     389
# 도고면          2288    4630    2380    2250    4563    2344    2219      67
# 신창면          9332   25247   13328   11919   20477   10635    9842    4770
# 온양1동         4543   10085    5248    4837    9646    5039    4607     439
# 온양2동         3493    7869    3987    3882    7172    3607    3565     697
# 온양3동        14242   37848   18781   19067   37207   18512   18695     641
# 온양4동         7356   19078    9831    9247   18161    9305    8856     917
# 온양5동        10853   26973   13811   13162   26055   13388   12667     918
# 온양6동        12079   29554   14604   14950   29195   14463   14732     359
#
#          2019.8  2019.9    2019.10         2019.11   2019.12   2019.13 2019.14
# 읍면동별(1)
# 읍면동별(1)  인구 (명)  인구 (명)  세대당인구 (명)  65세 이상 고령자 (명)  평균연령 (세)      인구밀도    인구밀도
# 읍면동별(1)     외국인     외국인         소계              소계        소계  소계 (명/㎢)  면적 (㎢)
# 읍면동별(1)       남       여         소계              소계        소계        소계      소계
# 합계        11439    7240       2.33           40045      38.7    579.21  542.80
# 염치읍         196      50       2.09            1704         -    159.74   42.16
# 배방읍         774     725       2.45            5605         -   1479.55   49.61
# 송악면          24      18       2.23            1280         -     70.51   61.17
# 탕정면         437     551       2.41            1248         -    862.96   24.21
# 음봉면         945     217       2.29            2283         -    335.44   59.13
# 둔포면        2727    1287       2.01            2580         -    512.78   41.19
# 영인면         634      86       2.06            1938         -    100.77   56.33
# 인주면         680     131       1.86            1696         -    147.09   45.32
# 선장면         345      44       1.97            1408         -     86.48   37.87
# 도고면          36      31       1.99            1665         -    104.14   43.82
# 신창면        2693    2077       2.19            3303         -    515.79   39.70
# 온양1동        209     230       2.12            1484         -    6780.1    1.42
# 온양2동        380     317       2.05            1501         -   9314.29    0.77
# 온양3동        269     372       2.61            3791         -   5929.14    6.28
# 온양4동        526     391       2.47            2384         -   1805.13   10.06
# 온양5동        423     495       2.40            2791         -   2001.77   13.02
# 온양6동        141     218       2.42            3384         -   2717.83   10.74

# %%
#고창 무주 정읍 동일 라인 생성
