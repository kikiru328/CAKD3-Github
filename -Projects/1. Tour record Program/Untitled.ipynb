# %%
data
# Out:
#               여행날짜 관광유형        출발지        관광지명  이동수단  관광기간      총비용  만족도  \
# 0         20210704   캠핑      여의나루역    여의나루한강공원    도보     1    50000  5.0
# 1   2020-10-22-Thu   도시    걸포1로 10          경주   KTX     2   100000  5.0
# 2         20210130   식사        개포동          경주   KTX     3   150000  5.0
# 3         20210220    술     금천구독산동         대부도   자동차     2   150000  4.0
# 4         20201211   스키     금천구독산동     홍천비발디파크   자동차     2   180000  4.8
# 5         20210101   바다        서울역         을왕리  고속버스     3   200000  3.0
# 6         20210406   도시       인천공항         제주도   비행기     3   600000  5.0
# 7         20191011   도시        영등포          부산   비행기     3   300000  4.0
# 8         20210603   바다  서울고속버스터미널  동해시종합버스터미널  고속버스     2   150000  5.0
# 9         20210605   휴가  서산시해미면기지리         지리산   자동차     2   100000  4.7
# 10        20210611    산      걸포북변역         인왕산   지하철     1    30000  3.4
# 11        20200501   도시         서울      전주한옥마을   KTX     2   200000  4.3
# ...

# %%
data= pd.read
