# %%
import pandas as pd

# %%
Total = pd.read_csv('Dataset/total/찐최종.csv')

# %%
Total['설치유무'] = Total['설치유무'].astype(float)
Total['등록인구수']=Total['등록인구수'].astype(float)
Total['어린이보호구역개수']=Total['어린이보호구역개수'].astype(float)
Total['화재발생횟수']=Total['화재발생횟수'].astype(float)

Total.to_csv('Dataset/total/진짜최종_2.csv',index=0)
Total = pd.read_csv('Dataset/total/진짜최종_2.csv')
Total = Total.rename({'범죄발생비율':'예상범죄횟수'},axis=1)

# Total = Total.drop('인구밀도',axis=1)
# Total = Total.drop('범죄총계(구)',axis=1)
# Total['전국범죄총계'] = Total['예상범죄횟수'].sum()
# Total['예상범죄비율'] = Total['예상범죄횟수'] / Total['전국범죄총계']
# Total = Total.drop(['전국범죄총계'],axis=1)

# %%
Total
# Out:
#       시도명 시군구명 읍/면/동  설치유무    등록인구수  어린이보호구역개수  화재발생횟수  인구밀도  범죄총계(구)  예상범죄횟수  \
# 0     강원도  강릉시  주문진읍   1.0  17085.0        8.0     0.0  0.01    328.0    3.59
# 1     강원도  강릉시   성산면   0.0   3393.0        3.0     0.0  0.00    328.0    0.71
# 2     강원도  강릉시   왕산면   0.0   1648.0        2.0     0.0  0.00    328.0    0.35
# 3     강원도  강릉시   구정면   0.0   4096.0        5.0     0.0  0.00    328.0    0.86
# 4     강원도  강릉시   강동면   1.0   4690.0        3.0     0.0  0.00    328.0    0.99
# ..    ...  ...   ...   ...      ...        ...     ...   ...      ...     ...
# 638  충청북도  진천군   초평면   1.0   3508.0        4.0     0.0  0.04    980.0   40.80
# 639  충청북도  진천군   문백면   1.0   4147.0        4.0     0.0  0.05    980.0   48.23
# 640  충청북도  진천군   백곡면   1.0   2167.0        2.0     0.0  0.03    980.0   25.20
# 641  충청북도  진천군   이월면   0.0   8078.0        6.0     0.0  0.10    980.0   93.95
# 642  충청북도  진천군  광혜원면   1.0  12009.0        3.0     0.0  0.14    980.0  139.66
#
#      관광지개수
# 0      1.0
# ...

# %%
Total = Total.drop(['인구밀도','예상범죄횟수'],axis=1)
Total
# Out:
#       시도명 시군구명 읍/면/동  설치유무    등록인구수  어린이보호구역개수  화재발생횟수  범죄총계(구)  관광지개수
# 0     강원도  강릉시  주문진읍   1.0  17085.0        8.0     0.0    328.0    1.0
# 1     강원도  강릉시   성산면   0.0   3393.0        3.0     0.0    328.0    1.0
# 2     강원도  강릉시   왕산면   0.0   1648.0        2.0     0.0    328.0    0.0
# 3     강원도  강릉시   구정면   0.0   4096.0        5.0     0.0    328.0    0.0
# 4     강원도  강릉시   강동면   1.0   4690.0        3.0     0.0    328.0    0.0
# ..    ...  ...   ...   ...      ...        ...     ...      ...    ...
# 638  충청북도  진천군   초평면   1.0   3508.0        4.0     0.0    980.0    0.0
# 639  충청북도  진천군   문백면   1.0   4147.0        4.0     0.0    980.0    0.0
# 640  충청북도  진천군   백곡면   1.0   2167.0        2.0     0.0    980.0    0.0
# 641  충청북도  진천군   이월면   0.0   8078.0        6.0     0.0    980.0    0.0
# 642  충청북도  진천군  광혜원면   1.0  12009.0        3.0     0.0    980.0    0.0
#
# [643 rows x 9 columns]

# %%
# Total.to_csv('Dataset/F_Dataset/Raw_dataset.csv',index=0)

# %%
grouped = Total.groupby(['시도명','시군구명'])[['등록인구수']].sum()

# %%
grouped = grouped.reset_index()

# %%
grouped = grouped.rename(columns={'등록인구수':'등록인구수총계(구)'})

# %%
grouped.head(1)
# Out:
#    시도명 시군구명  등록인구수총계(구)
# 0  강원도  강릉시    215239.0

# %%
Total.head(1)
# Out:
#    시도명 시군구명 읍/면/동  설치유무    등록인구수  어린이보호구역개수  화재발생횟수  범죄총계(구)  관광지개수
# 0  강원도  강릉시  주문진읍   1.0  17085.0        8.0     0.0    328.0    1.0

# %%
mil = pd.merge(Total,grouped,on=(['시도명','시군구명']),how='left')

# %%
Total = mil

# %%
Total
# Out:
#       시도명 시군구명 읍/면/동  설치유무    등록인구수  어린이보호구역개수  화재발생횟수  범죄총계(구)  관광지개수  \
# 0     강원도  강릉시  주문진읍   1.0  17085.0        8.0     0.0    328.0    1.0
# 1     강원도  강릉시   성산면   0.0   3393.0        3.0     0.0    328.0    1.0
# 2     강원도  강릉시   왕산면   0.0   1648.0        2.0     0.0    328.0    0.0
# 3     강원도  강릉시   구정면   0.0   4096.0        5.0     0.0    328.0    0.0
# 4     강원도  강릉시   강동면   1.0   4690.0        3.0     0.0    328.0    0.0
# ..    ...  ...   ...   ...      ...        ...     ...      ...    ...
# 638  충청북도  진천군   초평면   1.0   3508.0        4.0     0.0    980.0    0.0
# 639  충청북도  진천군   문백면   1.0   4147.0        4.0     0.0    980.0    0.0
# 640  충청북도  진천군   백곡면   1.0   2167.0        2.0     0.0    980.0    0.0
# 641  충청북도  진천군   이월면   0.0   8078.0        6.0     0.0    980.0    0.0
# 642  충청북도  진천군  광혜원면   1.0  12009.0        3.0     0.0    980.0    0.0
#
#      등록인구수총계(구)
# 0      215239.0
# 1      215239.0
# 2      215239.0
# 3      215239.0
# 4      215239.0
# ...

# %%
# Total.to_csv('Dataset/F_Dataset/raw_data.csv',index=0)

# %%
Total['인구밀도비율'] = Total['등록인구수'] / Total['등록인구수총계(구)']

# %%
Total['예상범죄발생횟수'] = Total['범죄총계(구)'] * Total['인구밀도비율']

# %%
Total.head()
# Out:
#    시도명 시군구명 읍/면/동  설치유무    등록인구수  어린이보호구역개수  화재발생횟수  범죄총계(구)  관광지개수  \
# 0  강원도  강릉시  주문진읍   1.0  17085.0        8.0     0.0    328.0    1.0
# 1  강원도  강릉시   성산면   0.0   3393.0        3.0     0.0    328.0    1.0
# 2  강원도  강릉시   왕산면   0.0   1648.0        2.0     0.0    328.0    0.0
# 3  강원도  강릉시   구정면   0.0   4096.0        5.0     0.0    328.0    0.0
# 4  강원도  강릉시   강동면   1.0   4690.0        3.0     0.0    328.0    0.0
#
#    등록인구수총계(구)    인구밀도비율   예상범죄발생횟수
# 0    215239.0  0.079377  26.035616
# 1    215239.0  0.015764   5.170550
# 2    215239.0  0.007657   2.511366
# 3    215239.0  0.019030   6.241843
# 4    215239.0  0.021790   7.147032

# %%
# Total = Total.drop('예상범죄발생',axis=1)

# %%
# Total.to_csv('Dataset/F_Dataset/Raw_dataset_Derived.csv',index=0)

# %%
Total = Total.drop(['범죄총계(구)','등록인구수총계(구)','인구밀도비율'],axis=1)

# %%
# Total.to_csv('Dataset/F_Dataset/Raw_dataset_Derived_2.csv',index=0)

# %%
Total
# Out:
#       시도명 시군구명 읍/면/동  설치유무    등록인구수  어린이보호구역개수  화재발생횟수  관광지개수    예상범죄발생횟수
# 0     강원도  강릉시  주문진읍   1.0  17085.0        8.0     0.0    1.0   26.035616
# 1     강원도  강릉시   성산면   0.0   3393.0        3.0     0.0    1.0    5.170550
# 2     강원도  강릉시   왕산면   0.0   1648.0        2.0     0.0    0.0    2.511366
# 3     강원도  강릉시   구정면   0.0   4096.0        5.0     0.0    0.0    6.241843
# 4     강원도  강릉시   강동면   1.0   4690.0        3.0     0.0    0.0    7.147032
# ..    ...  ...   ...   ...      ...        ...     ...    ...         ...
# 638  충청북도  진천군   초평면   1.0   3508.0        4.0     0.0    0.0   40.797959
# 639  충청북도  진천군   문백면   1.0   4147.0        4.0     0.0    0.0   48.229514
# 640  충청북도  진천군   백곡면   1.0   2167.0        2.0     0.0    0.0   25.202160
# 641  충청북도  진천군   이월면   0.0   8078.0        6.0     0.0    0.0   93.946953
# 642  충청북도  진천군  광혜원면   1.0  12009.0        3.0     0.0    0.0  139.664392
#
# [643 rows x 9 columns]

# %%
Total['A'] = Total['예상범죄발생횟수'] / Total['예상범죄발생횟수'].sum()

# %%
Total.head(1)
# Out:
#    시도명 시군구명 읍/면/동  설치유무    등록인구수  어린이보호구역개수  화재발생횟수  관광지개수   예상범죄발생횟수  \
# 0  강원도  강릉시  주문진읍   1.0  17085.0        8.0     0.0    1.0  26.035616
#
#           A
# 0  0.000199

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
features=[['등록인구수','어린이보호구역개수','화재발생횟수','관광지개수']]
for feature in features:
    Total[feature] = scaler.fit_transform(Total[feature])
Total.head(2)
# Out:
#    시도명 시군구명 읍/면/동  설치유무     등록인구수  어린이보호구역개수  화재발생횟수  관광지개수   예상범죄발생횟수  \
# 0  강원도  강릉시  주문진읍   1.0  0.081903     0.1000     0.0    0.2  26.035616
# 1  강원도  강릉시   성산면   0.0  0.015829     0.0375     0.0    0.2   5.170550
#
#           A
# 0  0.000199
# 1  0.000039

# %%
Total = Total.drop('예상범죄횟수',axis=1)
# Total.to_csv('Dataset/Acc/정규화완료.csv',index=0)
# Total = pd.read_csv('Dataset/Acc/정규화완료.csv')
Total
# Out:
#     시군구명 읍/면/동  설치유무     등록인구수  어린이보호구역개수  화재발생횟수  관광지개수    예상범죄비율
# 0    강릉시  주문진읍   1.0  0.081903     0.1000     0.0    0.2  0.000258
# 1    강릉시   성산면   0.0  0.015829     0.0375     0.0    0.2  0.000051
# 2    강릉시   왕산면   0.0  0.007408     0.0250     0.0    0.0  0.000025
# 3    강릉시   구정면   0.0  0.019221     0.0625     0.0    0.0  0.000062
# 4    강릉시   강동면   1.0  0.022088     0.0375     0.0    0.0  0.000071
# ..   ...   ...   ...       ...        ...     ...    ...       ...
# 638  진천군   초평면   1.0  0.016383     0.0500     0.0    0.0  0.002933
# 639  진천군   문백면   1.0  0.019467     0.0500     0.0    0.0  0.003467
# 640  진천군   백곡면   1.0  0.009912     0.0250     0.0    0.0  0.001811
# 641  진천군   이월면   0.0  0.038437     0.0750     0.0    0.0  0.006753
# 642  진천군  광혜원면   1.0  0.057407     0.0375     0.0    0.0  0.010038
#
# [643 rows x 8 columns]

# %%
A = pd.read_csv('Dataset/Acc/Acc/정규화완료.csv')

# %%
A.head(2)
# Out:
#    시도명 시군구명 읍/면/동  설치유무     등록인구수  어린이보호구역개수  화재발생횟수    예상범죄비율
# 0  강원도  강릉시  주문진읍   1.0  0.081903     0.1000     0.0  0.000258
# 1  강원도  강릉시   성산면   0.0  0.015829     0.0375     0.0  0.000051

# %%
A['예상범죄비율'].sum()
# Out:
# 0.9999999999999745

# %%
Test7 = Total[['설치유무','등록인구수','어린이보호구역개수','화재발생횟수','예상범죄발생횟수','관광지개수']]
# Test4.to_csv('Dataset/Acc/Test4.csv',index=0)

# %%
Test6.corr()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-3eac74a05228> in <module>
# ----> 1 Test6.corr()
#
# NameError: name 'Test6' is not defined

# %%
Test6.corr()
# Out:
#                설치유무     등록인구수  어린이보호구역개수    화재발생횟수    예상범죄비율     관광지개수
# 설치유무       1.000000 -0.094284  -0.006521 -0.096913  0.231305  0.091346
# 등록인구수     -0.094284  1.000000   0.811589  0.788874  0.235147  0.006554
# 어린이보호구역개수 -0.006521  0.811589   1.000000  0.741144  0.170189 -0.014155
# 화재발생횟수    -0.096913  0.788874   0.741144  1.000000  0.080852 -0.004895
# 예상범죄비율     0.231305  0.235147   0.170189  0.080852  1.000000  0.078242
# 관광지개수      0.091346  0.006554  -0.014155 -0.004895  0.078242  1.000000

# %%
# 모델 평가 준비 작업
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

# 독립변수, 종속변수 분리
y_t_df = Test7['설치유무'] # 종속변수
X_t_df = Test7.drop('설치유무', axis = 1) # 독립변수

# 독립변수 정규화
# X_t_df = preprocessing.StandardScaler().fit(X_t_df).transform(X_t_df)

# 학습용 데이터와 평가용 데이터를 8:2 혹은 7:3으로 분리
X_train, X_test, y_train, y_test = train_test_split(X_t_df, y_t_df, test_size = 0.2,
                                                   random_state = 11)

print(X_train.shape)
print(X_test.shape)
# Out:
# (514, 5)
# (129, 5)

# %%
# 모델 학습 및 평가
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier()
rf_model.fit(X_train, y_train)
rf_pred = rf_model.predict(X_test)
accuracy_rf = accuracy_score(y_test, rf_pred)

lr_model = LogisticRegression()
lr_model.fit(X_train,y_train)
lr_pred = lr_model.predict(X_test)
accuracy_lr = accuracy_score(y_test,lr_pred)

print('rf 정확도:{}, lr 정확도:{}'.format(accuracy_rf,accuracy_lr))
# Out:
# rf 정확도:0.8527131782945736, lr 정확도:0.8682170542635659

# %%
Test6.to_csv('Dataset/total/Test6.csv',index=0)
