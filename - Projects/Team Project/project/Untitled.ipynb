# %%
import pandas as pd

# %%
City = pd.read_csv('국토교통부_전국 법정동_20201119.csv',encoding='cp949')

# %%
pd.read_excel('한국행정구역분류_2021.7.1.기준.xlsx')
# Out:
#     Unnamed: 0  <한국행정구역분류 사용자 일러두기>  \
# 0          NaN                  NaN
# 1          NaN                  NaN
# 2          NaN         1. 행정구역분류 개요
# 3          NaN               ■ (정의)
# 4          NaN              ■ (목적)
# 5          NaN              ■ (연혁)
# 6          NaN                  NaN
# 7          NaN                  NaN
# 8          NaN        2. 분류 구조 및 특징
# 9          NaN             ■ (코드체계)
# 10         NaN                  NaN
# 11         NaN                  NaN
# 12         NaN                  NaN
# 13         NaN                  NaN
# 14         NaN                  NaN
# 15         NaN                  NaN
# 16         NaN                  NaN
# 17         NaN                  NaN
# 18         NaN                  NaN
# 19         NaN                  NaN
# 20         NaN             ■ (개정방법)
# 21         NaN                  NaN
# 22         NaN                  NaN
# 23         NaN                  NaN
# 24         NaN                  NaN
# ...
