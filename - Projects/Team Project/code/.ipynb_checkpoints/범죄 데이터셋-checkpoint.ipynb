# %%
import pandas as pd

df = pd.read_excel('C:/cakd3/팀프로젝트/범죄발생장소.csv')
df.fillna(0)
df.fillna(0, inplace= True)
df
# Out:
# C:\anaconda3\envs\cakb3\lib\site-packages\openpyxl\styles\stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#     No   자료시점      분류          분류.1          계        계.1     계.2    계.3  \
# 0   No   자료시점      분류            분류          계  아파트,연립다세대    단독주택   고속도로
# 1   No   자료시점      분류            분류        원자료        원자료     원자료    원자료
# 2    1  2019년      총계            총계  1,611,906     96,879  84,895  7,762
# 3    2  2019년    강력범죄      강력범죄(소계)     26,476      3,892   2,725     18
# 4    3  2019년    강력범죄            강간      5,310      1,432     999      0
# 5    4  2019년    강력범죄       강간·강제추행          0          0       0      0
# 6    5  2019년    강력범죄            강도        798        106      89      1
# 7    6  2019년    강력범죄          강제추행     17,120      1,477     934     17
# 8    7  2019년    강력범죄  기타(강간·강제추행등)        325         88      96      0
# ...

# %%
import pandas as pd
df = pd.read_csv('C:/cakd3/팀프로젝트/범죄검거율.txt',delim_whitespace = True)
df.to_csv('C:/cakd3/팀프로젝트/범죄검거율.csv',index=None)

# %%
import pandas as pd

df = pd.read_csv('C:/cakd3/팀프로젝트/범죄검거율.csv')
df.fillna(0)
df.fillna(0, inplace= True)
df
# Out:
#       기간   자치구       합계    합계.1   살인 살인.1   강도 강도.1 강간강제추행 강간강제추행.1      절도  \
# 0     기간   자치구       발생      검거   발생   검거   발생   검거     발생       검거      발생
# 1   2019    합계  103,668  74,805  136  128  136  133  6,469    6,007  42,204
# 2   2019   종로구    3,846   4,117    4    5    7    8    238    1,143   1,515
# 3   2019    중구    4,327   2,804    2    1    6    5    195      115   2,202
# 4   2019   용산구    3,313   2,611    3    3    3    4    272      237     999
# 5   2019   성동구    2,512   1,838    6    5    9   10    133       96     970
# 6   2019   광진구    4,011   2,816    4    5    6    5    273      213   1,875
# 7   2019  동대문구    3,692   2,818    6    6   10    9    168      143   1,531
# 8   2019   중랑구    4,268   3,138   10   10    4    5    138      108   1,666
# 9   2019   성북구    2,877   2,323    3    3    3    3    176      130   1,082
# 10  2019   강북구    3,838   3,023    6    6    3    2    176      145   1,229
# ...
