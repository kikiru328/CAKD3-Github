# %% [markdown]
# Q1

# %%
# <K-digital training 3기>
text = '<K-digital training 3기>'
print(text.capitalize())
# Out:
# <k-digital training 3기>

# %% [markdown]
# Q2

# %%
import requests
URL = 'https://www.youtube.com'
response = requests.get(URL)
print(response.text)
# Out:
# <!DOCTYPE html><html style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" lang="ko-KR" typography typography-spacing><head><meta http-equiv="X-UA-Compatible" content="IE=edge"/><script nonce="83VExPYHxfd4eYZwzflAIw">var ytcfg={d:function(){return window.yt&&yt.config_||ytcfg.data_||(ytcfg.data_={})},get:function(k,o){return k in ytcfg.d()?ytcfg.d()[k]:o},set:function(){var a=arguments;if(a.length>1)ytcfg.d()[a[0]]=a[1];else for(var k in a[0])ytcfg.d()[k]=a[0][k]}};
# window.ytcfg.set('EMERGENCY_BASE_URL', '\/error_204?t\x3djserror\x26level\x3dERROR\x26client.name\x3d1\x26client.version\x3d2.20210701.07.00');</script><script nonce="83VExPYHxfd4eYZwzflAIw">(function(){window.yterr=window.yterr||true;window.unhandledErrorMessages={};window.unhandledErrorCount=0;
# ...

# %%
import urllib
URL ='https://www.youtube.com'
response = urllib.request.urlopen(URL)
byte_data = response.read()
text_data = byte_data.decode('utf-8')
print(text_data)
# Out:
# <!DOCTYPE html><html style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" lang="ko-KR" typography typography-spacing><head><meta http-equiv="X-UA-Compatible" content="IE=edge"/><script nonce="cXbpq2Oy+YsFhMudkLcMeA">var ytcfg={d:function(){return window.yt&&yt.config_||ytcfg.data_||(ytcfg.data_={})},get:function(k,o){return k in ytcfg.d()?ytcfg.d()[k]:o},set:function(){var a=arguments;if(a.length>1)ytcfg.d()[a[0]]=a[1];else for(var k in a[0])ytcfg.d()[k]=a[0][k]}};
# window.ytcfg.set('EMERGENCY_BASE_URL', '\/error_204?t\x3djserror\x26level\x3dERROR\x26client.name\x3d1\x26client.version\x3d2.20210701.07.00');</script><script nonce="cXbpq2Oy+YsFhMudkLcMeA">(function(){window.yterr=window.yterr||true;window.unhandledErrorMessages={};window.unhandledErrorCount=0;
# ...

# %% [markdown]
# Q3

# %%
import re
import requests
URL = 'https://www.youtube.com'
response = requests.get(URL)
html_data = response.text
sp = html_data.split(' title="음악">')[1]
m = re.search('[가-힣]+')
text = (m,sp)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-41-aee615bd87d4> in <module>
#       4 response = requests.get(URL)
#       5 html_data = response.text
# ----> 6 sp = html_data.split(' title="음악">')[1]
#       7 m = re.search('[가-힣]+')
#       8 text = (m,sp)
#
# IndexError: list index out of range

# %% [markdown]
# Q4

# %%
import urllib
img_src = 'https://image.dongascience.com/Photo/2017/03/14900752352661.jpg'
name = 'img.png'
urllib.request.urlretrieve(img_src,name)
# Out:
# ('img.png', <http.client.HTTPMessage at 0x21200c530a0>)

# %% [markdown]
# Q5

# %%
import urllib.request
from bs4 import BeautifulSoup
page = urllib.request.urlopen('https://movie.naver.com/movie/sdb/rank/rmovie.nhn')
soup = BeautifulSoup(page,'html.parser')
rank = soup.find('div',{'class':"title"})
rank1 = rank.text
rank2 = rank.strip(" ")
rank3 = rank2.strip(" ")
rank3[0]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-30-cf7d2d0f9a94> in <module>
#       1 import urllib.request
# ----> 2 from bs4 import BeautifulSoup
#       3 page = urllib.request.urlopen('https://movie.naver.com/movie/sdb/rank/rmovie.nhn')
#       4 soup = BeautifulSoup(page,'html.parser')
#       5 rank = soup.find('div',{'class':"title"})
#
# ModuleNotFoundError: No module named 'bs4'
