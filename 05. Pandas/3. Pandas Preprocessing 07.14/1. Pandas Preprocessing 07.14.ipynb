# %% [markdown]
# ##### Setting

# %%
import pandas as pd
pd.options.display.max_rows = 5 #최대 행 수 설정
pd.get_option('min_rows')
pd.options.display.max_columns = 10 #최대 열 수 설정

# %%
df_auto = pd.read_csv('../Data/auto-mpg.csv')
print('nun ? :' , df_auto.isnull().sum().sum())
print(df_auto.describe)
# Out:
# nun ? : 0
# <bound method NDFrame.describe of       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# ..    ...        ...           ...        ...     ...           ...
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# ..          ...     ...                        ...
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]>

# %%
#mpg : 연비 (meter per gas)
#cylinders : 실린더 (기통)
#displacement
#horsepower : 마력
#acclereation

# %%
#데이터 전처리 (column 변수 = series 생성)
mpg = df_auto['mpg']
cylinders = df_auto['cylinders']
displacement = df_auto['displacement']
horsepower = df_auto['horsepower']
weight = df_auto['weight']
acceleration = df_auto['acceleration']
model_year = df_auto['model year']
origitn = df_auto['origin']
car_name = df_auto['car name']

#column index변경
df_auto
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# ..    ...        ...           ...        ...     ...           ...
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# ..          ...     ...                        ...
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]

# %% [markdown]
# Q. df_auto 데이터세트에 대한 파악 내용을 기술하세요.

# %%
df_auto.columns
new_columns = ['car name','mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
       'acceleration', 'model year', 'origin']
mtcars = df_auto[new_columns]
mtcars.to_csv('../Data/mtcars.csv',index=False)
mtcars = pd.read_csv('../Data/mtcars.csv')
mtcars
# Out:
#                       car name   mpg  cylinders  displacement horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0        130
# 1            buick skylark 320  15.0          8         350.0        165
# ..                         ...   ...        ...           ...        ...
# 396                ford ranger  28.0          4         120.0         79
# 397                 chevy s-10  31.0          4         119.0         82
#
#      weight  acceleration  model year  origin
# 0      3504          12.0          70       1
# 1      3693          11.5          70       1
# ..      ...           ...         ...     ...
# 396    2625          18.6          82       1
# 397    2720          19.4          82       1
#
# [398 rows x 9 columns]

# %%
mtcars.to_csv('../Data/mtcars.csv',index = False)
mtcar = pd.read_csv('../Data/mtcars.csv')
mtcar
# Out:
#                       car name   mpg  cylinders  displacement horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0        130
# 1            buick skylark 320  15.0          8         350.0        165
# ..                         ...   ...        ...           ...        ...
# 396                ford ranger  28.0          4         120.0         79
# 397                 chevy s-10  31.0          4         119.0         82
#
#      weight  acceleration  model year  origin
# 0      3504          12.0          70       1
# 1      3693          11.5          70       1
# ..      ...           ...         ...     ...
# 396    2625          18.6          82       1
# 397    2720          19.4          82       1
#
# [398 rows x 9 columns]

# %%
mtcar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   car name      398 non-null    object
#  1   mpg           398 non-null    float64
#  2   cylinders     398 non-null    int64
#  3   displacement  398 non-null    float64
#  4   horsepower    398 non-null    object
#  5   weight        398 non-null    int64
#  6   acceleration  398 non-null    float64
#  7   model year    398 non-null    int64
#  8   origin        398 non-null    int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
pd.set_option('max_rows', 10)
pd.set_option('max_columns', 10)
mtcar.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
mtcar.horsepower.value_counts()
mtcar.horsepower.unique()
# 결측값 ? 이 있음
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', '?', '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %%
#자동차 연비에 영향을 주는 변수를 선택하여 연비 예측 모델을 생성함.
mcar1 = mtcar.drop(['car name','horsepower'],axis=1)
mcar1
# Out:
#       mpg  cylinders  displacement  weight  acceleration  model year  origin
# 0    18.0          8         307.0    3504          12.0          70       1
# 1    15.0          8         350.0    3693          11.5          70       1
# 2    18.0          8         318.0    3436          11.0          70       1
# 3    16.0          8         304.0    3433          12.0          70       1
# 4    17.0          8         302.0    3449          10.5          70       1
# ..    ...        ...           ...     ...           ...         ...     ...
# 393  27.0          4         140.0    2790          15.6          82       1
# 394  44.0          4          97.0    2130          24.6          82       2
# 395  32.0          4         135.0    2295          11.6          82       1
# 396  28.0          4         120.0    2625          18.6          82       1
# 397  31.0          4         119.0    2720          19.4          82       1
#
# [398 rows x 7 columns]

# %%
mcar1.set_index('mpg',inplace=True)

# %%
mcar1.index
# Out:
# Float64Index([18.0, 15.0, 18.0, 16.0, 17.0, 15.0, 14.0, 14.0, 14.0, 15.0,
#               ...
#               26.0, 22.0, 32.0, 36.0, 27.0, 27.0, 44.0, 32.0, 28.0, 31.0],
#              dtype='float64', name='mpg', length=398)

# %%
mc_range = mcar1[:10]
mc_range
# Out:
#       cylinders  displacement  weight  acceleration  model year  origin
# mpg
# 18.0          8         307.0    3504          12.0          70       1
# 15.0          8         350.0    3693          11.5          70       1
# 18.0          8         318.0    3436          11.0          70       1
# 16.0          8         304.0    3433          12.0          70       1
# 17.0          8         302.0    3449          10.5          70       1
# ...         ...           ...     ...           ...         ...     ...
# 25.0          4         104.0    2375          17.5          70       2
# 26.0          4         121.0    2234          12.5          70       2
# 21.0          6         199.0    2648          15.0          70       1
# 10.0          8         360.0    4615          14.0          70       1
# 10.0          8         307.0    4376          15.0          70       1
#
# [27 rows x 6 columns]

# %%
mc_range = mcar1[10:1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\tool\envs\cakd3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Float64Engine._maybe_get_bool_indexer()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._unpack_bool_indexer()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
import seaborn as sns
import matplotlib as plt
plt.style.use('seaborn-dark')
sns.pairplot(mcar1)
# %config InlineBackend.figure_format = 'retina'

# %%
mcar1.corr() #상관관계
# Out:
#                    mpg  cylinders  displacement    weight  acceleration  \
# mpg           1.000000  -0.775396     -0.804203 -0.831741      0.420289
# cylinders    -0.775396   1.000000      0.950721  0.896017     -0.505419
# displacement -0.804203   0.950721      1.000000  0.932824     -0.543684
# weight       -0.831741   0.896017      0.932824  1.000000     -0.417457
# acceleration  0.420289  -0.505419     -0.543684 -0.417457      1.000000
# model year    0.579267  -0.348746     -0.370164 -0.306564      0.288137
# origin        0.563450  -0.562543     -0.609409 -0.581024      0.205873
#
#               model year    origin
# mpg             0.579267  0.563450
# cylinders      -0.348746 -0.562543
# displacement   -0.370164 -0.609409
# weight         -0.306564 -0.581024
# acceleration    0.288137  0.205873
# model year      1.000000  0.180662
# origin          0.180662  1.000000

# %%
#최적의 컬럼 선택하여 분석용 데이터 셋 구축 - Feature engineering
mcar2 = mcar1[['mpg','weight']]
mcar2.head()
# Out:
#     mpg  weight
# 0  18.0    3504
# 1  15.0    3693
# 2  18.0    3436
# 3  16.0    3433
# 4  17.0    3449

# %%
y = ax + b
# x =weight
# a 기울기 b 절편
y = 3x + 1
y = 5x + 1

# 기울기 == 가중치
# Out:
#   File "<ipython-input-14-b6fe9329b92d>", line 4
#     y = 3x + 1
#          ^
# SyntaxError: invalid syntax

# %%
# Counter
from collections import Counter
my_list = ['a','b','c','a','b','c','a']
count =Counter(my_list)
print(count)
words = dict(count.most_common(n=2))
print(words) # 동값 알파벳순서

# %%
#반올림
import pandas as pd
import numpy as np

col1=np.random.uniform(10,20,size=10)
col2 = np.random.uniform(10,20,size=10)
sr1 = pd.Series(col1,name='col1')
sr2 = pd.Series(col2,name='col2')
df = pd.concat([sr1,sr2],axis = 1)
df = df.round({'col1':2,'col2':1})
df

# %%
df.iloc[1:3,:] = None
df.iloc[1:3,:] = np.nan
df.head(3)

# %%
df.fillna(0,inplace=True)
# df.head()
df = df.astype({'col1':'int','col2':'int'})
df.head()

# %%
df['col0'] = list('abcdefghij')
df.set_index('col0',inplace=True)
df.head()

# %%
df1 = df.copy()
df1.loc['c','col2'] = np.nan
df1.head()

# %% [markdown]
# col2의 평균값으로 null 값 대체

# %%
df1 = df1.fillna(df1['col2'].mean())
df1 = df1.round({'col2':2})
df1.head()

# %%
df1.head()

# %%
#col2를 정수로 변환하여 출력
df1['col2'] = df1['col2'].astype(int)
df1.head()

# %%
df1.iloc[1:3,1:2] = np.nan
df1.head()
df1.dropna(subset=['col2'],inplace=True)
df1.head()

# %%
df1['col2'] = df1.col2.astype(int)

# %%
df1.reset_index()

# %%
df1 = df1.reindex(index=[3,4],columns=['col1','col2'])
df1

# %%
import numpy as np
import pandas as pd

# 1~20까지 연속된 정수를 가지고 4행 5열짜리 데이터를 저장?

# %%
data1 = np.arange(1,21).reshape(4,5)
data2 = np.arange(11,31).reshape(5,4)
df1 = pd.DataFrame(data1,columns=list('abcde'))
df2 = pd.DataFrame(data2,columns=list('dehi'))

df1['ind'] = [1,2,3,4]
df2['ind'] = [1,2,3,4,5]

print(df1,'\n')
print(df2)

# %%
con1 = pd.concat([df1,df2],axis=0)
con1.head()

# %%
con2 = pd.concat([df1,df2],axis=1)
con2

# %%
#merge()를 이용한 결합
#공통된 COLUMN을 이용할때
print(pd.merge(df1,df2,on='ind',how='outer'))
print()
print(pd.merge(df1,df2,on='ind'))  #default = how = 'inner'

# %%
df1 = df1.drop('ind',axis=1)
df2 = df2.drop('ind',axis=1)

# %%
#join은 인덱스 기준으로 결합
#merge는 공통된 column으로 결합
#join의 defalut --> 공통된것만.(교집합) how='inner'
df1.join(df2,lsuffix='_1',rsuffix='_2')

# %%
df1.join(df2,lsuffix='_1',rsuffix='_2',how='outer')

# %%
df1['ind'] = [1,2,3,4]
df2['ind'] = [1,2,3,4,5]

# %%
df1.set_index('ind').join(df2.set_index('ind'),lsuffix='_1', rsuffix='_2')

# %%
df1.set_index('ind').join(df2.set_index('ind'),lsuffix='_1', rsuffix='_2',how = 'outer')

# %%
df_j1 =df1.set_index('ind').join(df2.set_index('ind'),lsuffix='_1', rsuffix='_2',how = 'outer')

# %%
df_j1[['a','b']].mean()

# %%
df_j1.count()

# %%
import pandas as pd
import numpy as np
data = np.arange(1,22).reshape(7,3)
df = pd.DataFrame(data,columns = list('abc'),index=list('1122333'))
df

# %%
df.reset_index(inplace=True)
df

# %%
df.groupby(by ='index')

# %%
data.groupby()
