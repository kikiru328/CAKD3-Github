# %% [markdown]
# # Santander Customer Satisfaction

# %%
# module import

# EDA
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# Seperate
from sklearn.model_selection import train_test_split

# models
from sklearn.metrics import roc_auc_score
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# validation
from sklearn.model_selection import GridSearchCV
# ETC
import warnings
warnings.filterwarnings('ignore')

# %%
# Load data
cust_data = pd.read_csv('../Data/train.csv')
cust_data.head(1)
print(cust_data['TARGET'].value_counts())
unsatisfied_cnt = cust_data[cust_data['TARGET']==1]["TARGET"].count()
total_cnt = cust_data['TARGET'].count()
print("unsatisfied ratio > {:.2f}".format((unsatisfied_cnt/total_cnt)))
# Out:
# 0    73012
# 1     3008
# Name: TARGET, dtype: int64
# unsatisfied ratio > 0.04

# %%
cust_data.describe() # var 3 min == -9999999999
cust_data['var3'] = cust_data['var3'].replace(-999999.000000, 2 ) 
cust_data.drop('ID',axis=1,inplace=True)

# %%
# seperate
X = cust_data.iloc[:,:-1]
y = cust_data.iloc[:,-1]

X_train, X_test, y_train, y_test =  train_test_split(X,y,
                                                    test_size=0.2,
                                                    random_state=150)

train_cnt = y_train.count()
test_cnt = y_test.count()
print(X_train.shape,X_test.shape)
print('학습 분포 비율:\n',y_train.value_counts()/train_cnt)
print('\n 테스트 분포 비율:\n', y_test.value_counts()/test_cnt)
# Out:
# (60816, 369) (15204, 369)
# 학습 분포 비율:
#  0    0.960701
# 1    0.039299
# Name: TARGET, dtype: float64
#
#  테스트 분포 비율:
#  0    0.959353
# 1    0.040647
# Name: TARGET, dtype: float64

# %%
y_train
# Out:
# 45327    0
# 23334    0
# 48217    0
# 12634    0
# 68486    0
#         ..
# 2354     0
# 496      0
# 49177    0
# 28155    0
# 62692    0
# Name: TARGET, Length: 60816, dtype: int64

# %% [markdown]
# ### XGBoost Model

# %%
# models
xgb_clf = XGBClassifier(n_estimators=500, random_state=150)

# %%
# fit
evals = [(X_train,y_train),(X_test,y_test)]
xgb_clf.fit(X_train,y_train,early_stopping_rounds=100,eval_metric="auc",eval_set=evals)
# Out:
# [0]	validation_0-auc:0.82496	validation_1-auc:0.81473
# [1]	validation_0-auc:0.83359	validation_1-auc:0.82282
# [2]	validation_0-auc:0.84137	validation_1-auc:0.82665
# [3]	validation_0-auc:0.84633	validation_1-auc:0.82918
# [4]	validation_0-auc:0.84861	validation_1-auc:0.82973
# [5]	validation_0-auc:0.85185	validation_1-auc:0.83182
# [6]	validation_0-auc:0.85599	validation_1-auc:0.83561
# [7]	validation_0-auc:0.85908	validation_1-auc:0.83554
# [8]	validation_0-auc:0.86367	validation_1-auc:0.83485
# [9]	validation_0-auc:0.86616	validation_1-auc:0.83632
# [10]	validation_0-auc:0.86949	validation_1-auc:0.83733
# [11]	validation_0-auc:0.87153	validation_1-auc:0.83751
# [12]	validation_0-auc:0.87418	validation_1-auc:0.83832
# [13]	validation_0-auc:0.87696	validation_1-auc:0.83890
# [14]	validation_0-auc:0.87867	validation_1-auc:0.83840
# [15]	validation_0-auc:0.88074	validation_1-auc:0.83924
# [16]	validation_0-auc:0.88313	validation_1-auc:0.84013
# [17]	validation_0-auc:0.88407	validation_1-auc:0.83973
# [18]	validation_0-auc:0.88514	validation_1-auc:0.83974
# [19]	validation_0-auc:0.88679	validation_1-auc:0.83927
# [20]	validation_0-auc:0.88816	validation_1-auc:0.84015
# [21]	validation_0-auc:0.88908	validation_1-auc:0.84012
# [22]	validation_0-auc:0.89114	validation_1-auc:0.83992
# [23]	validation_0-auc:0.89141	validation_1-auc:0.84014
# [24]	validation_0-auc:0.89189	validation_1-auc:0.83981
# [25]	validation_0-auc:0.89420	validation_1-auc:0.83860
# [26]	validation_0-auc:0.89496	validation_1-auc:0.83811
# [27]	validation_0-auc:0.89614	validation_1-auc:0.83832
# [28]	validation_0-auc:0.89631	validation_1-auc:0.83840
# [29]	validation_0-auc:0.89750	validation_1-auc:0.83834
# [30]	validation_0-auc:0.89810	validation_1-auc:0.83830
# [31]	validation_0-auc:0.89935	validation_1-auc:0.83862
# [32]	validation_0-auc:0.90033	validation_1-auc:0.83843
# [33]	validation_0-auc:0.90117	validation_1-auc:0.83762
# [34]	validation_0-auc:0.90220	validation_1-auc:0.83865
# [35]	validation_0-auc:0.90292	validation_1-auc:0.83840
# [36]	validation_0-auc:0.90323	validation_1-auc:0.83828
# [37]	validation_0-auc:0.90370	validation_1-auc:0.83836
# [38]	validation_0-auc:0.90409	validation_1-auc:0.83876
# [39]	validation_0-auc:0.90524	validation_1-auc:0.83782
# [40]	validation_0-auc:0.90542	validation_1-auc:0.83781
# [41]	validation_0-auc:0.90558	validation_1-auc:0.83783
# [42]	validation_0-auc:0.90643	validation_1-auc:0.83785
# [43]	validation_0-auc:0.90662	validation_1-auc:0.83759
# [44]	validation_0-auc:0.90698	validation_1-auc:0.83742
# [45]	validation_0-auc:0.90714	validation_1-auc:0.83719
# [46]	validation_0-auc:0.90755	validation_1-auc:0.83719
# [47]	validation_0-auc:0.90875	validation_1-auc:0.83760
# [48]	validation_0-auc:0.90926	validation_1-auc:0.83770
# [49]	validation_0-auc:0.90948	validation_1-auc:0.83780
# [50]	validation_0-auc:0.90964	validation_1-auc:0.83753
# [51]	validation_0-auc:0.90987	validation_1-auc:0.83724
# [52]	validation_0-auc:0.91063	validation_1-auc:0.83688
# [53]	validation_0-auc:0.91178	validation_1-auc:0.83534
# [54]	validation_0-auc:0.91343	validation_1-auc:0.83500
# [55]	validation_0-auc:0.91353	validation_1-auc:0.83491
# [56]	validation_0-auc:0.91371	validation_1-auc:0.83493
# [57]	validation_0-auc:0.91464	validation_1-auc:0.83442
# [58]	validation_0-auc:0.91473	validation_1-auc:0.83460
# [59]	validation_0-auc:0.91483	validation_1-auc:0.83460
# [60]	validation_0-auc:0.91589	validation_1-auc:0.83396
# [61]	validation_0-auc:0.91613	validation_1-auc:0.83384
# [62]	validation_0-auc:0.91642	validation_1-auc:0.83327
# [63]	validation_0-auc:0.91648	validation_1-auc:0.83313
# [64]	validation_0-auc:0.91662	validation_1-auc:0.83304
# [65]	validation_0-auc:0.91739	validation_1-auc:0.83303
# [66]	validation_0-auc:0.91890	validation_1-auc:0.83276
# [67]	validation_0-auc:0.91925	validation_1-auc:0.83262
# [68]	validation_0-auc:0.91956	validation_1-auc:0.83245
# [69]	validation_0-auc:0.92039	validation_1-auc:0.83198
# [70]	validation_0-auc:0.92049	validation_1-auc:0.83177
# [71]	validation_0-auc:0.92056	validation_1-auc:0.83172
# [72]	validation_0-auc:0.92069	validation_1-auc:0.83182
# [73]	validation_0-auc:0.92157	validation_1-auc:0.83099
# [74]	validation_0-auc:0.92171	validation_1-auc:0.83076
# [75]	validation_0-auc:0.92193	validation_1-auc:0.83014
# [76]	validation_0-auc:0.92272	validation_1-auc:0.82976
# [77]	validation_0-auc:0.92288	validation_1-auc:0.82997
# [78]	validation_0-auc:0.92319	validation_1-auc:0.82997
# [79]	validation_0-auc:0.92443	validation_1-auc:0.82962
# [80]	validation_0-auc:0.92566	validation_1-auc:0.82923
# [81]	validation_0-auc:0.92632	validation_1-auc:0.82905
# [82]	validation_0-auc:0.92658	validation_1-auc:0.82896
# [83]	validation_0-auc:0.92721	validation_1-auc:0.82881
# [84]	validation_0-auc:0.92788	validation_1-auc:0.82880
# [85]	validation_0-auc:0.92802	validation_1-auc:0.82866
# [86]	validation_0-auc:0.92851	validation_1-auc:0.82840
# [87]	validation_0-auc:0.92874	validation_1-auc:0.82839
# [88]	validation_0-auc:0.92897	validation_1-auc:0.82815
# [89]	validation_0-auc:0.92992	validation_1-auc:0.82726
# [90]	validation_0-auc:0.93028	validation_1-auc:0.82656
# [91]	validation_0-auc:0.93096	validation_1-auc:0.82626
# [92]	validation_0-auc:0.93167	validation_1-auc:0.82617
# [93]	validation_0-auc:0.93173	validation_1-auc:0.82615
# [94]	validation_0-auc:0.93186	validation_1-auc:0.82572
# [95]	validation_0-auc:0.93216	validation_1-auc:0.82579
# [96]	validation_0-auc:0.93224	validation_1-auc:0.82571
# [97]	validation_0-auc:0.93239	validation_1-auc:0.82521
# [98]	validation_0-auc:0.93258	validation_1-auc:0.82508
# [99]	validation_0-auc:0.93265	validation_1-auc:0.82501
# [100]	validation_0-auc:0.93301	validation_1-auc:0.82431
# [101]	validation_0-auc:0.93350	validation_1-auc:0.82388
# [102]	validation_0-auc:0.93364	validation_1-auc:0.82354
# [103]	validation_0-auc:0.93416	validation_1-auc:0.82337
# [104]	validation_0-auc:0.93469	validation_1-auc:0.82317
# [105]	validation_0-auc:0.93497	validation_1-auc:0.82367
# [106]	validation_0-auc:0.93539	validation_1-auc:0.82312
# [107]	validation_0-auc:0.93557	validation_1-auc:0.82296
# [108]	validation_0-auc:0.93592	validation_1-auc:0.82273
# [109]	validation_0-auc:0.93606	validation_1-auc:0.82256
# [110]	validation_0-auc:0.93658	validation_1-auc:0.82210
# [111]	validation_0-auc:0.93668	validation_1-auc:0.82191
# [112]	validation_0-auc:0.93741	validation_1-auc:0.82081
# [113]	validation_0-auc:0.93749	validation_1-auc:0.82065
# [114]	validation_0-auc:0.93763	validation_1-auc:0.82051
# [115]	validation_0-auc:0.93765	validation_1-auc:0.82043
# [116]	validation_0-auc:0.93782	validation_1-auc:0.82041
# [117]	validation_0-auc:0.93784	validation_1-auc:0.82035
# [118]	validation_0-auc:0.93789	validation_1-auc:0.82035
# [119]	validation_0-auc:0.93807	validation_1-auc:0.82056
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=500, n_jobs=12, num_parallel_tree=1,
#               random_state=150, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#               subsample=1, tree_method='exact', validate_parameters=1,
#               verbosity=None)

# %%
# predict
xgb_clf_preds = xgb_clf.predict(X_test)
xgb_clf_proba = xgb_clf.predict_proba(X_test)[:,1]

# %%
# roc_auc
xgb_clf_auc = roc_auc_score(y_test, xgb_clf_proba, average='macro')
print("roc_auc : {0:.4f}".format(xgb_clf_auc))
# Out:
# roc_auc : 0.8402

# %%
# 2nd validation
from sklearn.model_selection import GridSearchCV
xgb_clf = XGBClassifier(n_estimators=100)
params = {'max_depth':[5,7],'min_child_weight':[1,3],
         'colsample_bytree':[0.5,0.75]}
gridcv = GridSearchCV(xgb_clf,param_grid=params,cv=3)
gridcv.fit(X_train,y_train,early_stopping_rounds=30,
           eval_metric='auc',
          eval_set=[(X_train,y_train),(X_test,y_test)])
print('GV 최적 파라미터:', gridcv.best_params_)
xgb_roc_score = roc_auc_score(y_test,gridcv.predict_proba(X_test)[:,1])
print('AUC:{:.4f}'.format(xgb_roc_score))
# Out:
# [0]	validation_0-auc:0.80729	validation_1-auc:0.79441
# [1]	validation_0-auc:0.81724	validation_1-auc:0.80286
# [2]	validation_0-auc:0.82363	validation_1-auc:0.81132
# [3]	validation_0-auc:0.82988	validation_1-auc:0.81728
# [4]	validation_0-auc:0.83261	validation_1-auc:0.82028
# [5]	validation_0-auc:0.83461	validation_1-auc:0.81962
# [6]	validation_0-auc:0.83276	validation_1-auc:0.81758
# [7]	validation_0-auc:0.84359	validation_1-auc:0.82437
# [8]	validation_0-auc:0.84671	validation_1-auc:0.82665
# [9]	validation_0-auc:0.84815	validation_1-auc:0.82362
# [10]	validation_0-auc:0.84744	validation_1-auc:0.82007
# [11]	validation_0-auc:0.84790	validation_1-auc:0.81824
# [12]	validation_0-auc:0.85346	validation_1-auc:0.82656
# [13]	validation_0-auc:0.85699	validation_1-auc:0.82975
# [14]	validation_0-auc:0.85938	validation_1-auc:0.83134
# [15]	validation_0-auc:0.86102	validation_1-auc:0.83040
# [16]	validation_0-auc:0.86258	validation_1-auc:0.83243
# [17]	validation_0-auc:0.86442	validation_1-auc:0.83319
# [18]	validation_0-auc:0.86512	validation_1-auc:0.83277
# [19]	validation_0-auc:0.86584	validation_1-auc:0.83425
# [20]	validation_0-auc:0.86640	validation_1-auc:0.83451
# [21]	validation_0-auc:0.86758	validation_1-auc:0.83358
# [22]	validation_0-auc:0.86843	validation_1-auc:0.83453
# [23]	validation_0-auc:0.86949	validation_1-auc:0.83423
# [24]	validation_0-auc:0.87012	validation_1-auc:0.83488
# [25]	validation_0-auc:0.87073	validation_1-auc:0.83458
# [26]	validation_0-auc:0.87097	validation_1-auc:0.83467
# [27]	validation_0-auc:0.87133	validation_1-auc:0.83486
# [28]	validation_0-auc:0.87149	validation_1-auc:0.83483
# [29]	validation_0-auc:0.87259	validation_1-auc:0.83452
# [30]	validation_0-auc:0.87407	validation_1-auc:0.83296
# [31]	validation_0-auc:0.87435	validation_1-auc:0.83325
# [32]	validation_0-auc:0.87469	validation_1-auc:0.83285
# [33]	validation_0-auc:0.87484	validation_1-auc:0.83260
# [34]	validation_0-auc:0.87498	validation_1-auc:0.83264
# [35]	validation_0-auc:0.87534	validation_1-auc:0.83225
# [36]	validation_0-auc:0.87562	validation_1-auc:0.83223
# [37]	validation_0-auc:0.87648	validation_1-auc:0.83181
# [38]	validation_0-auc:0.87718	validation_1-auc:0.83184
# [39]	validation_0-auc:0.87800	validation_1-auc:0.83204
# [40]	validation_0-auc:0.87810	validation_1-auc:0.83213
# [41]	validation_0-auc:0.87845	validation_1-auc:0.83186
# [42]	validation_0-auc:0.87873	validation_1-auc:0.83170
# [43]	validation_0-auc:0.87886	validation_1-auc:0.83143
# [44]	validation_0-auc:0.87966	validation_1-auc:0.83096
# [45]	validation_0-auc:0.87986	validation_1-auc:0.83096
# [46]	validation_0-auc:0.88033	validation_1-auc:0.83077
# [47]	validation_0-auc:0.88150	validation_1-auc:0.83040
# [48]	validation_0-auc:0.88169	validation_1-auc:0.83007
# [49]	validation_0-auc:0.88226	validation_1-auc:0.83009
# [50]	validation_0-auc:0.88235	validation_1-auc:0.83025
# [51]	validation_0-auc:0.88249	validation_1-auc:0.82993
# [52]	validation_0-auc:0.88277	validation_1-auc:0.82950
# [53]	validation_0-auc:0.88284	validation_1-auc:0.82971
# [0]	validation_0-auc:0.79994	validation_1-auc:0.79114
# [1]	validation_0-auc:0.81614	validation_1-auc:0.80134
# [2]	validation_0-auc:0.83056	validation_1-auc:0.81865
# [3]	validation_0-auc:0.83290	validation_1-auc:0.82046
# [4]	validation_0-auc:0.83473	validation_1-auc:0.82190
# [5]	validation_0-auc:0.83478	validation_1-auc:0.82054
# [6]	validation_0-auc:0.83311	validation_1-auc:0.82040
# [7]	validation_0-auc:0.84057	validation_1-auc:0.82455
# [8]	validation_0-auc:0.84646	validation_1-auc:0.82868
# [9]	validation_0-auc:0.84657	validation_1-auc:0.82484
# [10]	validation_0-auc:0.84666	validation_1-auc:0.82089
# [11]	validation_0-auc:0.84601	validation_1-auc:0.81809
# [12]	validation_0-auc:0.85287	validation_1-auc:0.82820
# [13]	validation_0-auc:0.85704	validation_1-auc:0.83300
# [14]	validation_0-auc:0.85878	validation_1-auc:0.83506
# [15]	validation_0-auc:0.85925	validation_1-auc:0.83415
# [16]	validation_0-auc:0.86065	validation_1-auc:0.83587
# [17]	validation_0-auc:0.86293	validation_1-auc:0.83646
# [18]	validation_0-auc:0.86462	validation_1-auc:0.83617
# [19]	validation_0-auc:0.86571	validation_1-auc:0.83732
# [20]	validation_0-auc:0.86652	validation_1-auc:0.83776
# [21]	validation_0-auc:0.86735	validation_1-auc:0.83749
# [22]	validation_0-auc:0.86805	validation_1-auc:0.83762
# [23]	validation_0-auc:0.86876	validation_1-auc:0.83756
# [24]	validation_0-auc:0.86925	validation_1-auc:0.83826
# [25]	validation_0-auc:0.86977	validation_1-auc:0.83981
# [26]	validation_0-auc:0.87057	validation_1-auc:0.83871
# [27]	validation_0-auc:0.87119	validation_1-auc:0.83906
# [28]	validation_0-auc:0.87160	validation_1-auc:0.83894
# [29]	validation_0-auc:0.87227	validation_1-auc:0.83891
# [30]	validation_0-auc:0.87288	validation_1-auc:0.83898
# [31]	validation_0-auc:0.87301	validation_1-auc:0.83907
# [32]	validation_0-auc:0.87337	validation_1-auc:0.83867
# [33]	validation_0-auc:0.87357	validation_1-auc:0.83912
# [34]	validation_0-auc:0.87438	validation_1-auc:0.83898
# [35]	validation_0-auc:0.87530	validation_1-auc:0.83985
# [36]	validation_0-auc:0.87644	validation_1-auc:0.83931
# [37]	validation_0-auc:0.87692	validation_1-auc:0.83872
# [38]	validation_0-auc:0.87726	validation_1-auc:0.83903
# [39]	validation_0-auc:0.87752	validation_1-auc:0.83880
# [40]	validation_0-auc:0.87770	validation_1-auc:0.83877
# [41]	validation_0-auc:0.87796	validation_1-auc:0.83850
# [42]	validation_0-auc:0.87826	validation_1-auc:0.83867
# [43]	validation_0-auc:0.87837	validation_1-auc:0.83886
# [44]	validation_0-auc:0.87847	validation_1-auc:0.83894
# [45]	validation_0-auc:0.87869	validation_1-auc:0.83889
# [46]	validation_0-auc:0.87884	validation_1-auc:0.83890
# [47]	validation_0-auc:0.87970	validation_1-auc:0.83899
# [48]	validation_0-auc:0.87988	validation_1-auc:0.83835
# [49]	validation_0-auc:0.88042	validation_1-auc:0.83809
# [50]	validation_0-auc:0.88052	validation_1-auc:0.83766
# [51]	validation_0-auc:0.88066	validation_1-auc:0.83764
# [52]	validation_0-auc:0.88100	validation_1-auc:0.83719
# [53]	validation_0-auc:0.88121	validation_1-auc:0.83700
# [54]	validation_0-auc:0.88133	validation_1-auc:0.83710
# [55]	validation_0-auc:0.88196	validation_1-auc:0.83698
# [56]	validation_0-auc:0.88208	validation_1-auc:0.83696
# [57]	validation_0-auc:0.88218	validation_1-auc:0.83678
# [58]	validation_0-auc:0.88240	validation_1-auc:0.83666
# [59]	validation_0-auc:0.88249	validation_1-auc:0.83645
# [60]	validation_0-auc:0.88266	validation_1-auc:0.83629
# [61]	validation_0-auc:0.88339	validation_1-auc:0.83589
# [62]	validation_0-auc:0.88418	validation_1-auc:0.83554
# [63]	validation_0-auc:0.88458	validation_1-auc:0.83544
# [64]	validation_0-auc:0.88498	validation_1-auc:0.83527
# [0]	validation_0-auc:0.79832	validation_1-auc:0.78700
# [1]	validation_0-auc:0.82126	validation_1-auc:0.81188
# [2]	validation_0-auc:0.83036	validation_1-auc:0.81928
# [3]	validation_0-auc:0.83342	validation_1-auc:0.82588
# [4]	validation_0-auc:0.83805	validation_1-auc:0.82618
# [5]	validation_0-auc:0.83965	validation_1-auc:0.82661
# [6]	validation_0-auc:0.83767	validation_1-auc:0.82510
# [7]	validation_0-auc:0.84501	validation_1-auc:0.82884
# [8]	validation_0-auc:0.84807	validation_1-auc:0.83096
# [9]	validation_0-auc:0.84962	validation_1-auc:0.82886
# [10]	validation_0-auc:0.84950	validation_1-auc:0.82602
# [11]	validation_0-auc:0.84992	validation_1-auc:0.82559
# [12]	validation_0-auc:0.85437	validation_1-auc:0.83068
# [13]	validation_0-auc:0.85732	validation_1-auc:0.83421
# [14]	validation_0-auc:0.85905	validation_1-auc:0.83628
# [15]	validation_0-auc:0.86021	validation_1-auc:0.83485
# [16]	validation_0-auc:0.86150	validation_1-auc:0.83643
# [17]	validation_0-auc:0.86206	validation_1-auc:0.83659
# [18]	validation_0-auc:0.86290	validation_1-auc:0.83567
# [19]	validation_0-auc:0.86417	validation_1-auc:0.83585
# [20]	validation_0-auc:0.86499	validation_1-auc:0.83608
# [21]	validation_0-auc:0.86528	validation_1-auc:0.83591
# [22]	validation_0-auc:0.86625	validation_1-auc:0.83620
# [23]	validation_0-auc:0.86666	validation_1-auc:0.83548
# [24]	validation_0-auc:0.86713	validation_1-auc:0.83546
# [25]	validation_0-auc:0.86801	validation_1-auc:0.83538
# [26]	validation_0-auc:0.86892	validation_1-auc:0.83575
# [27]	validation_0-auc:0.86938	validation_1-auc:0.83585
# [28]	validation_0-auc:0.86968	validation_1-auc:0.83527
# [29]	validation_0-auc:0.86996	validation_1-auc:0.83501
# [30]	validation_0-auc:0.87021	validation_1-auc:0.83456
# [31]	validation_0-auc:0.87141	validation_1-auc:0.83464
# [32]	validation_0-auc:0.87191	validation_1-auc:0.83419
# [33]	validation_0-auc:0.87211	validation_1-auc:0.83443
# [34]	validation_0-auc:0.87314	validation_1-auc:0.83371
# [35]	validation_0-auc:0.87323	validation_1-auc:0.83361
# [36]	validation_0-auc:0.87411	validation_1-auc:0.83377
# [37]	validation_0-auc:0.87470	validation_1-auc:0.83428
# [38]	validation_0-auc:0.87539	validation_1-auc:0.83364
# [39]	validation_0-auc:0.87581	validation_1-auc:0.83336
# [40]	validation_0-auc:0.87598	validation_1-auc:0.83341
# [41]	validation_0-auc:0.87604	validation_1-auc:0.83322
# [42]	validation_0-auc:0.87694	validation_1-auc:0.83321
# [43]	validation_0-auc:0.87713	validation_1-auc:0.83300
# [44]	validation_0-auc:0.87723	validation_1-auc:0.83303
# [45]	validation_0-auc:0.87723	validation_1-auc:0.83297
# [46]	validation_0-auc:0.87758	validation_1-auc:0.83225
# [47]	validation_0-auc:0.87791	validation_1-auc:0.83233
# [0]	validation_0-auc:0.80805	validation_1-auc:0.79559
# [1]	validation_0-auc:0.81760	validation_1-auc:0.80196
# [2]	validation_0-auc:0.82816	validation_1-auc:0.81577
# [3]	validation_0-auc:0.83167	validation_1-auc:0.81756
# [4]	validation_0-auc:0.83462	validation_1-auc:0.81978
# [5]	validation_0-auc:0.83588	validation_1-auc:0.81939
# [6]	validation_0-auc:0.83422	validation_1-auc:0.81775
# [7]	validation_0-auc:0.84335	validation_1-auc:0.82412
# [8]	validation_0-auc:0.84725	validation_1-auc:0.82642
# [9]	validation_0-auc:0.84804	validation_1-auc:0.82288
# [10]	validation_0-auc:0.84731	validation_1-auc:0.81926
# [11]	validation_0-auc:0.84684	validation_1-auc:0.81798
# [12]	validation_0-auc:0.85197	validation_1-auc:0.82535
# [13]	validation_0-auc:0.85592	validation_1-auc:0.82911
# [14]	validation_0-auc:0.85740	validation_1-auc:0.83131
# [15]	validation_0-auc:0.85899	validation_1-auc:0.83011
# [16]	validation_0-auc:0.86055	validation_1-auc:0.83259
# [17]	validation_0-auc:0.86173	validation_1-auc:0.83302
# [18]	validation_0-auc:0.86261	validation_1-auc:0.83256
# [19]	validation_0-auc:0.86363	validation_1-auc:0.83238
# [20]	validation_0-auc:0.86406	validation_1-auc:0.83178
# [21]	validation_0-auc:0.86466	validation_1-auc:0.83217
# [22]	validation_0-auc:0.86552	validation_1-auc:0.83262
# [23]	validation_0-auc:0.86604	validation_1-auc:0.83312
# [24]	validation_0-auc:0.86729	validation_1-auc:0.83424
# [25]	validation_0-auc:0.86742	validation_1-auc:0.83460
# [26]	validation_0-auc:0.86824	validation_1-auc:0.83446
# [27]	validation_0-auc:0.86853	validation_1-auc:0.83451
# [28]	validation_0-auc:0.86892	validation_1-auc:0.83434
# [29]	validation_0-auc:0.86914	validation_1-auc:0.83385
# [30]	validation_0-auc:0.86951	validation_1-auc:0.83357
# [31]	validation_0-auc:0.87037	validation_1-auc:0.83299
# [32]	validation_0-auc:0.87118	validation_1-auc:0.83259
# [33]	validation_0-auc:0.87136	validation_1-auc:0.83228
# [34]	validation_0-auc:0.87172	validation_1-auc:0.83202
# [35]	validation_0-auc:0.87259	validation_1-auc:0.83161
# [36]	validation_0-auc:0.87364	validation_1-auc:0.83121
# [37]	validation_0-auc:0.87384	validation_1-auc:0.83037
# [38]	validation_0-auc:0.87409	validation_1-auc:0.83055
# [39]	validation_0-auc:0.87517	validation_1-auc:0.82968
# [40]	validation_0-auc:0.87526	validation_1-auc:0.82951
# [41]	validation_0-auc:0.87549	validation_1-auc:0.82930
# [42]	validation_0-auc:0.87563	validation_1-auc:0.82939
# [43]	validation_0-auc:0.87617	validation_1-auc:0.82864
# [44]	validation_0-auc:0.87768	validation_1-auc:0.82751
# [45]	validation_0-auc:0.87791	validation_1-auc:0.82674
# [46]	validation_0-auc:0.87827	validation_1-auc:0.82664
# [47]	validation_0-auc:0.87919	validation_1-auc:0.82623
# [48]	validation_0-auc:0.87964	validation_1-auc:0.82595
# [49]	validation_0-auc:0.88028	validation_1-auc:0.82633
# [50]	validation_0-auc:0.88111	validation_1-auc:0.82558
# [51]	validation_0-auc:0.88131	validation_1-auc:0.82526
# [52]	validation_0-auc:0.88163	validation_1-auc:0.82547
# [53]	validation_0-auc:0.88179	validation_1-auc:0.82521
# [54]	validation_0-auc:0.88217	validation_1-auc:0.82500
# [55]	validation_0-auc:0.88260	validation_1-auc:0.82479
# [0]	validation_0-auc:0.80182	validation_1-auc:0.79088
# [1]	validation_0-auc:0.81553	validation_1-auc:0.80124
# [2]	validation_0-auc:0.83092	validation_1-auc:0.82054
# [3]	validation_0-auc:0.83316	validation_1-auc:0.82310
# [4]	validation_0-auc:0.83428	validation_1-auc:0.82429
# [5]	validation_0-auc:0.83448	validation_1-auc:0.82163
# [6]	validation_0-auc:0.83263	validation_1-auc:0.81976
# [7]	validation_0-auc:0.83920	validation_1-auc:0.82535
# [8]	validation_0-auc:0.84534	validation_1-auc:0.82870
# [9]	validation_0-auc:0.84609	validation_1-auc:0.82520
# [10]	validation_0-auc:0.84548	validation_1-auc:0.82075
# [11]	validation_0-auc:0.84484	validation_1-auc:0.81710
# [12]	validation_0-auc:0.85096	validation_1-auc:0.82736
# [13]	validation_0-auc:0.85466	validation_1-auc:0.83215
# [14]	validation_0-auc:0.85694	validation_1-auc:0.83576
# [15]	validation_0-auc:0.85820	validation_1-auc:0.83486
# [16]	validation_0-auc:0.85945	validation_1-auc:0.83593
# [17]	validation_0-auc:0.86105	validation_1-auc:0.83620
# [18]	validation_0-auc:0.86220	validation_1-auc:0.83616
# [19]	validation_0-auc:0.86300	validation_1-auc:0.83691
# [20]	validation_0-auc:0.86332	validation_1-auc:0.83675
# [21]	validation_0-auc:0.86414	validation_1-auc:0.83601
# [22]	validation_0-auc:0.86445	validation_1-auc:0.83617
# [23]	validation_0-auc:0.86509	validation_1-auc:0.83673
# [24]	validation_0-auc:0.86545	validation_1-auc:0.83686
# [25]	validation_0-auc:0.86651	validation_1-auc:0.83720
# [26]	validation_0-auc:0.86727	validation_1-auc:0.83643
# [27]	validation_0-auc:0.86747	validation_1-auc:0.83661
# [28]	validation_0-auc:0.86820	validation_1-auc:0.83601
# [29]	validation_0-auc:0.86878	validation_1-auc:0.83562
# [30]	validation_0-auc:0.86969	validation_1-auc:0.83529
# [31]	validation_0-auc:0.86981	validation_1-auc:0.83506
# [32]	validation_0-auc:0.87119	validation_1-auc:0.83461
# [33]	validation_0-auc:0.87159	validation_1-auc:0.83477
# [34]	validation_0-auc:0.87190	validation_1-auc:0.83443
# [35]	validation_0-auc:0.87245	validation_1-auc:0.83366
# [36]	validation_0-auc:0.87260	validation_1-auc:0.83335
# [37]	validation_0-auc:0.87290	validation_1-auc:0.83347
# [38]	validation_0-auc:0.87307	validation_1-auc:0.83347
# [39]	validation_0-auc:0.87331	validation_1-auc:0.83391
# [40]	validation_0-auc:0.87333	validation_1-auc:0.83393
# [41]	validation_0-auc:0.87341	validation_1-auc:0.83404
# [42]	validation_0-auc:0.87387	validation_1-auc:0.83380
# [43]	validation_0-auc:0.87384	validation_1-auc:0.83382
# [44]	validation_0-auc:0.87396	validation_1-auc:0.83346
# [45]	validation_0-auc:0.87422	validation_1-auc:0.83347
# [46]	validation_0-auc:0.87425	validation_1-auc:0.83356
# [47]	validation_0-auc:0.87457	validation_1-auc:0.83356
# [48]	validation_0-auc:0.87472	validation_1-auc:0.83355
# [49]	validation_0-auc:0.87560	validation_1-auc:0.83401
# [50]	validation_0-auc:0.87564	validation_1-auc:0.83386
# [51]	validation_0-auc:0.87600	validation_1-auc:0.83353
# [52]	validation_0-auc:0.87623	validation_1-auc:0.83330
# [53]	validation_0-auc:0.87642	validation_1-auc:0.83270
# [54]	validation_0-auc:0.87702	validation_1-auc:0.83196
# [0]	validation_0-auc:0.79870	validation_1-auc:0.78906
# [1]	validation_0-auc:0.82047	validation_1-auc:0.81429
# [2]	validation_0-auc:0.82958	validation_1-auc:0.82023
# [3]	validation_0-auc:0.83337	validation_1-auc:0.82595
# [4]	validation_0-auc:0.83969	validation_1-auc:0.82623
# [5]	validation_0-auc:0.84223	validation_1-auc:0.82863
# [6]	validation_0-auc:0.83923	validation_1-auc:0.82535
# [7]	validation_0-auc:0.84488	validation_1-auc:0.82899
# [8]	validation_0-auc:0.84809	validation_1-auc:0.83217
# [9]	validation_0-auc:0.84909	validation_1-auc:0.82795
# [10]	validation_0-auc:0.84804	validation_1-auc:0.82483
# [11]	validation_0-auc:0.84820	validation_1-auc:0.82413
# [12]	validation_0-auc:0.85312	validation_1-auc:0.83008
# [13]	validation_0-auc:0.85635	validation_1-auc:0.83299
# [14]	validation_0-auc:0.85722	validation_1-auc:0.83539
# [15]	validation_0-auc:0.85854	validation_1-auc:0.83595
# [16]	validation_0-auc:0.85991	validation_1-auc:0.83781
# [17]	validation_0-auc:0.86069	validation_1-auc:0.83848
# [18]	validation_0-auc:0.86174	validation_1-auc:0.83763
# [19]	validation_0-auc:0.86335	validation_1-auc:0.83839
# [20]	validation_0-auc:0.86368	validation_1-auc:0.83802
# [21]	validation_0-auc:0.86389	validation_1-auc:0.83775
# [22]	validation_0-auc:0.86461	validation_1-auc:0.83799
# [23]	validation_0-auc:0.86528	validation_1-auc:0.83848
# [24]	validation_0-auc:0.86570	validation_1-auc:0.83810
# [25]	validation_0-auc:0.86675	validation_1-auc:0.83814
# [26]	validation_0-auc:0.86753	validation_1-auc:0.83750
# [27]	validation_0-auc:0.86833	validation_1-auc:0.83806
# [28]	validation_0-auc:0.86849	validation_1-auc:0.83783
# [29]	validation_0-auc:0.86928	validation_1-auc:0.83828
# [30]	validation_0-auc:0.86956	validation_1-auc:0.83840
# [31]	validation_0-auc:0.87008	validation_1-auc:0.83918
# [32]	validation_0-auc:0.87023	validation_1-auc:0.83911
# [33]	validation_0-auc:0.87055	validation_1-auc:0.83874
# [34]	validation_0-auc:0.87109	validation_1-auc:0.83832
# [35]	validation_0-auc:0.87140	validation_1-auc:0.83847
# [36]	validation_0-auc:0.87166	validation_1-auc:0.83849
# [37]	validation_0-auc:0.87229	validation_1-auc:0.83806
# [38]	validation_0-auc:0.87267	validation_1-auc:0.83733
# [39]	validation_0-auc:0.87298	validation_1-auc:0.83805
# [40]	validation_0-auc:0.87316	validation_1-auc:0.83776
# [41]	validation_0-auc:0.87375	validation_1-auc:0.83832
# [42]	validation_0-auc:0.87454	validation_1-auc:0.83796
# [43]	validation_0-auc:0.87459	validation_1-auc:0.83806
# [44]	validation_0-auc:0.87470	validation_1-auc:0.83786
# [45]	validation_0-auc:0.87477	validation_1-auc:0.83803
# [46]	validation_0-auc:0.87557	validation_1-auc:0.83788
# [47]	validation_0-auc:0.87571	validation_1-auc:0.83761
# [48]	validation_0-auc:0.87601	validation_1-auc:0.83710
# [49]	validation_0-auc:0.87603	validation_1-auc:0.83671
# [50]	validation_0-auc:0.87609	validation_1-auc:0.83673
# [51]	validation_0-auc:0.87615	validation_1-auc:0.83652
# [52]	validation_0-auc:0.87636	validation_1-auc:0.83665
# [53]	validation_0-auc:0.87651	validation_1-auc:0.83649
# [54]	validation_0-auc:0.87673	validation_1-auc:0.83634
# [55]	validation_0-auc:0.87732	validation_1-auc:0.83537
# [56]	validation_0-auc:0.87749	validation_1-auc:0.83491
# [57]	validation_0-auc:0.87800	validation_1-auc:0.83502
# [58]	validation_0-auc:0.87833	validation_1-auc:0.83466
# [59]	validation_0-auc:0.87897	validation_1-auc:0.83421
# [60]	validation_0-auc:0.87935	validation_1-auc:0.83450
# [61]	validation_0-auc:0.87939	validation_1-auc:0.83417
# [0]	validation_0-auc:0.81355	validation_1-auc:0.79913
# [1]	validation_0-auc:0.82730	validation_1-auc:0.80931
# [2]	validation_0-auc:0.83625	validation_1-auc:0.81643
# [3]	validation_0-auc:0.84224	validation_1-auc:0.82140
# [4]	validation_0-auc:0.84847	validation_1-auc:0.82435
# [5]	validation_0-auc:0.84936	validation_1-auc:0.82393
# [6]	validation_0-auc:0.84801	validation_1-auc:0.81984
# [7]	validation_0-auc:0.85774	validation_1-auc:0.82555
# [8]	validation_0-auc:0.86274	validation_1-auc:0.82632
# [9]	validation_0-auc:0.86564	validation_1-auc:0.82325
# [10]	validation_0-auc:0.86646	validation_1-auc:0.81845
# [11]	validation_0-auc:0.86731	validation_1-auc:0.81493
# [12]	validation_0-auc:0.87359	validation_1-auc:0.82293
# [13]	validation_0-auc:0.87755	validation_1-auc:0.82695
# [14]	validation_0-auc:0.87958	validation_1-auc:0.82842
# [15]	validation_0-auc:0.88098	validation_1-auc:0.82806
# [16]	validation_0-auc:0.88241	validation_1-auc:0.82862
# [17]	validation_0-auc:0.88335	validation_1-auc:0.82905
# [18]	validation_0-auc:0.88454	validation_1-auc:0.82984
# [19]	validation_0-auc:0.88598	validation_1-auc:0.83101
# [20]	validation_0-auc:0.88629	validation_1-auc:0.83036
# [21]	validation_0-auc:0.88716	validation_1-auc:0.83057
# [22]	validation_0-auc:0.88798	validation_1-auc:0.83080
# [23]	validation_0-auc:0.88909	validation_1-auc:0.83157
# [24]	validation_0-auc:0.88940	validation_1-auc:0.83162
# [25]	validation_0-auc:0.88973	validation_1-auc:0.83232
# [26]	validation_0-auc:0.89037	validation_1-auc:0.83219
# [27]	validation_0-auc:0.89199	validation_1-auc:0.83195
# [28]	validation_0-auc:0.89209	validation_1-auc:0.83166
# [29]	validation_0-auc:0.89313	validation_1-auc:0.83046
# [30]	validation_0-auc:0.89386	validation_1-auc:0.82917
# [31]	validation_0-auc:0.89443	validation_1-auc:0.82902
# [32]	validation_0-auc:0.89479	validation_1-auc:0.82937
# [33]	validation_0-auc:0.89591	validation_1-auc:0.82813
# [34]	validation_0-auc:0.89678	validation_1-auc:0.82735
# [35]	validation_0-auc:0.89709	validation_1-auc:0.82693
# [36]	validation_0-auc:0.89738	validation_1-auc:0.82669
# [37]	validation_0-auc:0.89757	validation_1-auc:0.82655
# [38]	validation_0-auc:0.89808	validation_1-auc:0.82610
# [39]	validation_0-auc:0.89807	validation_1-auc:0.82579
# [40]	validation_0-auc:0.89810	validation_1-auc:0.82571
# [41]	validation_0-auc:0.89887	validation_1-auc:0.82512
# [42]	validation_0-auc:0.89934	validation_1-auc:0.82445
# [43]	validation_0-auc:0.90038	validation_1-auc:0.82265
# [44]	validation_0-auc:0.90046	validation_1-auc:0.82217
# [45]	validation_0-auc:0.90053	validation_1-auc:0.82191
# [46]	validation_0-auc:0.90063	validation_1-auc:0.82200
# [47]	validation_0-auc:0.90145	validation_1-auc:0.82171
# [48]	validation_0-auc:0.90181	validation_1-auc:0.82185
# [49]	validation_0-auc:0.90231	validation_1-auc:0.82130
# [50]	validation_0-auc:0.90235	validation_1-auc:0.82147
# [51]	validation_0-auc:0.90275	validation_1-auc:0.82161
# [52]	validation_0-auc:0.90288	validation_1-auc:0.82068
# [53]	validation_0-auc:0.90334	validation_1-auc:0.82059
# [54]	validation_0-auc:0.90389	validation_1-auc:0.81940
# [0]	validation_0-auc:0.80957	validation_1-auc:0.80150
# [1]	validation_0-auc:0.82499	validation_1-auc:0.80743
# [2]	validation_0-auc:0.83876	validation_1-auc:0.82350
# [3]	validation_0-auc:0.84240	validation_1-auc:0.82407
# [4]	validation_0-auc:0.84817	validation_1-auc:0.82870
# [5]	validation_0-auc:0.84849	validation_1-auc:0.82707
# [6]	validation_0-auc:0.84722	validation_1-auc:0.82117
# [7]	validation_0-auc:0.85500	validation_1-auc:0.82729
# [8]	validation_0-auc:0.86144	validation_1-auc:0.82826
# [9]	validation_0-auc:0.86446	validation_1-auc:0.82384
# [10]	validation_0-auc:0.86410	validation_1-auc:0.82091
# [11]	validation_0-auc:0.86477	validation_1-auc:0.81957
# [12]	validation_0-auc:0.87045	validation_1-auc:0.82676
# [13]	validation_0-auc:0.87546	validation_1-auc:0.82984
# [14]	validation_0-auc:0.87732	validation_1-auc:0.83283
# [15]	validation_0-auc:0.87917	validation_1-auc:0.83177
# [16]	validation_0-auc:0.88088	validation_1-auc:0.83324
# [17]	validation_0-auc:0.88246	validation_1-auc:0.83451
# [18]	validation_0-auc:0.88269	validation_1-auc:0.83317
# [19]	validation_0-auc:0.88368	validation_1-auc:0.83283
# [20]	validation_0-auc:0.88428	validation_1-auc:0.83272
# [21]	validation_0-auc:0.88506	validation_1-auc:0.83184
# [22]	validation_0-auc:0.88618	validation_1-auc:0.83224
# [23]	validation_0-auc:0.88757	validation_1-auc:0.83278
# [24]	validation_0-auc:0.88797	validation_1-auc:0.83381
# [25]	validation_0-auc:0.88851	validation_1-auc:0.83383
# [26]	validation_0-auc:0.88964	validation_1-auc:0.83352
# [27]	validation_0-auc:0.88985	validation_1-auc:0.83304
# [28]	validation_0-auc:0.89013	validation_1-auc:0.83292
# [29]	validation_0-auc:0.89238	validation_1-auc:0.83326
# [30]	validation_0-auc:0.89249	validation_1-auc:0.83319
# [31]	validation_0-auc:0.89344	validation_1-auc:0.83324
# [32]	validation_0-auc:0.89356	validation_1-auc:0.83326
# [33]	validation_0-auc:0.89423	validation_1-auc:0.83384
# [34]	validation_0-auc:0.89510	validation_1-auc:0.83371
# [35]	validation_0-auc:0.89518	validation_1-auc:0.83348
# [36]	validation_0-auc:0.89509	validation_1-auc:0.83330
# [37]	validation_0-auc:0.89526	validation_1-auc:0.83294
# [38]	validation_0-auc:0.89541	validation_1-auc:0.83290
# [39]	validation_0-auc:0.89555	validation_1-auc:0.83259
# [40]	validation_0-auc:0.89551	validation_1-auc:0.83256
# [41]	validation_0-auc:0.89559	validation_1-auc:0.83145
# [42]	validation_0-auc:0.89574	validation_1-auc:0.83124
# [43]	validation_0-auc:0.89589	validation_1-auc:0.83115
# [44]	validation_0-auc:0.89654	validation_1-auc:0.83038
# [45]	validation_0-auc:0.89652	validation_1-auc:0.83039
# [46]	validation_0-auc:0.89728	validation_1-auc:0.82998
# [0]	validation_0-auc:0.81197	validation_1-auc:0.80344
# [1]	validation_0-auc:0.83081	validation_1-auc:0.81916
# [2]	validation_0-auc:0.83876	validation_1-auc:0.82569
# [3]	validation_0-auc:0.83950	validation_1-auc:0.82664
# [4]	validation_0-auc:0.84926	validation_1-auc:0.82716
# [5]	validation_0-auc:0.85056	validation_1-auc:0.82848
# [6]	validation_0-auc:0.85041	validation_1-auc:0.82518
# [7]	validation_0-auc:0.85727	validation_1-auc:0.82969
# [8]	validation_0-auc:0.86318	validation_1-auc:0.83353
# [9]	validation_0-auc:0.86568	validation_1-auc:0.82844
# [10]	validation_0-auc:0.86612	validation_1-auc:0.82478
# [11]	validation_0-auc:0.86764	validation_1-auc:0.82194
# [12]	validation_0-auc:0.87332	validation_1-auc:0.82666
# [13]	validation_0-auc:0.87684	validation_1-auc:0.83014
# [14]	validation_0-auc:0.87807	validation_1-auc:0.83189
# [15]	validation_0-auc:0.87984	validation_1-auc:0.83142
# [16]	validation_0-auc:0.88122	validation_1-auc:0.83256
# [17]	validation_0-auc:0.88231	validation_1-auc:0.83279
# [18]	validation_0-auc:0.88409	validation_1-auc:0.83149
# [19]	validation_0-auc:0.88560	validation_1-auc:0.83239
# [20]	validation_0-auc:0.88584	validation_1-auc:0.83193
# [21]	validation_0-auc:0.88591	validation_1-auc:0.83179
# [22]	validation_0-auc:0.88663	validation_1-auc:0.83206
# [23]	validation_0-auc:0.88875	validation_1-auc:0.83200
# [24]	validation_0-auc:0.88919	validation_1-auc:0.83191
# [25]	validation_0-auc:0.88944	validation_1-auc:0.83174
# [26]	validation_0-auc:0.88973	validation_1-auc:0.83132
# [27]	validation_0-auc:0.89081	validation_1-auc:0.83154
# [28]	validation_0-auc:0.89093	validation_1-auc:0.83131
# [29]	validation_0-auc:0.89120	validation_1-auc:0.83137
# [30]	validation_0-auc:0.89152	validation_1-auc:0.83139
# [31]	validation_0-auc:0.89157	validation_1-auc:0.83137
# [32]	validation_0-auc:0.89166	validation_1-auc:0.83114
# [33]	validation_0-auc:0.89185	validation_1-auc:0.83125
# [34]	validation_0-auc:0.89251	validation_1-auc:0.83102
# [35]	validation_0-auc:0.89321	validation_1-auc:0.83123
# [36]	validation_0-auc:0.89358	validation_1-auc:0.83078
# [37]	validation_0-auc:0.89418	validation_1-auc:0.83100
# [38]	validation_0-auc:0.89411	validation_1-auc:0.83050
# [0]	validation_0-auc:0.81263	validation_1-auc:0.79766
# [1]	validation_0-auc:0.82427	validation_1-auc:0.80736
# [2]	validation_0-auc:0.83439	validation_1-auc:0.81803
# [3]	validation_0-auc:0.84010	validation_1-auc:0.82169
# [4]	validation_0-auc:0.84622	validation_1-auc:0.82395
# [5]	validation_0-auc:0.84705	validation_1-auc:0.82251
# [6]	validation_0-auc:0.84569	validation_1-auc:0.81799
# [7]	validation_0-auc:0.85503	validation_1-auc:0.82331
# [8]	validation_0-auc:0.85986	validation_1-auc:0.82374
# [9]	validation_0-auc:0.86215	validation_1-auc:0.82280
# [10]	validation_0-auc:0.86241	validation_1-auc:0.81926
# [11]	validation_0-auc:0.86233	validation_1-auc:0.81859
# [12]	validation_0-auc:0.86848	validation_1-auc:0.82449
# [13]	validation_0-auc:0.87228	validation_1-auc:0.82889
# [14]	validation_0-auc:0.87380	validation_1-auc:0.83107
# [15]	validation_0-auc:0.87498	validation_1-auc:0.83124
# [16]	validation_0-auc:0.87673	validation_1-auc:0.83209
# [17]	validation_0-auc:0.87802	validation_1-auc:0.83248
# [18]	validation_0-auc:0.87832	validation_1-auc:0.83154
# [19]	validation_0-auc:0.87979	validation_1-auc:0.83316
# [20]	validation_0-auc:0.88059	validation_1-auc:0.83330
# [21]	validation_0-auc:0.88145	validation_1-auc:0.83219
# [22]	validation_0-auc:0.88250	validation_1-auc:0.83321
# [23]	validation_0-auc:0.88289	validation_1-auc:0.83384
# [24]	validation_0-auc:0.88368	validation_1-auc:0.83416
# [25]	validation_0-auc:0.88429	validation_1-auc:0.83316
# [26]	validation_0-auc:0.88472	validation_1-auc:0.83292
# [27]	validation_0-auc:0.88520	validation_1-auc:0.83358
# [28]	validation_0-auc:0.88525	validation_1-auc:0.83330
# [29]	validation_0-auc:0.88645	validation_1-auc:0.83273
# [30]	validation_0-auc:0.88655	validation_1-auc:0.83205
# [31]	validation_0-auc:0.88693	validation_1-auc:0.83190
# [32]	validation_0-auc:0.88757	validation_1-auc:0.83164
# [33]	validation_0-auc:0.88780	validation_1-auc:0.83158
# [34]	validation_0-auc:0.88855	validation_1-auc:0.83247
# [35]	validation_0-auc:0.88875	validation_1-auc:0.83210
# [36]	validation_0-auc:0.88907	validation_1-auc:0.83180
# [37]	validation_0-auc:0.88935	validation_1-auc:0.83139
# [38]	validation_0-auc:0.88994	validation_1-auc:0.83012
# [39]	validation_0-auc:0.89048	validation_1-auc:0.82961
# [40]	validation_0-auc:0.89072	validation_1-auc:0.83010
# [41]	validation_0-auc:0.89078	validation_1-auc:0.83006
# [42]	validation_0-auc:0.89231	validation_1-auc:0.82982
# [43]	validation_0-auc:0.89243	validation_1-auc:0.82978
# [44]	validation_0-auc:0.89313	validation_1-auc:0.82888
# [45]	validation_0-auc:0.89327	validation_1-auc:0.82898
# [46]	validation_0-auc:0.89412	validation_1-auc:0.82766
# [47]	validation_0-auc:0.89472	validation_1-auc:0.82718
# [48]	validation_0-auc:0.89485	validation_1-auc:0.82704
# [49]	validation_0-auc:0.89565	validation_1-auc:0.82654
# [50]	validation_0-auc:0.89571	validation_1-auc:0.82640
# [51]	validation_0-auc:0.89620	validation_1-auc:0.82678
# [52]	validation_0-auc:0.89631	validation_1-auc:0.82689
# [53]	validation_0-auc:0.89646	validation_1-auc:0.82668

# %%
print('GV 최적 파라미터:', gridcv.best_params_)
xgb_roc_score = roc_auc_score(y_test,gridcv.predict_proba(X_test)[:,1])
print('AUC:{:.4f}'.format(xgb_roc_score))

# %%
gridcv.predict_proba(X_test)[:,1]

# %%
# refit
xgb_clf = XGBClassifier(n_estimators=1000,random_state=150,colsample_bytes=0.75, max_depth=5,
                        min_child_weight=1, reg_alpha=0.02)
xgb_clf.fit(X_train,y_train,early_stopping_rounds=200,eval_metric='auc',eval_set=evals)

# %%
xgb_roc_score = roc_auc_score(y_test,xgb_clf.predict_proba(X_test)[:,1])
print('AUC:{:.4f}'.format(xgb_roc_score))

# %%
# models
lgbm_wrapper = LGBMClassifier(n_estimators=500, random_state=150)

# %%
# fit
evals=[(X_test,y_test),(X_test,y_test)]
lgbm_wrapper.fit(X_train,y_train,early_stopping_rounds=100, eval_metric='auc',eval_set=evals,verbose=True)

# %%
# predict
lgbm_wrapper_preds = lgbm_wrapper.predict(X_test)
lgbm_wrapper_proba = lgbm_wrapper.predict_proba(X_test)[:,1]

# %%
# AUC
lgb_roc_score = roc_auc_score(y_test,lgbm_wrapper_proba,average='macro')
print("roc_auc : {0:.4f}".format(lgb_roc_score))

# %%
# 2nd Validation
grid_lgb_clf = LGBMClassifier()
print(grid_lgb_clf.get_params())
params = {max_depth:[]}
