# %%
import numpy as np
import pandas as pd

# %%
ar1 = np.arange(10).reshape(2,5)
df = pd.DataFrame(ar1,columns=list('abcde'))
df.to_csv('../Data/test.csv')

# %%
data = pd.read_csv('../Data/test.csv',index_col=0)
data1 = data.copy()
data1 = data1.rename(columns={'a':'Name','b':'Age','c':'job_code','d':'Salary','e':'home_location'})

# %%
data1['alive'] = np.random.choice([0,1])
data1.set_index('Name')
data1 = data1.rename(index={0:'A',1:'B'})

# %%
data1.loc['C']=0
data1.loc['D']=0

# %%
data1.to_csv('../Data/test1.csv')
data1 = pd.read_csv('../Data/test1.csv',index_col=0)
#data1.to_csv('../Data/test1.csv',index=False)

# %%
data1
# Out:
#    Name  Age  job_code  Salary  home_location  alive
# A     0    1         2       3              4      0
# B     5    6         7       8              9      0
# C     0    0         0       0              0      0
# D     0    0         0       0              0      0

# %%
# json file  
#json DICT 형식으로 저장됨 -- {key:value}

# %%
data1.iloc[2]=1
data1.iloc[3]=2

# %%
data1.to_json('../Data/test2.json')
data_J = pd.read_json('../Data/test2.json')
data_J
# Out:
#    Name  Age  job_code  Salary  home_location  alive
# A     0    1         2       3              4      0
# B     5    6         7       8              9      0
# C     1    1         1       1              1      1
# D     2    2         2       2              2      2

# %%
# Binary 파일 읽고 쓰기
data1.to_pickle('../Data/test3.pkl')
data_P = pd.read_pickle('../Data/test3.pkl')

# %% [markdown]
# Q. 간단한 DF 만들고 csv,json,pickle 형태로 저장후 불러오기

# %%
np.random.seed(0)
data  = np.random.randint(80,100,size=(5,5))
df = pd.DataFrame(data,columns =list('abcde'))
df
# Out:
#     a   b   c   d   e
# 0  92  95  80  83  83
# 1  87  89  99  98  84
# 2  86  92  81  86  87
# 3  94  97  85  93  88
# 4  89  99  96  99  85

# %%
df.to_csv('../Data/df_c.csv',index=False)
data_c = pd.read_csv('../Data/df_c.csv')
data_c
# Out:
#     a   b   c   d   e
# 0  92  95  80  83  83
# 1  87  89  99  98  84
# 2  86  92  81  86  87
# 3  94  97  85  93  88
# 4  89  99  96  99  85

# %%
df.to_json('../Data/df_j.json')
data_j = pd.read_json('../Data/df_j.json')
data_j
# Out:
#     a   b   c   d   e
# 0  92  95  80  83  83
# 1  87  89  99  98  84
# 2  86  92  81  86  87
# 3  94  97  85  93  88
# 4  89  99  96  99  85

# %%
df.to_pickle('../Data/df_p.pkl')
data_p = pd.read_pickle('../Data/df_p.pkl')
data_p
# Out:
#     a   b   c   d   e
# 0  92  95  80  83  83
# 1  87  89  99  98  84
# 2  86  92  81  86  87
# 3  94  97  85  93  88
# 4  89  99  96  99  85

# %%
# !pip install openpyxl
# !pip install xlrd
# Out:
# Requirement already satisfied: openpyxl in c:\tool\envs\cakd3\lib\site-packages (3.0.7)
# Requirement already satisfied: et-xmlfile in c:\tool\envs\cakd3\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: xlrd in c:\tool\envs\cakd3\lib\site-packages (2.0.1)

# %%
data = pd.read_excel('../Data/auto-mpg.xlsx')
data_h = data.head()
data.to_excel('../Data/test_E.xlsx',index=False)
data1 = pd.read_excel('../Data/test_E.xlsx')
data1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 393          82       1            ford mustang gl
# 394          82       2                  vw pickup
# 395          82       1              dodge rampage
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
data.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
data.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
data.mpg
data[['mpg']].plot()
# Out:
# <AxesSubplot:>
